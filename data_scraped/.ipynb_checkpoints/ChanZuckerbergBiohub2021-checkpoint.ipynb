# %%
# Project 03 - Donation tells you who they really are! (Chan Zuckerberg Initiative Advocacy)

# %%
import requests
zuck_biohub = requests.get("https://projects.propublica.org/nonprofits/download-xml?object_id=202123169349300012")
zuck_biohub
# Out:
# <Response [200]>

# %%
# The text is the raw xml of Form 990 tax document,obtained from ProPublica's non-profit explorer.
zuck_xml = zuck_biohub.text
print(zuck_xml)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Return xmlns="http://www.irs.gov/efile" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.irs.gov/efile" returnVersion="2020v4.1">
#   <ReturnHeader binaryAttachmentCnt="0">
#     <ReturnTs>2021-11-12T02:42:42-06:00</ReturnTs>
#     <TaxPeriodEndDt>2020-12-31</TaxPeriodEndDt>
#     <PreparerFirmGrp>
#       <PreparerFirmEIN>861065772</PreparerFirmEIN>
#       <PreparerFirmName>
#         <BusinessNameLine1Txt>DELOITTE TAX LLP</BusinessNameLine1Txt>
#       </PreparerFirmName>
#       <PreparerUSAddress>
#         <AddressLine1Txt>50 SOUTH SIXTH STREET</AddressLine1Txt>
#         <CityNm>MINNEAPOLIS</CityNm>
#         <StateAbbreviationCd>MN</StateAbbreviationCd>
#         <ZIPCd>55402</ZIPCd>
#       </PreparerUSAddress>
#     </PreparerFirmGrp>
#     <ReturnTypeCd>990</ReturnTypeCd>
#     <TaxPeriodBeginDt>2020-01-01</TaxPeriodBeginDt>
#     <Filer>
#       <EIN>811669175</EIN>
#       <BusinessName>
#         <BusinessNameLine1Txt>CHAN ZUCKERBERG BIOHUB INC</BusinessNameLine1Txt>
#       </BusinessName>
#       <BusinessNameControlTxt>CHAN</BusinessNameControlTxt>
#       <PhoneNum>6282003246</PhoneNum>
#       <USAddress>
#         <AddressLine1Txt>499 ILLINOIS ST</AddressLine1Txt>
#         <CityNm>SAN FRANCISCO</CityNm>
#         <StateAbbreviationCd>CA</StateAbbreviationCd>
#         <ZIPCd>94158</ZIPCd>
#       </USAddress>
#     </Filer>
#     <BusinessOfficerGrp>
#       <PersonNm>VICTOR COLUNGA</PersonNm>
#       <PersonTitleTxt>CFO AND TREASURER</PersonTitleTxt>
#       <PhoneNum>6282003246</PhoneNum>
#       <SignatureDt>2021-11-11</SignatureDt>
#       <DiscussWithPaidPreparerInd>1</DiscussWithPaidPreparerInd>
#     </BusinessOfficerGrp>
#     <SigningOfficerGrp>
#       <PersonFullName>
#         <PersonFirstNm>VICTOR</PersonFirstNm>
#         <PersonLastNm>COLUNGA</PersonLastNm>
#       </PersonFullName>
#       <SSN>999009999</SSN>
#     </SigningOfficerGrp>
#     <PreparerPersonGrp>
#       <PreparerPersonNm>ANNA KOLAKALURI</PreparerPersonNm>
#       <PTIN>P01275237</PTIN>
#       <PhoneNum>6123974000</PhoneNum>
#     </PreparerPersonGrp>
#     <AdditionalFilerInformation>
#       <TrustedCustomerGrp>
#         <TrustedCustomerCd>2</TrustedCustomerCd>
#         <AuthenticationAssuranceLevelCd>AAL1</AuthenticationAssuranceLevelCd>
#         <IdentityAssuranceLevelCd>IAL1</IdentityAssuranceLevelCd>
#       </TrustedCustomerGrp>
#     </AdditionalFilerInformation>
#     <TaxYr>2020</TaxYr>
#     <BuildTS>2022-09-23 18:48:47Z</BuildTS>
#   </ReturnHeader>
#   <ReturnData documentCnt="11">
#     <IRS990 documentId="RetDoc1038000001" referenceDocumentId="RetDoc1044400001">
#       <PrincipalOfficerNm>GAJUS WORTHINGTON</PrincipalOfficerNm>
#       <USAddress>
#         <AddressLine1Txt>499 ILLINOIS ST</AddressLine1Txt>
#         <CityNm>SAN FRANCISCO</CityNm>
#         <StateAbbreviationCd>CA</StateAbbreviationCd>
#         <ZIPCd>94158</ZIPCd>
#       </USAddress>
#       <GrossReceiptsAmt>14019977</GrossReceiptsAmt>
#       <GroupReturnForAffiliatesInd>0</GroupReturnForAffiliatesInd>
#       <Organization501c3Ind>X</Organization501c3Ind>
#       <WebsiteAddressTxt>WWW.CZBIOHUB.ORG</WebsiteAddressTxt>
#       <TypeOfOrganizationCorpInd>X</TypeOfOrganizationCorpInd>
#       <FormationYr>2016</FormationYr>
#       <LegalDomicileStateCd>CA</LegalDomicileStateCd>
#       <ActivityOrMissionDesc>CONDUCT CUTTING EDGE MEDICAL RESEARCH</ActivityOrMissionDesc>
#       <VotingMembersGoverningBodyCnt>7</VotingMembersGoverningBodyCnt>
#       <VotingMembersIndependentCnt>3</VotingMembersIndependentCnt>
#       <TotalEmployeeCnt>147</TotalEmployeeCnt>
#       <TotalVolunteersCnt>0</TotalVolunteersCnt>
#       <TotalGrossUBIAmt>0</TotalGrossUBIAmt>
#       <NetUnrelatedBusTxblIncmAmt>0</NetUnrelatedBusTxblIncmAmt>
#       <PYContributionsGrantsAmt>10451256</PYContributionsGrantsAmt>
#       <CYContributionsGrantsAmt>12999993</CYContributionsGrantsAmt>
#       <PYProgramServiceRevenueAmt>421941</PYProgramServiceRevenueAmt>
#       <CYProgramServiceRevenueAmt>472759</CYProgramServiceRevenueAmt>
#       <PYInvestmentIncomeAmt>1286901</PYInvestmentIncomeAmt>
#       <CYInvestmentIncomeAmt>317759</CYInvestmentIncomeAmt>
#       <PYOtherRevenueAmt>83378</PYOtherRevenueAmt>
#       <CYOtherRevenueAmt>229466</CYOtherRevenueAmt>
#       <PYTotalRevenueAmt>12243476</PYTotalRevenueAmt>
#       <CYTotalRevenueAmt>14019977</CYTotalRevenueAmt>
#       <PYGrantsAndSimilarPaidAmt>22278762</PYGrantsAndSimilarPaidAmt>
#       <CYGrantsAndSimilarPaidAmt>24769945</CYGrantsAndSimilarPaidAmt>
#       <PYBenefitsPaidToMembersAmt>0</PYBenefitsPaidToMembersAmt>
#       <CYBenefitsPaidToMembersAmt>0</CYBenefitsPaidToMembersAmt>
#       <PYSalariesCompEmpBnftPaidAmt>18098377</PYSalariesCompEmpBnftPaidAmt>
#       <CYSalariesCompEmpBnftPaidAmt>21962369</CYSalariesCompEmpBnftPaidAmt>
#       <PYTotalProfFndrsngExpnsAmt>0</PYTotalProfFndrsngExpnsAmt>
#       <CYTotalProfFndrsngExpnsAmt>0</CYTotalProfFndrsngExpnsAmt>
#       <CYTotalFundraisingExpenseAmt>0</CYTotalFundraisingExpenseAmt>
#       <PYOtherExpensesAmt>24924894</PYOtherExpensesAmt>
#       <CYOtherExpensesAmt>30625193</CYOtherExpensesAmt>
#       <PYTotalExpensesAmt>65302033</PYTotalExpensesAmt>
#       <CYTotalExpensesAmt>77357507</CYTotalExpensesAmt>
#       <PYRevenuesLessExpensesAmt>-53058557</PYRevenuesLessExpensesAmt>
#       <CYRevenuesLessExpensesAmt>-63337530</CYRevenuesLessExpensesAmt>
#       <TotalAssetsBOYAmt>468214819</TotalAssetsBOYAmt>
#       <TotalAssetsEOYAmt>404074181</TotalAssetsEOYAmt>
#       <TotalLiabilitiesBOYAmt>13973337</TotalLiabilitiesBOYAmt>
#       <TotalLiabilitiesEOYAmt>13170229</TotalLiabilitiesEOYAmt>
#       <NetAssetsOrFundBalancesBOYAmt>454241482</NetAssetsOrFundBalancesBOYAmt>
#       <NetAssetsOrFundBalancesEOYAmt>390903952</NetAssetsOrFundBalancesEOYAmt>
#       <InfoInScheduleOPartIIIInd>X</InfoInScheduleOPartIIIInd>
#       <MissionDesc>ALLEVIATING HUMAN SUFFERING THROUGH ITS MISSION TO CURE, MANAGE, AND PREVENT ALL DISEASES BY THE END OF THE 21ST CENTURY.</MissionDesc>
#       <SignificantNewProgramSrvcInd>0</SignificantNewProgramSrvcInd>
#       <SignificantChangeInd>0</SignificantChangeInd>
#       <ExpenseAmt>68944396</ExpenseAmt>
#       <GrantAmt>24769945</GrantAmt>
#       <RevenueAmt>472759</RevenueAmt>
#       <Desc>THOUGH OUR LABS WERE SHUT DOWN FOR EVERYTHING BUT ESSENTIAL COVID-19 WORK THROUGH MOST OF THE SUMMER OF 2020, OUR STAFF WERE STILL VERY PRODUCTIVE WITH THE TIME THEY HAD PRIOR TO THE SHELTER IN PLACE ORDERS AND AFTER WE WERE ABLE TO BEGIN NON-COVID WORK AT A LOWER AND SAFE LAB DENSITY. AMONG THE PUBLISHED WORK WE WERE ABLE TO COMPLETE ARE THE FOLLOWING:- NINE JOURNAL PUBLICATIONS ABOUT AGING AND DISEASES OF AGING, LARGELY ORIENTED AROUND SINGLE CELL TRANSCIPTOMICS. - NINE JOURNAL PUBLICATIONS AND PREPRINTS DESCRIBING TOOLS DEVELOPED TO FACILITATE SINGLE CELL TRANSCIPTOMICS.- FIVE JOURNAL PUBLICATIONS INVOLVING THE USE OF SINGLE CELL TRANSCRIPTOMICS IN DEVELOPMENT AND NEUROSCIENCE.- SIX JOURNAL PUBLICATIONS INVOLVING THE USE OF SINGLE CELL TRANSCRIPTOMICS IN INFECTIOUS DISEASE AND IMMUNE RESPONSE.- FIVE JOURNAL PUBLICATIONS RELATING TO STUDIES ABOUT CELL ARCHITECTURE.- SEVEN PUBLICATIONS AND PREPRINTS DESCRIBING TOOLS TO STUDY CELLULAR ARCHITECTURE.- TWENTY-SIX JOURNAL/PRE-PRINT PUBLICATIONS FOCUSED ON COVID-19.- THIRTEEN JOURNAL/PRE-PRINT PUBLICATIONS ON IMMUNOLOGICAL ASPECTS OF INFECTION.- SIX PUBLICATIONS ON NEW TOOLS FOR INFECTIOUS DISEASE INVESTIGATION.ORGANIZATIONALLY, WE AUGMENTED OUR RESEARCH ORGANIZATION LEADERSHIP BY RECRUITING A CHIEF SCIENTIFIC OFFICER, A NATIONAL ACADEMY OF SCIENCE RESEARCHER TO LEAD OUR SCIENTIFIC PROGRAMS.IN ADDITION TO THE ABOVE, THE BIOHUB MOBILIZED TO DELIVER A NUMBER OF CONTRIBUTIONS TOWARDS COVID-19. THESE INCLUDE:1) CLIAHUB, WITH OVER 160,000 PATIENT SAMPLES TESTED.2) COVIDTRACKER FOR MOLECULAR EPIDEMIOLOGY.3) CATCH, AN AT-HOME SAMPLE COLLECTION TESTING PLATFORM.4) AN FDA EMERGENCY USE AUTHORIZATION SUBMISSION FOR A FULLY DESIGNED AND TESTED LOW-COST VENTILATOR.5) FUNDING FOR THREE SEPARATE ANTIVIRAL INVESTIGATIONAL NEW DRUG FILINGS IN CONJUNCTION WITH STANFORD UNIVERSITY.6) COLLABORATION ON MULTIPLE SEROLOGICAL PROJECTS.7) COLLABORATION ON THE DEVELOPMENT OF EARLY STAGE COVID-19 VACCINES.8) ORGANIZATION AND EXECUTION OF CALIFORNIA DEPARTMENT OF PUBLIC HEALTH SCIENTIFIC WORKSHOPS.9) ASSISTANCE WITH PROCUREMENT OF EQUIPMENT AND SUPPLIES FOR TESTING CLINICS AROUND THE BAY AREA.</Desc>
#       <TotalProgramServiceExpensesAmt>68944396</TotalProgramServiceExpensesAmt>
#       <DescribedInSection501c3Ind referenceDocumentId="RetDoc1039100001">1</DescribedInSection501c3Ind>
#       <ScheduleBRequiredInd referenceDocumentId="RetDoc1234500001">1</ScheduleBRequiredInd>
#       <PoliticalCampaignActyInd>0</PoliticalCampaignActyInd>
#       <LobbyingActivitiesInd>0</LobbyingActivitiesInd>
#       <SubjectToProxyTaxInd>0</SubjectToProxyTaxInd>
#       <DonorAdvisedFundInd referenceDocumentId="RetDoc1040000001">0</DonorAdvisedFundInd>
#       <ConservationEasementsInd referenceDocumentId="RetDoc1040000001">0</ConservationEasementsInd>
#       <CollectionsOfArtInd referenceDocumentId="RetDoc1040000001">0</CollectionsOfArtInd>
#       <CreditCounselingInd referenceDocumentId="RetDoc1040000001">0</CreditCounselingInd>
#       <DonorRstrOrQuasiEndowmentsInd>0</DonorRstrOrQuasiEndowmentsInd>
#       <ReportLandBuildingEquipmentInd referenceDocumentId="RetDoc1040000001">1</ReportLandBuildingEquipmentInd>
#       <ReportInvestmentsOtherSecInd referenceDocumentId="RetDoc1040000001">0</ReportInvestmentsOtherSecInd>
#       <ReportProgramRelatedInvstInd referenceDocumentId="RetDoc1040000001">0</ReportProgramRelatedInvstInd>
#       <ReportOtherAssetsInd referenceDocumentId="RetDoc1040000001">0</ReportOtherAssetsInd>
#       <ReportOtherLiabilitiesInd referenceDocumentId="RetDoc1040000001">0</ReportOtherLiabilitiesInd>
#       <IncludeFIN48FootnoteInd referenceDocumentId="RetDoc1040000001">1</IncludeFIN48FootnoteInd>
#       <IndependentAuditFinclStmtInd referenceDocumentId="RetDoc1040000001">1</IndependentAuditFinclStmtInd>
#       <ConsolidatedAuditFinclStmtInd referenceDocumentId="RetDoc1040000001">0</ConsolidatedAuditFinclStmtInd>
#       <SchoolOperatingInd>0</SchoolOperatingInd>
#       <ForeignOfficeInd>0</ForeignOfficeInd>
#       <ForeignActivitiesInd referenceDocumentId="RetDoc1040500001">1</ForeignActivitiesInd>
#       <MoreThan5000KToOrgInd referenceDocumentId="RetDoc1040500001">1</MoreThan5000KToOrgInd>
#       <MoreThan5000KToIndividualsInd referenceDocumentId="RetDoc1040500001">0</MoreThan5000KToIndividualsInd>
#       <ProfessionalFundraisingInd>0</ProfessionalFundraisingInd>
#       <FundraisingActivitiesInd>0</FundraisingActivitiesInd>
#       <GamingActivitiesInd>0</GamingActivitiesInd>
#       <OperateHospitalInd>0</OperateHospitalInd>
#       <GrantsToOrganizationsInd referenceDocumentId="RetDoc1041900001">1</GrantsToOrganizationsInd>
#       <GrantsToIndividualsInd referenceDocumentId="RetDoc1041900001">0</GrantsToIndividualsInd>
#       <ScheduleJRequiredInd referenceDocumentId="RetDoc1042400001">1</ScheduleJRequiredInd>
#       <TaxExemptBondsInd>0</TaxExemptBondsInd>
#       <EngagedInExcessBenefitTransInd referenceDocumentId="RetDoc1042800001">0</EngagedInExcessBenefitTransInd>
#       <PYExcessBenefitTransInd referenceDocumentId="RetDoc1042800001">0</PYExcessBenefitTransInd>
#       <LoanOutstandingInd referenceDocumentId="RetDoc1042800001">0</LoanOutstandingInd>
#       <GrantToRelatedPersonInd referenceDocumentId="RetDoc1042800001">0</GrantToRelatedPersonInd>
#       <BusinessRlnWithOrgMemInd referenceDocumentId="RetDoc1042800001">0</BusinessRlnWithOrgMemInd>
#       <BusinessRlnWithFamMemInd referenceDocumentId="RetDoc1042800001">0</BusinessRlnWithFamMemInd>
#       <BusinessRlnWith35CtrlEntInd>1</BusinessRlnWith35CtrlEntInd>
#       <DeductibleNonCashContriInd referenceDocumentId="RetDoc1042900001">1</DeductibleNonCashContriInd>
#       <DeductibleArtContributionInd referenceDocumentId="RetDoc1042900001">0</DeductibleArtContributionInd>
#       <TerminateOperationsInd>0</TerminateOperationsInd>
#       <PartialLiquidationInd>0</PartialLiquidationInd>
#       <DisregardedEntityInd referenceDocumentId="RetDoc1043400001">0</DisregardedEntityInd>
#       <RelatedEntityInd referenceDocumentId="RetDoc1043400001">1</RelatedEntityInd>
#       <RelatedOrganizationCtrlEntInd>0</RelatedOrganizationCtrlEntInd>
#       <TrnsfrExmptNonChrtblRltdOrgInd referenceDocumentId="RetDoc1043400001">0</TrnsfrExmptNonChrtblRltdOrgInd>
#       <ActivitiesConductedPrtshpInd referenceDocumentId="RetDoc1043400001">0</ActivitiesConductedPrtshpInd>
#       <ScheduleORequiredInd>1</ScheduleORequiredInd>
#       <IRPDocumentCnt>83</IRPDocumentCnt>
#       <IRPDocumentW2GCnt>0</IRPDocumentW2GCnt>
#       <BackupWthldComplianceInd>1</BackupWthldComplianceInd>
#       <EmployeeCnt>147</EmployeeCnt>
#       <EmploymentTaxReturnsFiledInd>1</EmploymentTaxReturnsFiledInd>
#       <UnrelatedBusIncmOverLimitInd>0</UnrelatedBusIncmOverLimitInd>
#       <ForeignFinancialAccountInd>0</ForeignFinancialAccountInd>
#       <ProhibitedTaxShelterTransInd>0</ProhibitedTaxShelterTransInd>
#       <TaxablePartyNotificationInd>0</TaxablePartyNotificationInd>
#       <NondeductibleContributionsInd>0</NondeductibleContributionsInd>
#       <QuidProQuoContributionsInd>0</QuidProQuoContributionsInd>
#       <Form8282PropertyDisposedOfInd>0</Form8282PropertyDisposedOfInd>
#       <RcvFndsToPayPrsnlBnftCntrctInd>0</RcvFndsToPayPrsnlBnftCntrctInd>
#       <PayPremiumsPrsnlBnftCntrctInd>0</PayPremiumsPrsnlBnftCntrctInd>
#       <IndoorTanningServicesInd>0</IndoorTanningServicesInd>
#       <SubjToTaxRmnrtnExPrchtPymtInd>0</SubjToTaxRmnrtnExPrchtPymtInd>
#       <SubjectToExcsTaxNetInvstIncInd>0</SubjectToExcsTaxNetInvstIncInd>
#       <InfoInScheduleOPartVIInd>X</InfoInScheduleOPartVIInd>
#       <GoverningBodyVotingMembersCnt>7</GoverningBodyVotingMembersCnt>
#       <IndependentVotingMemberCnt>3</IndependentVotingMemberCnt>
#       <FamilyOrBusinessRlnInd>1</FamilyOrBusinessRlnInd>
#       <DelegationOfMgmtDutiesInd>0</DelegationOfMgmtDutiesInd>
#       <ChangeToOrgDocumentsInd>0</ChangeToOrgDocumentsInd>
#       <MaterialDiversionOrMisuseInd>0</MaterialDiversionOrMisuseInd>
#       <MembersOrStockholdersInd>0</MembersOrStockholdersInd>
#       <ElectionOfBoardMembersInd>1</ElectionOfBoardMembersInd>
#       <DecisionsSubjectToApprovaInd>1</DecisionsSubjectToApprovaInd>
#       <MinutesOfGoverningBodyInd>1</MinutesOfGoverningBodyInd>
#       <MinutesOfCommitteesInd>1</MinutesOfCommitteesInd>
#       <OfficerMailingAddressInd>0</OfficerMailingAddressInd>
#       <LocalChaptersInd>0</LocalChaptersInd>
#       <Form990ProvidedToGvrnBodyInd>1</Form990ProvidedToGvrnBodyInd>
#       <ConflictOfInterestPolicyInd>1</ConflictOfInterestPolicyInd>
#       <AnnualDisclosureCoveredPrsnInd>1</AnnualDisclosureCoveredPrsnInd>
#       <RegularMonitoringEnfrcInd>1</RegularMonitoringEnfrcInd>
#       <WhistleblowerPolicyInd>1</WhistleblowerPolicyInd>
#       <DocumentRetentionPolicyInd>0</DocumentRetentionPolicyInd>
#       <CompensationProcessCEOInd>1</CompensationProcessCEOInd>
#       <CompensationProcessOtherInd>0</CompensationProcessOtherInd>
#       <InvestmentInJointVentureInd>1</InvestmentInJointVentureInd>
#       <WrittenPolicyOrProcedureInd>0</WrittenPolicyOrProcedureInd>
#       <StatesWhereCopyOfReturnIsFldCd>CA</StatesWhereCopyOfReturnIsFldCd>
#       <OtherInd>X</OtherInd>
#       <BooksInCareOfDetail>
#         <BusinessName>
#           <BusinessNameLine1Txt>VICTOR COLUNGA CFO &amp; TREASURER</BusinessNameLine1Txt>
#         </BusinessName>
#         <PhoneNum>6282003246</PhoneNum>
#         <USAddress>
#           <AddressLine1Txt>499 ILLINOIS ST</AddressLine1Txt>
#           <CityNm>SAN FRANCISCO</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94158</ZIPCd>
#         </USAddress>
#       </BooksInCareOfDetail>
#       <InfoInScheduleOPartVIIInd>X</InfoInScheduleOPartVIIInd>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>JOSEPH DERISI</PersonNm>
#         <TitleTxt>CO-PRESIDENT</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#         <OfficerInd>X</OfficerInd>
#         <ReportableCompFromOrgAmt>909234</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>35540</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>STEVE QUAKE</PersonNm>
#         <TitleTxt>CO-PRESIDENT</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#         <OfficerInd>X</OfficerInd>
#         <ReportableCompFromOrgAmt>909234</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>35540</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>CORI BARGMANN</PersonNm>
#         <TitleTxt>DIRECTOR</TitleTxt>
#         <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#         <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>0</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>JOHN HENNESSY</PersonNm>
#         <TitleTxt>DIRECTOR</TitleTxt>
#         <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#         <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>0</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>PRISCILLA CHAN</PersonNm>
#         <TitleTxt>DIRECTOR</TitleTxt>
#         <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>3.50</AverageHoursPerWeekRltdOrgRt>
#         <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#         <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>0</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>REID HOFFMAN</PersonNm>
#         <TitleTxt>DIRECTOR</TitleTxt>
#         <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#         <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>0</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>MARK ZUCKERBERG</PersonNm>
#         <TitleTxt>DIRECTOR</TitleTxt>
#         <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>41.50</AverageHoursPerWeekRltdOrgRt>
#         <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#         <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>0</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>GAJUS WORTHINGTON</PersonNm>
#         <TitleTxt>CHIEF OPERATING OFFICER</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <OfficerInd>X</OfficerInd>
#         <ReportableCompFromOrgAmt>741684</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>45961</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>VICTOR COLUNGA</PersonNm>
#         <TitleTxt>CFO &amp; TREASURER</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <OfficerInd>X</OfficerInd>
#         <ReportableCompFromOrgAmt>713940</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>44170</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>MAUREEN SHEEHY</PersonNm>
#         <TitleTxt>SECRETARY AND LEGAL COUNSEL</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <OfficerInd>X</OfficerInd>
#         <ReportableCompFromOrgAmt>607455</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>43513</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>JIM KARKANIAS</PersonNm>
#         <TitleTxt>VP, DATA SCIENCES &amp; IT INF</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <KeyEmployeeInd>X</KeyEmployeeInd>
#         <ReportableCompFromOrgAmt>510736</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>36565</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>SANDRA L SCHMID START 6120</PersonNm>
#         <TitleTxt>CHIEF SCIENTIFIC OFFICER</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <KeyEmployeeInd>X</KeyEmployeeInd>
#         <ReportableCompFromOrgAmt>384941</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>13593</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>WILLIAM BURKHOLDER</PersonNm>
#         <TitleTxt>DIRECTOR, SCIENTIFIC PGRM MGMT</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <KeyEmployeeInd>X</KeyEmployeeInd>
#         <ReportableCompFromOrgAmt>277856</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>39195</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>SONYA ZILKA</PersonNm>
#         <TitleTxt>VP OF HUMAN RESOURCE</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#         <ReportableCompFromOrgAmt>495945</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>29103</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>RAFAEL GOMEZ-SJOBERG</PersonNm>
#         <TitleTxt>DIRECTOR, BIOENGINEERING</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#         <ReportableCompFromOrgAmt>319515</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>32948</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>ANNETTE PARENT</PersonNm>
#         <TitleTxt>LEAD IP COUNSEL</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#         <ReportableCompFromOrgAmt>303845</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>24124</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>ASTRID HO</PersonNm>
#         <TitleTxt>CONTROLLER</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#         <ReportableCompFromOrgAmt>281234</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>45823</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <Form990PartVIISectionAGrp>
#         <PersonNm>JOSHUA E ELIAS-MERRIMAN</PersonNm>
#         <TitleTxt>PLATFORM LEADER</TitleTxt>
#         <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#         <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#         <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#         <ReportableCompFromOrgAmt>257518</ReportableCompFromOrgAmt>
#         <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#         <OtherCompensationAmt>29783</OtherCompensationAmt>
#       </Form990PartVIISectionAGrp>
#       <TotalReportableCompFromOrgAmt>6713137</TotalReportableCompFromOrgAmt>
#       <TotReportableCompRltdOrgAmt>0</TotReportableCompRltdOrgAmt>
#       <TotalOtherCompensationAmt>455858</TotalOtherCompensationAmt>
#       <IndivRcvdGreaterThan100KCnt>78</IndivRcvdGreaterThan100KCnt>
#       <FormerOfcrEmployeesListedInd>0</FormerOfcrEmployeesListedInd>
#       <TotalCompGreaterThan150KInd>1</TotalCompGreaterThan150KInd>
#       <CompensationFromOtherSrcsInd>0</CompensationFromOtherSrcsInd>
#       <ContractorCompensationGrp>
#         <ContractorName>
#           <BusinessName>
#             <BusinessNameLine1Txt>KDINFOTECH</BusinessNameLine1Txt>
#           </BusinessName>
#         </ContractorName>
#         <ContractorAddress>
#           <USAddress>
#             <AddressLine1Txt>95 S MARKET ST 220</AddressLine1Txt>
#             <CityNm>SAN FRANCISCO</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>95113</ZIPCd>
#           </USAddress>
#         </ContractorAddress>
#         <ServicesDesc>IT SERVICES</ServicesDesc>
#         <CompensationAmt>1009603</CompensationAmt>
#       </ContractorCompensationGrp>
#       <ContractorCompensationGrp>
#         <ContractorName>
#           <BusinessName>
#             <BusinessNameLine1Txt>KILPATRICK TOWNSEND</BusinessNameLine1Txt>
#           </BusinessName>
#         </ContractorName>
#         <ContractorAddress>
#           <USAddress>
#             <AddressLine1Txt>PO BOX 39000</AddressLine1Txt>
#             <CityNm>SAN FRANCISCO</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94139</ZIPCd>
#           </USAddress>
#         </ContractorAddress>
#         <ServicesDesc>LEGAL SERVICES</ServicesDesc>
#         <CompensationAmt>828649</CompensationAmt>
#       </ContractorCompensationGrp>
#       <ContractorCompensationGrp>
#         <ContractorName>
#           <BusinessName>
#             <BusinessNameLine1Txt>AEROTEK INC</BusinessNameLine1Txt>
#           </BusinessName>
#         </ContractorName>
#         <ContractorAddress>
#           <USAddress>
#             <AddressLine1Txt>7301 PARKWAY DRIVE</AddressLine1Txt>
#             <CityNm>HANOVER</CityNm>
#             <StateAbbreviationCd>MD</StateAbbreviationCd>
#             <ZIPCd>21076</ZIPCd>
#           </USAddress>
#         </ContractorAddress>
#         <ServicesDesc>TEMPORARY SERVICES</ServicesDesc>
#         <CompensationAmt>752089</CompensationAmt>
#       </ContractorCompensationGrp>
#       <ContractorCompensationGrp>
#         <ContractorName>
#           <BusinessName>
#             <BusinessNameLine1Txt>CATHERINE M LELYVELD DBA KML STRATEGIC</BusinessNameLine1Txt>
#           </BusinessName>
#         </ContractorName>
#         <ContractorAddress>
#           <USAddress>
#             <AddressLine1Txt>7981 LA JOLLA DRIVE</AddressLine1Txt>
#             <CityNm>LA JOLLA</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>92037</ZIPCd>
#           </USAddress>
#         </ContractorAddress>
#         <ServicesDesc>COMMUNICATION SERVICES</ServicesDesc>
#         <CompensationAmt>384261</CompensationAmt>
#       </ContractorCompensationGrp>
#       <ContractorCompensationGrp>
#         <ContractorName>
#           <BusinessName>
#             <BusinessNameLine1Txt>WILSON SONSINI GOODRICH &amp; ROSATI</BusinessNameLine1Txt>
#           </BusinessName>
#         </ContractorName>
#         <ContractorAddress>
#           <USAddress>
#             <AddressLine1Txt>650 PAGE MILL ROAD</AddressLine1Txt>
#             <CityNm>PALO ALTO</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>943041050</ZIPCd>
#           </USAddress>
#         </ContractorAddress>
#         <ServicesDesc>LEGAL SERVICES</ServicesDesc>
#         <CompensationAmt>334895</CompensationAmt>
#       </ContractorCompensationGrp>
#       <CntrctRcvdGreaterThan100KCnt>16</CntrctRcvdGreaterThan100KCnt>
#       <AllOtherContributionsAmt>12999993</AllOtherContributionsAmt>
#       <NoncashContributionsAmt>772518</NoncashContributionsAmt>
#       <TotalContributionsAmt>12999993</TotalContributionsAmt>
#       <ProgramServiceRevenueGrp>
#         <Desc>COLLABORATION PROGRAM &amp; LICENSE</Desc>
#         <BusinessCd>541700</BusinessCd>
#         <TotalRevenueColumnAmt>472759</TotalRevenueColumnAmt>
#         <RelatedOrExemptFuncIncomeAmt>472759</RelatedOrExemptFuncIncomeAmt>
#       </ProgramServiceRevenueGrp>
#       <TotalProgramServiceRevenueAmt>472759</TotalProgramServiceRevenueAmt>
#       <InvestmentIncomeGrp>
#         <TotalRevenueColumnAmt>317759</TotalRevenueColumnAmt>
#         <ExclusionAmt>317759</ExclusionAmt>
#       </InvestmentIncomeGrp>
#       <RoyaltiesRevenueGrp>
#         <TotalRevenueColumnAmt>229466</TotalRevenueColumnAmt>
#         <ExclusionAmt>229466</ExclusionAmt>
#       </RoyaltiesRevenueGrp>
#       <TotalRevenueGrp>
#         <TotalRevenueColumnAmt>14019977</TotalRevenueColumnAmt>
#         <RelatedOrExemptFuncIncomeAmt>472759</RelatedOrExemptFuncIncomeAmt>
#         <UnrelatedBusinessRevenueAmt>0</UnrelatedBusinessRevenueAmt>
#         <ExclusionAmt>547225</ExclusionAmt>
#       </TotalRevenueGrp>
#       <GrantsToDomesticOrgsGrp>
#         <TotalAmt>24709945</TotalAmt>
#         <ProgramServicesAmt>24709945</ProgramServicesAmt>
#       </GrantsToDomesticOrgsGrp>
#       <ForeignGrantsGrp>
#         <TotalAmt>60000</TotalAmt>
#         <ProgramServicesAmt>60000</ProgramServicesAmt>
#       </ForeignGrantsGrp>
#       <CompCurrentOfcrDirectorsGrp>
#         <TotalAmt>5055080</TotalAmt>
#         <ProgramServicesAmt>2810154</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>2244926</ManagementAndGeneralAmt>
#       </CompCurrentOfcrDirectorsGrp>
#       <OtherSalariesAndWagesGrp>
#         <TotalAmt>13073142</TotalAmt>
#         <ProgramServicesAmt>10606604</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>2466538</ManagementAndGeneralAmt>
#       </OtherSalariesAndWagesGrp>
#       <PensionPlanContributionsGrp>
#         <TotalAmt>720188</TotalAmt>
#         <ProgramServicesAmt>584309</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>135879</ManagementAndGeneralAmt>
#       </PensionPlanContributionsGrp>
#       <OtherEmployeeBenefitsGrp>
#         <TotalAmt>2019430</TotalAmt>
#         <ProgramServicesAmt>1751307</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>268123</ManagementAndGeneralAmt>
#       </OtherEmployeeBenefitsGrp>
#       <PayrollTaxesGrp>
#         <TotalAmt>1094529</TotalAmt>
#         <ProgramServicesAmt>810065</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>284464</ManagementAndGeneralAmt>
#       </PayrollTaxesGrp>
#       <FeesForServicesLegalGrp>
#         <TotalAmt>1816061</TotalAmt>
#         <ProgramServicesAmt>1457248</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>358813</ManagementAndGeneralAmt>
#       </FeesForServicesLegalGrp>
#       <FeesForServicesAccountingGrp>
#         <TotalAmt>111680</TotalAmt>
#         <ManagementAndGeneralAmt>111680</ManagementAndGeneralAmt>
#       </FeesForServicesAccountingGrp>
#       <FeesForServicesOtherGrp>
#         <TotalAmt>2882041</TotalAmt>
#         <ProgramServicesAmt>2104572</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>777469</ManagementAndGeneralAmt>
#       </FeesForServicesOtherGrp>
#       <AdvertisingGrp>
#         <TotalAmt>469485</TotalAmt>
#         <ProgramServicesAmt>18312</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>451173</ManagementAndGeneralAmt>
#       </AdvertisingGrp>
#       <OfficeExpensesGrp>
#         <TotalAmt>3227533</TotalAmt>
#         <ProgramServicesAmt>3087151</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>140382</ManagementAndGeneralAmt>
#       </OfficeExpensesGrp>
#       <InformationTechnologyGrp>
#         <TotalAmt>2066256</TotalAmt>
#         <ProgramServicesAmt>1817062</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>249194</ManagementAndGeneralAmt>
#       </InformationTechnologyGrp>
#       <OccupancyGrp>
#         <TotalAmt>6867588</TotalAmt>
#         <ProgramServicesAmt>6193518</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>674070</ManagementAndGeneralAmt>
#       </OccupancyGrp>
#       <TravelGrp>
#         <TotalAmt>80589</TotalAmt>
#         <ProgramServicesAmt>80236</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>353</ManagementAndGeneralAmt>
#       </TravelGrp>
#       <ConferencesMeetingsGrp>
#         <TotalAmt>22742</TotalAmt>
#         <ProgramServicesAmt>21113</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>1629</ManagementAndGeneralAmt>
#       </ConferencesMeetingsGrp>
#       <InterestGrp>
#         <TotalAmt>7943</TotalAmt>
#         <ProgramServicesAmt>7943</ProgramServicesAmt>
#       </InterestGrp>
#       <DepreciationDepletionGrp>
#         <TotalAmt>3684057</TotalAmt>
#         <ProgramServicesAmt>3589065</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>94992</ManagementAndGeneralAmt>
#       </DepreciationDepletionGrp>
#       <InsuranceGrp>
#         <TotalAmt>175945</TotalAmt>
#         <ProgramServicesAmt>67975</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>107970</ManagementAndGeneralAmt>
#       </InsuranceGrp>
#       <OtherExpensesGrp>
#         <Desc>LAB SUPPLIES</Desc>
#         <TotalAmt>8396799</TotalAmt>
#         <ProgramServicesAmt>8396799</ProgramServicesAmt>
#       </OtherExpensesGrp>
#       <OtherExpensesGrp>
#         <Desc>MEALS &amp; ENTERTAINMENT</Desc>
#         <TotalAmt>768627</TotalAmt>
#         <ProgramServicesAmt>723744</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>44883</ManagementAndGeneralAmt>
#       </OtherExpensesGrp>
#       <OtherExpensesGrp>
#         <Desc>ALL OTHER EXP</Desc>
#         <TotalAmt>39100</TotalAmt>
#         <ProgramServicesAmt>39100</ProgramServicesAmt>
#       </OtherExpensesGrp>
#       <OtherExpensesGrp>
#         <Desc>BUSINESS &amp; INCOME TAXES</Desc>
#         <TotalAmt>7322</TotalAmt>
#         <ProgramServicesAmt>7093</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>229</ManagementAndGeneralAmt>
#       </OtherExpensesGrp>
#       <AllOtherExpensesGrp>
#         <TotalAmt>1425</TotalAmt>
#         <ProgramServicesAmt>1081</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>344</ManagementAndGeneralAmt>
#       </AllOtherExpensesGrp>
#       <TotalFunctionalExpensesGrp>
#         <TotalAmt>77357507</TotalAmt>
#         <ProgramServicesAmt>68944396</ProgramServicesAmt>
#         <ManagementAndGeneralAmt>8413111</ManagementAndGeneralAmt>
#         <FundraisingAmt>0</FundraisingAmt>
#       </TotalFunctionalExpensesGrp>
#       <CashNonInterestBearingGrp>
#         <BOYAmt>7662391</BOYAmt>
#         <EOYAmt>4539723</EOYAmt>
#       </CashNonInterestBearingGrp>
#       <SavingsAndTempCashInvstGrp>
#         <BOYAmt>91233639</BOYAmt>
#         <EOYAmt>87950358</EOYAmt>
#       </SavingsAndTempCashInvstGrp>
#       <PledgesAndGrantsReceivableGrp>
#         <BOYAmt>353225605</BOYAmt>
#         <EOYAmt>296523989</EOYAmt>
#       </PledgesAndGrantsReceivableGrp>
#       <AccountsReceivableGrp>
#         <BOYAmt>423174</BOYAmt>
#         <EOYAmt>946696</EOYAmt>
#       </AccountsReceivableGrp>
#       <PrepaidExpensesDefrdChargesGrp>
#         <BOYAmt>1015036</BOYAmt>
#         <EOYAmt>1541870</EOYAmt>
#       </PrepaidExpensesDefrdChargesGrp>
#       <LandBldgEquipCostOrOtherBssAmt>18694280</LandBldgEquipCostOrOtherBssAmt>
#       <LandBldgEquipAccumDeprecAmt>9004741</LandBldgEquipAccumDeprecAmt>
#       <LandBldgEquipBasisNetGrp>
#         <BOYAmt>11711016</BOYAmt>
#         <EOYAmt>9689539</EOYAmt>
#       </LandBldgEquipBasisNetGrp>
#       <InvestmentsProgramRelatedGrp>
#         <BOYAmt>641875</BOYAmt>
#         <EOYAmt>904922</EOYAmt>
#       </InvestmentsProgramRelatedGrp>
#       <OtherAssetsTotalGrp>
#         <BOYAmt>2302083</BOYAmt>
#         <EOYAmt>1977084</EOYAmt>
#       </OtherAssetsTotalGrp>
#       <TotalAssetsGrp>
#         <BOYAmt>468214819</BOYAmt>
#         <EOYAmt>404074181</EOYAmt>
#       </TotalAssetsGrp>
#       <AccountsPayableAccrExpnssGrp>
#         <BOYAmt>3858373</BOYAmt>
#         <EOYAmt>3618027</EOYAmt>
#       </AccountsPayableAccrExpnssGrp>
#       <GrantsPayableGrp>
#         <BOYAmt>10114964</BOYAmt>
#         <EOYAmt>9552202</EOYAmt>
#       </GrantsPayableGrp>
#       <TotalLiabilitiesGrp>
#         <BOYAmt>13973337</BOYAmt>
#         <EOYAmt>13170229</EOYAmt>
#       </TotalLiabilitiesGrp>
#       <OrganizationFollowsFASB117Ind>X</OrganizationFollowsFASB117Ind>
#       <NoDonorRestrictionNetAssetsGrp>
#         <BOYAmt>97464133</BOYAmt>
#         <EOYAmt>90641865</EOYAmt>
#       </NoDonorRestrictionNetAssetsGrp>
#       <DonorRestrictionNetAssetsGrp>
#         <BOYAmt>356777349</BOYAmt>
#         <EOYAmt>300262087</EOYAmt>
#       </DonorRestrictionNetAssetsGrp>
#       <TotalNetAssetsFundBalanceGrp>
#         <BOYAmt>454241482</BOYAmt>
#         <EOYAmt>390903952</EOYAmt>
#       </TotalNetAssetsFundBalanceGrp>
#       <TotLiabNetAssetsFundBalanceGrp>
#         <BOYAmt>468214819</BOYAmt>
#         <EOYAmt>404074181</EOYAmt>
#       </TotLiabNetAssetsFundBalanceGrp>
#       <ReconcilationRevenueExpnssAmt>-63337530</ReconcilationRevenueExpnssAmt>
#       <OtherChangesInNetAssetsAmt>0</OtherChangesInNetAssetsAmt>
#       <MethodOfAccountingAccrualInd>X</MethodOfAccountingAccrualInd>
#       <AccountantCompileOrReviewInd>0</AccountantCompileOrReviewInd>
#       <FSAuditedInd>1</FSAuditedInd>
#       <FSAuditedBasisGrp>
#         <SeparateBasisFinclStmtInd>X</SeparateBasisFinclStmtInd>
#       </FSAuditedBasisGrp>
#       <AuditCommitteeInd>1</AuditCommitteeInd>
#       <FederalGrantAuditRequiredInd>0</FederalGrantAuditRequiredInd>
#     </IRS990>
#     <IRS990ScheduleA documentId="RetDoc1039100001">
#       <MedicalResearchOrganizationInd>X</MedicalResearchOrganizationInd>
#       <HospitalNameAndAddressGrp>
#         <SupportedOrganizationName>
#           <BusinessNameLine1Txt>AFFILIATED HOSPITALS OF STANFORD</BusinessNameLine1Txt>
#         </SupportedOrganizationName>
#         <CityNm>STANFORD</CityNm>
#         <StateAbbreviationCd>CA</StateAbbreviationCd>
#       </HospitalNameAndAddressGrp>
#       <HospitalNameAndAddressGrp>
#         <SupportedOrganizationName>
#           <BusinessNameLine1Txt>AFFILIATED HOSPITALS OF UCSF</BusinessNameLine1Txt>
#         </SupportedOrganizationName>
#         <CityNm>SAN FRANCISCO</CityNm>
#         <StateAbbreviationCd>CA</StateAbbreviationCd>
#       </HospitalNameAndAddressGrp>
#     </IRS990ScheduleA>
#     <IRS990ScheduleB documentId="RetDoc1234500001">
#       <ContributorInformationGrp>
#         <ContributorNum>RESTRICTED</ContributorNum>
#         <ContributorBusinessName>
#           <BusinessNameLine1>RESTRICTED</BusinessNameLine1>
#         </ContributorBusinessName>
#         <ContributorUSAddress>
#           <AddressLine1>RESTRICTED</AddressLine1>
#           <AddressLine2>RESTRICTED</AddressLine2>
#           <City>RESTRICTED</City>
#           <State>RESTRICTED</State>
#           <ZIPCode>RESTRICTED</ZIPCode>
#         </ContributorUSAddress>
#         <TotalContributionsAmt>RESTRICTED</TotalContributionsAmt>
#       </ContributorInformationGrp>
#     </IRS990ScheduleB>
#     <IRS990ScheduleD documentId="RetDoc1040000001">
#       <LeaseholdImprovementsGrp>
#         <OtherCostOrOtherBasisAmt>328114</OtherCostOrOtherBasisAmt>
#         <DepreciationAmt>104513</DepreciationAmt>
#         <BookValueAmt>223601</BookValueAmt>
#       </LeaseholdImprovementsGrp>
#       <EquipmentGrp>
#         <OtherCostOrOtherBasisAmt>18366166</OtherCostOrOtherBasisAmt>
#         <DepreciationAmt>8900228</DepreciationAmt>
#         <BookValueAmt>9465938</BookValueAmt>
#       </EquipmentGrp>
#       <TotalBookValueLandBuildingsAmt>9689539</TotalBookValueLandBuildingsAmt>
#       <FootnoteTextInd>X</FootnoteTextInd>
#       <TotalRevEtcAuditedFinclStmtAmt>14019977</TotalRevEtcAuditedFinclStmtAmt>
#       <RevenueNotReportedAmt>0</RevenueNotReportedAmt>
#       <RevenueSubtotalAmt>14019977</RevenueSubtotalAmt>
#       <RevenueNotReportedFinclStmtAmt>0</RevenueNotReportedFinclStmtAmt>
#       <TotalRevenuePerForm990Amt>14019977</TotalRevenuePerForm990Amt>
#       <TotExpnsEtcAuditedFinclStmtAmt>77357507</TotExpnsEtcAuditedFinclStmtAmt>
#       <ExpensesNotReportedAmt>0</ExpensesNotReportedAmt>
#       <ExpensesSubtotalAmt>77357507</ExpensesSubtotalAmt>
#       <ExpensesNotRptFinclStmtAmt>0</ExpensesNotRptFinclStmtAmt>
#       <TotalExpensesPerForm990Amt>77357507</TotalExpensesPerForm990Amt>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>PART X, LINE 2:</FormAndLineReferenceDesc>
#         <ExplanationTxt>THE BIOHUB IS EXEMPT FROM INCOME TAXES UNDER SECTION 501(C)(3) OF THE INTERNAL REVENUE CODE AS A MEDICAL RESEARCH ORGANIZATION OPERATED IN CONJUNCTION WITH A HOSPITAL AND SECTION 23701D OF THE CALIFORNIA REVENUE AND TAXATION CODE. THE BIOHUB HAS NO UNRECOGNIZED TAX BENEFITS OR LIABILITIES AS OF DECEMBER 31, 2020.</ExplanationTxt>
#       </SupplementalInformationDetail>
#     </IRS990ScheduleD>
#     <IRS990ScheduleF documentId="RetDoc1040500001">
#       <GrantRecordsMaintainedInd>1</GrantRecordsMaintainedInd>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>EUROPE (INCLUDING ICELAND &amp; GREENLAND)</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>PROGRAM SERVICES</TypeOfActivitiesConductedTxt>
#         <SpecificServicesProvidedTxt>ATTENDING AND SPEAKING AT CONFERENCE</SpecificServicesProvidedTxt>
#         <RegionTotalExpendituresAmt>5710</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>EAST ASIA AND THE PACIFIC</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>PROGRAM SERVICES</TypeOfActivitiesConductedTxt>
#         <SpecificServicesProvidedTxt>ATTENDING AND SPEAKING AT CONFERENCE</SpecificServicesProvidedTxt>
#         <RegionTotalExpendituresAmt>199</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>SOUTH ASIA</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>PROGRAM SERVICES</TypeOfActivitiesConductedTxt>
#         <SpecificServicesProvidedTxt>ATTENDING AND SPEAKING AT CONFERENCE</SpecificServicesProvidedTxt>
#         <RegionTotalExpendituresAmt>540</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>SUB-SAHARAN AFRICA</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>PROGRAM SERVICES</TypeOfActivitiesConductedTxt>
#         <SpecificServicesProvidedTxt>ATTENDING AND SPEAKING AT CONFERENCE</SpecificServicesProvidedTxt>
#         <RegionTotalExpendituresAmt>387</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>EUROPE (INCLUDING ICELAND &amp; GREENLAND)</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>PROGRAM SERVICES</TypeOfActivitiesConductedTxt>
#         <SpecificServicesProvidedTxt>CONSULTING SERVICES</SpecificServicesProvidedTxt>
#         <RegionTotalExpendituresAmt>37120</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>EAST ASIA AND THE PACIFIC</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>GRANT-MAKING</TypeOfActivitiesConductedTxt>
#         <RegionTotalExpendituresAmt>20000</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>SOUTH ASIA</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>GRANT-MAKING</TypeOfActivitiesConductedTxt>
#         <RegionTotalExpendituresAmt>20000</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <AccountActivitiesOutsideUSGrp>
#         <RegionTxt>SUB-SAHARAN AFRICA</RegionTxt>
#         <OfficesCnt>0</OfficesCnt>
#         <EmployeeCnt>0</EmployeeCnt>
#         <TypeOfActivitiesConductedTxt>GRANT-MAKING</TypeOfActivitiesConductedTxt>
#         <RegionTotalExpendituresAmt>20000</RegionTotalExpendituresAmt>
#       </AccountActivitiesOutsideUSGrp>
#       <SubtotalOfficesCnt>0</SubtotalOfficesCnt>
#       <SubtotalEmployeesCnt>0</SubtotalEmployeesCnt>
#       <ContinuationTotalOfficeCnt>0</ContinuationTotalOfficeCnt>
#       <ContinuationTotalEmployeeCnt>0</ContinuationTotalEmployeeCnt>
#       <TotalOfficeCnt>0</TotalOfficeCnt>
#       <TotalEmployeeCnt>0</TotalEmployeeCnt>
#       <SubtotalSpentAmt>103956</SubtotalSpentAmt>
#       <ContinuationSpentAmt>0</ContinuationSpentAmt>
#       <TotalSpentAmt>103956</TotalSpentAmt>
#       <GrantsToOrgOutsideUSGrp>
#         <RegionTxt>SOUTH ASIA</RegionTxt>
#         <PurposeOfGrantTxt>COVID-19 SUPPORT</PurposeOfGrantTxt>
#         <CashGrantAmt>20000</CashGrantAmt>
#         <MannerOfCashDisbursementTxt>ELECTRONIC FUND/WIRE TRANSFER</MannerOfCashDisbursementTxt>
#       </GrantsToOrgOutsideUSGrp>
#       <GrantsToOrgOutsideUSGrp>
#         <RegionTxt>EAST ASIA AND THE PACIFIC</RegionTxt>
#         <PurposeOfGrantTxt>COVID-19 SUPPORT</PurposeOfGrantTxt>
#         <CashGrantAmt>20000</CashGrantAmt>
#         <MannerOfCashDisbursementTxt>ELECTRONIC FUND/WIRE TRANSFER</MannerOfCashDisbursementTxt>
#       </GrantsToOrgOutsideUSGrp>
#       <GrantsToOrgOutsideUSGrp>
#         <RegionTxt>SUB-SAHARAN AFRICA</RegionTxt>
#         <PurposeOfGrantTxt>COVID-19 SUPPORT</PurposeOfGrantTxt>
#         <CashGrantAmt>20000</CashGrantAmt>
#         <MannerOfCashDisbursementTxt>ELECTRONIC FUND/WIRE TRANSFER</MannerOfCashDisbursementTxt>
#       </GrantsToOrgOutsideUSGrp>
#       <TotalOtherOrgCnt>3</TotalOtherOrgCnt>
#       <TransferToForeignCorpInd>0</TransferToForeignCorpInd>
#       <InterestInForeignTrustInd>0</InterestInForeignTrustInd>
#       <ForeignCorpOwnershipInd>0</ForeignCorpOwnershipInd>
#       <PassiveForeignInvestmestCoInd>0</PassiveForeignInvestmestCoInd>
#       <ForeignPartnershipInd>0</ForeignPartnershipInd>
#       <BoycottCountriesInd>0</BoycottCountriesInd>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>PART I, LINE 2:</FormAndLineReferenceDesc>
#         <ExplanationTxt>THE GRANTS STIPULATED THE PURPOSE OF THE FUNDS TO THE RECIPIENT IN A GRANT LETTER AND WHAT THE FUNDS SHOULD BE USED FOR AND THE ORGANIZATION OBTAINED ACTUAL RECEIPTS FOR THE GRANTS PROVIDED TO VALIDATE THE FUNDING WAS USED FOR THE PURPOSE INTENDED</ExplanationTxt>
#       </SupplementalInformationDetail>
# ...
#       </SupplementalInformationDetail>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>FORM 990, PART VI, SECTION B, LINE 11B</FormAndLineReferenceDesc>
#         <ExplanationTxt>THE FORM 990 IS PREPARED BY OUR TAX CONSULTANTS. THE DRAFT IS REVIEWED BY THE CFO OF THE ORGANIZATION. THE FORM 990 IS THEN MADE AVAILABLE TO THE BOARD PRIOR TO THE 990 BEING FILED.</ExplanationTxt>
#       </SupplementalInformationDetail>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>FORM 990, PART VI, SECTION B, LINE 12C</FormAndLineReferenceDesc>
#         <ExplanationTxt>EACH COVERED PERSON MUST DISCLOSE IN WRITING TO THE CHIEF CONFLICTS OFFICER EACH OF HIS OR HER CONFLICTS OF INTEREST, INCLUDING FINANCIAL INTERESTS, WHEN THEY JOIN THE COMPANY. TO ENSURE THAT POTENTIAL CONFLICTS OF INTEREST AND CONFLICTS OF COMMITMENT ARE DISCLOSED, EACH COVERED PERSON IS REQUIRED TO UPDATE THEIR DISCLOSURE PERIODICALLY THROUGHOUT THE YEAR AT ANY TIME WHEN HIS OR HER PREVIOUSLY DISCLOSED FINANCIAL INTERESTS CHANGE OR A NEW POTENTIAL CONFLICT OF COMMITMENT OR CONFLICT OF INTEREST ARISES. IN ADDITION, CERTAIN EMPLOYEES AT THE LEVEL OF GROUP OR PLATFORM LEADER OR ABOVE ARE REQUIRED TO FILE UPDATED DISCLOSURE STATEMENTS EACH YEAR. THE BOARD OF DIRECTORS APPROVED THE CONFLICT OF COMMITMENT AND CONFLICT OF INTEREST POLICY FOR THE BIOHUB, WHICH OUTLINES THE MECHANISMS FOR IMPLEMENTING THE POLICY. THE CHIEF CONFLICTS OFFICER OR IN SOME INSTANCES, THE BOARD OF DIRECTORS OR A COMMITTEE DESIGNATED BY THE BOARD IS RESPONSIBLE FOR INTERPRETING BOTH CONFLICTS OF COMMITMENT AND CONFLICTS OF INTEREST UNDER THE POLICY. THE CHIEF CONFLICTS OFFICER'S PRIMARY RESPONSIBILITY IS DETERMINING WHETHER A CONFLICT OF COMMITMENT OR CONFLICT OF INTEREST EXISTS AND, IF SO, WHETHER THE PROPOSED ACTIVITY OR THE TRANSACTION OR ARRANGEMENT GIVING RISE TO THE CONFLICT IS IN THE BEST INTERESTS OF THE BIOHUB AND CAN PROCEED IN A MANNER THAT PROTECTS THE BIOHUB'S FINANCIAL, SCIENTIFIC, AND REPUTATIONAL INTERESTS. WHEN A COVERED PERSON DISCLOSES AN ACTUAL OR POTENTIAL CONFLICT OF COMMITMENT OR CONFLICT OF INTEREST UNDER THIS POLICY, THE CHIEF CONFLICTS OFFICER WILL FOLLOW THE REVIEW PROCEDURES OUTLINED IN THE POLICY. A COVERED PERSON MAY NOT ENGAGE IN ANY ACTIVITY THAT GIVES RISE TO A CONFLICT OF COMMITMENT OR A CONFLICT OF INTEREST WITHOUT RECEIVING THE APPROVAL(S) REQUIRED IN THIS POLICY. WITH RESPECT TO ANY CONFLICT OF INTEREST, THE COVERED PERSON WILL BE RECUSED FROM ALL DECISIONS INVOLVING THE ACTIVITY GIVING RISE TO THE CONFLICT, AND THE CHIEF CONFLICTS OFFICER, THE BOARD OF DIRECTORS, OR A COMMITTEE DESIGNED BY THE BOARD WILL DETERMINE WHETHER TO PROCEED WITH THE ACTIVITY NOTWITHSTANDING THE CONFLICT. IF THE COVERED PERSON INVOLVED IN THE POTENTIAL OR ACTUAL CONFLICT UNDER REVIEW IS AN OFFICER OF THE BIOHUB, THE CONFLICT REVIEW PROCEDURES WILL BE PERFORMED BY THE BOARD OF DIRECTORS OR A COMMITTEE DESIGNATED BY THE BOARD, ASSISTED BY THE CHIEF CONFLICTS OFFICERAND, IF REQUESTED BY THE BOARD OR COMMITTEE, OUTSIDE COUNSEL.</ExplanationTxt>
#       </SupplementalInformationDetail>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>FORM 990, PART VI, SECTION B, LINE 15A</FormAndLineReferenceDesc>
#         <ExplanationTxt>THE BOARD OF DIRECTORS AND EXECUTIVE COMMITTEE OF THE BOARD REVIEW AND APPROVE THE COMPENSATION OF THE ORGANIZATION'S CO-PRESIDENTS. THE PROCESS INCLUDES A REVIEW OF THE COMPENSATION AGAINST COMPARABILITY DATA SURVEY PROVIDED PERIODICALLY BY AN INDEPENDENT COMPENSATION SERVICE. THE APPROVAL PROCESS IS DOCUMENTED CONTEMPORANEOUSLY. THE MOST RECENT COMPARABILITY DATA STUDY WAS COMPLETED IN 2018 AND WAS USED TO SET 2019 AND 2020 COMPENSATION.</ExplanationTxt>
#       </SupplementalInformationDetail>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>FORM 990, PART VI, SECTION C, LINE 19</FormAndLineReferenceDesc>
#         <ExplanationTxt>UPON REQUEST, DOCUMENTS THAT ARE REQUIRED BY LAW TO BE AVAILABLE FOR PUBLIC INSPECTION WILL BE MADE AVAILABLE.</ExplanationTxt>
#       </SupplementalInformationDetail>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>FORM 990, PART VI, SECTION B, LINE 16B</FormAndLineReferenceDesc>
#         <ExplanationTxt>BIOHUB HAS EXECUTED CERTAIN WRITTEN COLLABORATION AGREEMENTS IN FURTHERANCE OF ITS EXEMPT MISSION. SUCH CONTRACTS ARE EXECUTED ON TERMS THAT ARE AT ARM'S LENGTH OR MORE FAVORABLE TO BIOHUB.</ExplanationTxt>
#       </SupplementalInformationDetail>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>PART VII, SECTION A</FormAndLineReferenceDesc>
#         <ExplanationTxt>WHERE 40 HOURS IS LISTED AS HOURS OF SERVICE IN RESPECT OF AN INDIVIDUAL, THIS IS BASED ON AN ESTIMATED FULL-TIME WORK WEEK. ACTUAL HOURS DEVOTED BY THE INDIVIDUAL MAY VARY SIGNIFICANTLY, AND MAY EXCEED THE 40 HOUR ESTIMATE.</ExplanationTxt>
#       </SupplementalInformationDetail>
#     </IRS990ScheduleO>
#     <IRS990ScheduleR documentId="RetDoc1043400001">
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>CHAN ZUCKERBERG INITIATIVE ADVOCACY</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>314 LYTTON AVENUE SUITE 200</AddressLine1Txt>
#           <CityNm>PALO ALTO</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94301</ZIPCd>
#         </USAddress>
#         <EIN>813742328</EIN>
#         <PrimaryActivitiesTxt>SOCIAL WELFARE</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>CA</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(4)</ExemptCodeSectionTxt>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>CHAN ZUCKERBERG INITIATIVE FOUNDATION</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>314 LYTTON AVENUE SUITE 200</AddressLine1Txt>
#           <CityNm>PALO ALTO</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94301</ZIPCd>
#         </USAddress>
#         <EIN>455002209</EIN>
#         <PrimaryActivitiesTxt>GRANTMAKING</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>CA</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(3)</ExemptCodeSectionTxt>
#         <PublicCharityStatusTxt>PF</PublicCharityStatusTxt>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>THE PRIMARY SCHOOL LAB</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>1765 E BAYSHORE RD SUITE A2</AddressLine1Txt>
#           <CityNm>E PALO ALTO</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94303</ZIPCd>
#         </USAddress>
#         <EIN>364858582</EIN>
#         <PrimaryActivitiesTxt>SOCIAL WELFARE</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>CA</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(4)</ExemptCodeSectionTxt>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>THE PRIMARY SCHOOL - EAST PALO ALTO</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>2086 CLARKE STREET</AddressLine1Txt>
#           <CityNm>E PALO ALTO</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94303</ZIPCd>
#         </USAddress>
#         <EIN>473334579</EIN>
#         <PrimaryActivitiesTxt>EDUCATION</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>CA</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(3)</ExemptCodeSectionTxt>
#         <PublicCharityStatusTxt>LINE 2</PublicCharityStatusTxt>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>OPENNESS FOUNDATION</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>314 LYTTON AVENUE SUITE 200</AddressLine1Txt>
#           <CityNm>PALO ALTO</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94301</ZIPCd>
#         </USAddress>
#         <EIN>270889149</EIN>
#         <PrimaryActivitiesTxt>GRANTMAKING</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>CA</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(3)</ExemptCodeSectionTxt>
#         <PublicCharityStatusTxt>PF</PublicCharityStatusTxt>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>GRADIENT LEARNING</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>340 S LEMON AVE 6119</AddressLine1Txt>
#           <CityNm>WALNUT</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>91789</ZIPCd>
#         </USAddress>
#         <EIN>352645251</EIN>
#         <PrimaryActivitiesTxt>EDUCATION</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>CA</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(3)</ExemptCodeSectionTxt>
#         <PublicCharityStatusTxt>LINE 7</PublicCharityStatusTxt>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>FWDUS EDUCATION FUND INC</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>PO BOX 34506</AddressLine1Txt>
#           <CityNm>WASHINGTON DC</CityNm>
#           <StateAbbreviationCd>DE</StateAbbreviationCd>
#           <ZIPCd>20043</ZIPCd>
#         </USAddress>
#         <EIN>820962378</EIN>
#         <PrimaryActivitiesTxt>EDUCATE THE PUBLIC ABOUT IMMIGRATION AND CRIMINAL JUSTICE POLICY AND REFORM</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>DE</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(3)</ExemptCodeSectionTxt>
#         <PublicCharityStatusTxt>LINE 7</PublicCharityStatusTxt>
#         <DirectControllingEntityName>
#           <BusinessNameLine1Txt>FWDUS INC</BusinessNameLine1Txt>
#         </DirectControllingEntityName>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedTaxExemptOrgGrp>
#         <DisregardedEntityName>
#           <BusinessNameLine1Txt>FWDUS INC</BusinessNameLine1Txt>
#         </DisregardedEntityName>
#         <USAddress>
#           <AddressLine1Txt>PO BOX 34506</AddressLine1Txt>
#           <CityNm>WASHINGTON DC</CityNm>
#           <StateAbbreviationCd>DE</StateAbbreviationCd>
#           <ZIPCd>20043</ZIPCd>
#         </USAddress>
#         <EIN>462223015</EIN>
#         <PrimaryActivitiesTxt>ADVOCATE FOR IMMIGRATION AND CRIMINAL JUSTICE REFORM</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>DE</LegalDomicileStateCd>
#         <ExemptCodeSectionTxt>501(C)(4)</ExemptCodeSectionTxt>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedTaxExemptOrgGrp>
#       <IdRelatedOrgTxblCorpTrGrp>
#         <RelatedOrganizationName>
#           <BusinessNameLine1Txt>FACEBOOK INC</BusinessNameLine1Txt>
#         </RelatedOrganizationName>
#         <USAddress>
#           <AddressLine1Txt>1601 WILLOW ROAD</AddressLine1Txt>
#           <CityNm>MENLO PARK</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94025</ZIPCd>
#         </USAddress>
#         <EIN>201665019</EIN>
#         <PrimaryActivitiesTxt>SOCIAL MEDIA SERVICE COMPANY</PrimaryActivitiesTxt>
#         <LegalDomicileStateCd>DE</LegalDomicileStateCd>
#         <DirectControllingNACd>N/A</DirectControllingNACd>
#         <EntityTypeTxt>C</EntityTypeTxt>
#         <ControlledOrganizationInd>0</ControlledOrganizationInd>
#       </IdRelatedOrgTxblCorpTrGrp>
#       <ReceiptOfIntAnntsRntsRyltsInd>0</ReceiptOfIntAnntsRntsRyltsInd>
#       <GiftGrntOrCapContriToOthOrgInd>0</GiftGrntOrCapContriToOthOrgInd>
#       <GiftGrntCapContriFromOthOrgInd>0</GiftGrntCapContriFromOthOrgInd>
#       <LoansOrGuaranteesToOtherOrgInd>0</LoansOrGuaranteesToOtherOrgInd>
#       <LoansOrGuaranteesFromOthOrgInd>0</LoansOrGuaranteesFromOthOrgInd>
#       <DivRelatedOrganizationInd>0</DivRelatedOrganizationInd>
#       <AssetSaleToOtherOrgInd>0</AssetSaleToOtherOrgInd>
#       <AssetPurchaseFromOtherOrgInd>0</AssetPurchaseFromOtherOrgInd>
#       <AssetExchangeInd>0</AssetExchangeInd>
#       <RentalOfFacilitiesToOthOrgInd>0</RentalOfFacilitiesToOthOrgInd>
#       <RentalOfFcltsFromOthOrgInd>0</RentalOfFcltsFromOthOrgInd>
#       <PerformOfServicesForOthOrgInd>0</PerformOfServicesForOthOrgInd>
#       <PerformOfServicesByOtherOrgInd>0</PerformOfServicesByOtherOrgInd>
#       <SharingOfFacilitiesInd>0</SharingOfFacilitiesInd>
#       <PaidEmployeesSharingInd>0</PaidEmployeesSharingInd>
#       <ReimbursementPaidToOtherOrgInd>0</ReimbursementPaidToOtherOrgInd>
#       <ReimbursementPaidByOtherOrgInd>0</ReimbursementPaidByOtherOrgInd>
#       <TransferToOtherOrgInd>0</TransferToOtherOrgInd>
#       <TransferFromOtherOrgInd>0</TransferFromOtherOrgInd>
#       <SupplementalInformationDetail>
#         <FormAndLineReferenceDesc>FORM 990, SCHEDULE R, PART II AND PART IV</FormAndLineReferenceDesc>
#         <ExplanationTxt>ONE OF THE MANAGERS OF CHAN ZUCKERBERG INITIATIVE, LLC ("CZI") ALSO HAS A CONTROLLING INTEREST IN SEVERAL PASSIVE INVESTMENT VEHICLES. THESE INVESTMENT VEHICLES, THE TAX-EXEMPT ENTITIES DISCLOSED UNDER PART II ABOVE, AND FACEBOOK AS DISCLOSED UNDER PART IV ABOVE, MAY TECHNICALLY BE CONSIDERED "RELATED ORGANIZATIONS" OF THE BIOHUB FOR IRS FORM 990 REPORTING PURPOSES THROUGH THEIR RELATIONSHIP WITH ONE OF CZI'S MANAGERS, GIVEN CZI'S RELATIONSHIP WITH THE BIOHUB. EACH OF THESE DISCLOSED ENTITIES IS OTHERWISE UNAFFILIATED WITH AND DOES NOT CONTROL THE BIOHUB, AND THE BIOHUB'S DATA IS NOT SOLD OR SHARED WITH FACEBOOK, THE PASSIVE INVESTMENT VEHICLES, OR ANY OF THE DISCLOSED TAX-EXEMPT ENTITIES.</ExplanationTxt>
#       </SupplementalInformationDetail>
#     </IRS990ScheduleR>
#   </ReturnData>
# </Return>

# %%
from bs4 import BeautifulSoup

# %%
zuck_data = BeautifulSoup(zuck_xml, "xml")
type(zuck_data)
# Out:
# bs4.BeautifulSoup

# %%
zuck_officer_data = zuck_data.select("Form990PartVIISectionAGrp")
zuck_officer_data
# Out:
# [<Form990PartVIISectionAGrp>
#  <PersonNm>JOSEPH DERISI</PersonNm>
#  <TitleTxt>CO-PRESIDENT</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#  <OfficerInd>X</OfficerInd>
#  <ReportableCompFromOrgAmt>909234</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>35540</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>STEVE QUAKE</PersonNm>
#  <TitleTxt>CO-PRESIDENT</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#  <OfficerInd>X</OfficerInd>
#  <ReportableCompFromOrgAmt>909234</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>35540</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>CORI BARGMANN</PersonNm>
#  <TitleTxt>DIRECTOR</TitleTxt>
#  <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#  <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>0</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>JOHN HENNESSY</PersonNm>
#  <TitleTxt>DIRECTOR</TitleTxt>
#  <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#  <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>0</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>PRISCILLA CHAN</PersonNm>
#  <TitleTxt>DIRECTOR</TitleTxt>
#  <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>3.50</AverageHoursPerWeekRltdOrgRt>
#  <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#  <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>0</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>REID HOFFMAN</PersonNm>
#  <TitleTxt>DIRECTOR</TitleTxt>
#  <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#  <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>0</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>MARK ZUCKERBERG</PersonNm>
#  <TitleTxt>DIRECTOR</TitleTxt>
#  <AverageHoursPerWeekRt>2.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>41.50</AverageHoursPerWeekRltdOrgRt>
#  <IndividualTrusteeOrDirectorInd>X</IndividualTrusteeOrDirectorInd>
#  <ReportableCompFromOrgAmt>0</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>0</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>GAJUS WORTHINGTON</PersonNm>
#  <TitleTxt>CHIEF OPERATING OFFICER</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <OfficerInd>X</OfficerInd>
#  <ReportableCompFromOrgAmt>741684</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>45961</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>VICTOR COLUNGA</PersonNm>
#  <TitleTxt>CFO &amp; TREASURER</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <OfficerInd>X</OfficerInd>
#  <ReportableCompFromOrgAmt>713940</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>44170</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>MAUREEN SHEEHY</PersonNm>
#  <TitleTxt>SECRETARY AND LEGAL COUNSEL</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <OfficerInd>X</OfficerInd>
#  <ReportableCompFromOrgAmt>607455</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>43513</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>JIM KARKANIAS</PersonNm>
#  <TitleTxt>VP, DATA SCIENCES &amp; IT INF</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <KeyEmployeeInd>X</KeyEmployeeInd>
#  <ReportableCompFromOrgAmt>510736</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>36565</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>SANDRA L SCHMID START 6120</PersonNm>
#  <TitleTxt>CHIEF SCIENTIFIC OFFICER</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <KeyEmployeeInd>X</KeyEmployeeInd>
#  <ReportableCompFromOrgAmt>384941</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>13593</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>WILLIAM BURKHOLDER</PersonNm>
#  <TitleTxt>DIRECTOR, SCIENTIFIC PGRM MGMT</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <KeyEmployeeInd>X</KeyEmployeeInd>
#  <ReportableCompFromOrgAmt>277856</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>39195</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>SONYA ZILKA</PersonNm>
#  <TitleTxt>VP OF HUMAN RESOURCE</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#  <ReportableCompFromOrgAmt>495945</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>29103</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>RAFAEL GOMEZ-SJOBERG</PersonNm>
#  <TitleTxt>DIRECTOR, BIOENGINEERING</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#  <ReportableCompFromOrgAmt>319515</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>32948</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>ANNETTE PARENT</PersonNm>
#  <TitleTxt>LEAD IP COUNSEL</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#  <ReportableCompFromOrgAmt>303845</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>24124</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>ASTRID HO</PersonNm>
#  <TitleTxt>CONTROLLER</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#  <ReportableCompFromOrgAmt>281234</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>45823</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>,
#  <Form990PartVIISectionAGrp>
#  <PersonNm>JOSHUA E ELIAS-MERRIMAN</PersonNm>
#  <TitleTxt>PLATFORM LEADER</TitleTxt>
#  <AverageHoursPerWeekRt>40.00</AverageHoursPerWeekRt>
#  <AverageHoursPerWeekRltdOrgRt>0.00</AverageHoursPerWeekRltdOrgRt>
#  <HighestCompensatedEmployeeInd>X</HighestCompensatedEmployeeInd>
#  <ReportableCompFromOrgAmt>257518</ReportableCompFromOrgAmt>
#  <ReportableCompFromRltdOrgAmt>0</ReportableCompFromRltdOrgAmt>
#  <OtherCompensationAmt>29783</OtherCompensationAmt>
#  </Form990PartVIISectionAGrp>]

# %%
import pandas as pd

# %%
officer_list = []

for officer in zuck_officer_data:
    officer_dict = {}
    name = officer.find("PersonNm")
    officer_dict["name"] = name.text
    
    title = officer.find("TitleTxt")
    officer_dict["title"] = title.text
    
    compensation = officer.find("ReportableCompFromOrgAmt")
    officer_dict["reportable_compensation"] = compensation.text
    
    other_compensation = officer.find("OtherCompensationAmt")
    officer_dict["other_compensation"] = other_compensation.text
    
    officer_list.append(officer_dict)

# %%
officer_list
# Out:
# [{'name': 'JOSEPH DERISI',
#   'title': 'CO-PRESIDENT',
#   'reportable_compensation': '909234',
#   'other_compensation': '35540'},
#  {'name': 'STEVE QUAKE',
#   'title': 'CO-PRESIDENT',
#   'reportable_compensation': '909234',
#   'other_compensation': '35540'},
#  {'name': 'CORI BARGMANN',
#   'title': 'DIRECTOR',
#   'reportable_compensation': '0',
#   'other_compensation': '0'},
#  {'name': 'JOHN HENNESSY',
#   'title': 'DIRECTOR',
#   'reportable_compensation': '0',
#   'other_compensation': '0'},
#  {'name': 'PRISCILLA CHAN',
#   'title': 'DIRECTOR',
#   'reportable_compensation': '0',
#   'other_compensation': '0'},
#  {'name': 'REID HOFFMAN',
#   'title': 'DIRECTOR',
#   'reportable_compensation': '0',
#   'other_compensation': '0'},
#  {'name': 'MARK ZUCKERBERG',
#   'title': 'DIRECTOR',
#   'reportable_compensation': '0',
#   'other_compensation': '0'},
#  {'name': 'GAJUS WORTHINGTON',
#   'title': 'CHIEF OPERATING OFFICER',
#   'reportable_compensation': '741684',
#   'other_compensation': '45961'},
#  {'name': 'VICTOR COLUNGA',
#   'title': 'CFO & TREASURER',
#   'reportable_compensation': '713940',
#   'other_compensation': '44170'},
#  {'name': 'MAUREEN SHEEHY',
#   'title': 'SECRETARY AND LEGAL COUNSEL',
#   'reportable_compensation': '607455',
#   'other_compensation': '43513'},
#  {'name': 'JIM KARKANIAS',
#   'title': 'VP, DATA SCIENCES & IT INF',
#   'reportable_compensation': '510736',
#   'other_compensation': '36565'},
#  {'name': 'SANDRA L SCHMID START 6120',
#   'title': 'CHIEF SCIENTIFIC OFFICER',
#   'reportable_compensation': '384941',
#   'other_compensation': '13593'},
#  {'name': 'WILLIAM BURKHOLDER',
#   'title': 'DIRECTOR, SCIENTIFIC PGRM MGMT',
#   'reportable_compensation': '277856',
#   'other_compensation': '39195'},
#  {'name': 'SONYA ZILKA',
#   'title': 'VP OF HUMAN RESOURCE',
#   'reportable_compensation': '495945',
#   'other_compensation': '29103'},
#  {'name': 'RAFAEL GOMEZ-SJOBERG',
#   'title': 'DIRECTOR, BIOENGINEERING',
#   'reportable_compensation': '319515',
#   'other_compensation': '32948'},
#  {'name': 'ANNETTE PARENT',
#   'title': 'LEAD IP COUNSEL',
#   'reportable_compensation': '303845',
#   'other_compensation': '24124'},
#  {'name': 'ASTRID HO',
#   'title': 'CONTROLLER',
#   'reportable_compensation': '281234',
#   'other_compensation': '45823'},
#  {'name': 'JOSHUA E ELIAS-MERRIMAN',
#   'title': 'PLATFORM LEADER',
#   'reportable_compensation': '257518',
#   'other_compensation': '29783'}]

# %%
zuck_officer_df = pd.DataFrame(officer_list)
zuck_officer_df
# Out:
#                           name                           title  \
# 0                JOSEPH DERISI                    CO-PRESIDENT
# 1                  STEVE QUAKE                    CO-PRESIDENT
# 2                CORI BARGMANN                        DIRECTOR
# 3                JOHN HENNESSY                        DIRECTOR
# 4               PRISCILLA CHAN                        DIRECTOR
# 5                 REID HOFFMAN                        DIRECTOR
# 6              MARK ZUCKERBERG                        DIRECTOR
# 7            GAJUS WORTHINGTON         CHIEF OPERATING OFFICER
# 8               VICTOR COLUNGA                 CFO & TREASURER
# 9               MAUREEN SHEEHY     SECRETARY AND LEGAL COUNSEL
# 10               JIM KARKANIAS      VP, DATA SCIENCES & IT INF
# 11  SANDRA L SCHMID START 6120        CHIEF SCIENTIFIC OFFICER
# 12          WILLIAM BURKHOLDER  DIRECTOR, SCIENTIFIC PGRM MGMT
# 13                 SONYA ZILKA            VP OF HUMAN RESOURCE
# 14        RAFAEL GOMEZ-SJOBERG        DIRECTOR, BIOENGINEERING
# 15              ANNETTE PARENT                 LEAD IP COUNSEL
# 16                   ASTRID HO                      CONTROLLER
# 17     JOSHUA E ELIAS-MERRIMAN                 PLATFORM LEADER
#
#    reportable_compensation other_compensation
# 0                   909234              35540
# 1                   909234              35540
# 2                        0                  0
# 3                        0                  0
# 4                        0                  0
# 5                        0                  0
# 6                        0                  0
# 7                   741684              45961
# 8                   713940              44170
# 9                   607455              43513
# 10                  510736              36565
# 11                  384941              13593
# 12                  277856              39195
# 13                  495945              29103
# 14                  319515              32948
# 15                  303845              24124
# 16                  281234              45823
# 17                  257518              29783

# %%
recipient_data = zuck_data.find_all("RecipientTable")
recipient_data
# Out:
# [<RecipientTable>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>STANFORD UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <USAddress>
#  <AddressLine1Txt>3145 PORTER DRIVE</AddressLine1Txt>
#  <CityNm>PALO ALTO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94304</ZIPCd>
#  </USAddress>
#  <RecipientEIN>941156365</RecipientEIN>
#  <IRCSectionDesc>501(C)(3)</IRCSectionDesc>
#  <CashGrantAmt>11133566</CashGrantAmt>
#  <PurposeOfGrantTxt>SCIENTIFIC AND MEDICAL RESEARCH</PurposeOfGrantTxt>
#  </RecipientTable>,
#  <RecipientTable>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UC SAN FRANCISCO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <USAddress>
#  <AddressLine1Txt>PO BOX 0248</AddressLine1Txt>
#  <CityNm>SAN FRANCISCO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94143</ZIPCd>
#  </USAddress>
#  <RecipientEIN>946036493</RecipientEIN>
#  <IRCSectionDesc>501(C)(3)</IRCSectionDesc>
#  <CashGrantAmt>8886379</CashGrantAmt>
#  <PurposeOfGrantTxt>SCIENTIFIC AND MEDICAL RESEARCH</PurposeOfGrantTxt>
#  </RecipientTable>,
#  <RecipientTable>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UC BERKELEY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <USAddress>
#  <AddressLine1Txt>2195 HEARST AVE RM 120 MC 1104</AddressLine1Txt>
#  <CityNm>BERKELEY</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94720</ZIPCd>
#  </USAddress>
#  <RecipientEIN>946002123</RecipientEIN>
#  <IRCSectionDesc>501(C)(3)</IRCSectionDesc>
#  <CashGrantAmt>4690000</CashGrantAmt>
#  <PurposeOfGrantTxt>SCIENTIFIC AND MEDICAL RESEARCH</PurposeOfGrantTxt>
#  </RecipientTable>]

# %%
recipient_list = []

for recipient in recipient_data:
    recipient_dict = {}
    recipient_name = recipient.find("RecipientBusinessName")
    recipient_dict["business_name"] = recipient_name.text
    
    recipient_amount = recipient.find("CashGrantAmt")
    recipient_dict["amount_received"] = recipient_amount.text
    
    recipient_purpose = recipient.find("PurposeOfGrantTxt")
    recipient_dict["purpose"] = recipient_purpose.text

    recipient_city = recipient.find("CityNm")
    recipient_dict["city"] = recipient_city.text
    
    recipient_state = recipient.find("StateAbbreviationCd")
    recipient_dict["state"] = recipient_state.text
    recipient_list.append(recipient_dict)

    print(recipient_list)
    print("******")
# Out:
# [{'business_name': '\nSTANFORD UNIVERSITY\n', 'amount_received': '11133566', 'purpose': 'SCIENTIFIC AND MEDICAL RESEARCH', 'city': 'PALO ALTO', 'state': 'CA'}]
# ******
# [{'business_name': '\nSTANFORD UNIVERSITY\n', 'amount_received': '11133566', 'purpose': 'SCIENTIFIC AND MEDICAL RESEARCH', 'city': 'PALO ALTO', 'state': 'CA'}, {'business_name': '\nUC SAN FRANCISCO\n', 'amount_received': '8886379', 'purpose': 'SCIENTIFIC AND MEDICAL RESEARCH', 'city': 'SAN FRANCISCO', 'state': 'CA'}]
# ******
# [{'business_name': '\nSTANFORD UNIVERSITY\n', 'amount_received': '11133566', 'purpose': 'SCIENTIFIC AND MEDICAL RESEARCH', 'city': 'PALO ALTO', 'state': 'CA'}, {'business_name': '\nUC SAN FRANCISCO\n', 'amount_received': '8886379', 'purpose': 'SCIENTIFIC AND MEDICAL RESEARCH', 'city': 'SAN FRANCISCO', 'state': 'CA'}, {'business_name': '\nUC BERKELEY\n', 'amount_received': '4690000', 'purpose': 'SCIENTIFIC AND MEDICAL RESEARCH', 'city': 'BERKELEY', 'state': 'CA'}]
# ******

# %%
zuck_recipient_df = pd.DataFrame(recipient_list)
zuck_recipient_df["business_name"] = zuck_recipient_df["business_name"].str.strip("\n")
zuck_recipient_df
# Out:
#          business_name amount_received                          purpose  \
# 0  STANFORD UNIVERSITY        11133566  SCIENTIFIC AND MEDICAL RESEARCH
# 1     UC SAN FRANCISCO         8886379  SCIENTIFIC AND MEDICAL RESEARCH
# 2          UC BERKELEY         4690000  SCIENTIFIC AND MEDICAL RESEARCH
#
#             city state
# 0      PALO ALTO    CA
# 1  SAN FRANCISCO    CA
# 2       BERKELEY    CA

# %%
len(zuck_recipient_df)
# Out:
# 3

# %%
zuck_recipient_df["amount_received"].astype(float).sum()
# Out:
# 24709945.0

# %%
contributor_data = zuck_data.find_all("ContributorInformationGrp")

contributor_list = []

for contributor in contributor_data:
    contributor_dict = {}
    name = contributor.find("ContributorNum")
    contributor_dict["contributor_name"] = name.text
    
    business_contributer = contributor.find("BusinessNameLine1") 
    contributor_dict["business_contributor"] = business_contributer.text
    
    amount_contributed = contributor.find("TotalContributionsAmt")
    contributor_dict["contributed_amount"] = amount_contributed.text
    
    contributor_list.append(contributor_dict)
    
    print(contributor_dict)
# Out:
# {'contributor_name': 'RESTRICTED', 'business_contributor': 'RESTRICTED', 'contributed_amount': 'RESTRICTED'}

# %%
musk_contributor_df = pd.DataFrame(contributor_list)
musk_contributor_df
# Out:
#   contributor_name business_contributor contributed_amount
# 0       RESTRICTED           RESTRICTED         RESTRICTED
