# %%
# Project 03 - Donation tells you who they really are! (Chan Zuckerberg Initiative Foundation)

# %%
import requests
zuck_foundation = requests.get("https://projects.propublica.org/nonprofits/download-xml?object_id=202103199349108890")
zuck_foundation
# Out:
# <Response [200]>

# %%
# The text is the raw xml of Form 990 tax document,obtained from ProPublica's non-profit explorer.
zuck_xml = zuck_foundation.text
print(zuck_xml)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Return xmlns="http://www.irs.gov/efile" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.irs.gov/efile" returnVersion="2020v4.1">
#   <ReturnHeader binaryAttachmentCnt="0">
#     <ReturnTs>2021-11-15T17:01:10-06:00</ReturnTs>
#     <TaxPeriodEndDt>2020-12-31</TaxPeriodEndDt>
#     <PreparerFirmGrp>
#       <PreparerFirmEIN>135565207</PreparerFirmEIN>
#       <PreparerFirmName>
#         <BusinessNameLine1Txt>KPMG LLP</BusinessNameLine1Txt>
#       </PreparerFirmName>
#       <PreparerUSAddress>
#         <AddressLine1Txt>550 SOUTH HOPE STREET</AddressLine1Txt>
#         <CityNm>LOS ANGELES</CityNm>
#         <StateAbbreviationCd>CA</StateAbbreviationCd>
#         <ZIPCd>900712629</ZIPCd>
#       </PreparerUSAddress>
#     </PreparerFirmGrp>
#     <ReturnTypeCd>990PF</ReturnTypeCd>
#     <TaxPeriodBeginDt>2020-01-01</TaxPeriodBeginDt>
#     <Filer>
#       <EIN>455002209</EIN>
#       <BusinessName>
#         <BusinessNameLine1Txt>CHAN ZUCKERBERG INITIATIVE FOUNDATION</BusinessNameLine1Txt>
#       </BusinessName>
#       <BusinessNameControlTxt>CHAN</BusinessNameControlTxt>
#       <PhoneNum>6508047100</PhoneNum>
#       <USAddress>
#         <AddressLine1Txt>314 LYTTON AVE</AddressLine1Txt>
#         <CityNm>PALO ALTO</CityNm>
#         <StateAbbreviationCd>CA</StateAbbreviationCd>
#         <ZIPCd>94301</ZIPCd>
#       </USAddress>
#     </Filer>
#     <BusinessOfficerGrp>
#       <PersonNm>BRIAN MANCA</PersonNm>
#       <PersonTitleTxt>AUTHORIZED PERSON</PersonTitleTxt>
#       <PhoneNum>6508047100</PhoneNum>
#       <SignatureDt>2021-11-15</SignatureDt>
#       <DiscussWithPaidPreparerInd>1</DiscussWithPaidPreparerInd>
#     </BusinessOfficerGrp>
#     <SigningOfficerGrp>
#       <PersonFullName>
#         <PersonFirstNm>BRIAN</PersonFirstNm>
#         <PersonLastNm>MANCA</PersonLastNm>
#       </PersonFullName>
#       <SSN>999009999</SSN>
#     </SigningOfficerGrp>
#     <PreparerPersonGrp>
#       <PreparerPersonNm>LAURA A COLLINS</PreparerPersonNm>
#       <PTIN>P00008888</PTIN>
#       <PhoneNum>3362753394</PhoneNum>
#       <PreparationDt>2021-11-13</PreparationDt>
#     </PreparerPersonGrp>
#     <AdditionalFilerInformation>
#       <TrustedCustomerGrp>
#         <TrustedCustomerCd>3</TrustedCustomerCd>
#         <AuthenticationAssuranceLevelCd>AAL1</AuthenticationAssuranceLevelCd>
#         <IdentityAssuranceLevelCd>IAL1</IdentityAssuranceLevelCd>
#       </TrustedCustomerGrp>
#     </AdditionalFilerInformation>
#     <TaxYr>2020</TaxYr>
#     <BuildTS>2022-09-23 18:48:47Z</BuildTS>
#   </ReturnHeader>
#   <ReturnData documentCnt="17">
#     <IRS990PF documentId="RetDoc1235000001" referenceDocumentId="RetDoc2258700001">
#       <Organization501c3ExemptPFInd>X</Organization501c3ExemptPFInd>
#       <FMVAssetsEOYAmt>6404005977</FMVAssetsEOYAmt>
#       <MethodOfAccountingAccrualInd>X</MethodOfAccountingAccrualInd>
#       <AnalysisOfRevenueAndExpenses>
#         <ContriRcvdRevAndExpnssAmt>60000228</ContriRcvdRevAndExpnssAmt>
#         <DividendsRevAndExpnssAmt>15311606</DividendsRevAndExpnssAmt>
#         <DividendsNetInvstIncmAmt>32061399</DividendsNetInvstIncmAmt>
#         <NetGainSaleAstRevAndExpnssAmt>144451429</NetGainSaleAstRevAndExpnssAmt>
#         <GrossSalesPriceAmt>1777226847</GrossSalesPriceAmt>
#         <CapGainNetIncmNetInvstIncmAmt>213817144</CapGainNetIncmNetInvstIncmAmt>
#         <OtherIncomeRevAndExpnssAmt referenceDocumentId="RetDoc2001500001">6391847</OtherIncomeRevAndExpnssAmt>
#         <OtherIncomeNetInvstIncmAmt>3521791</OtherIncomeNetInvstIncmAmt>
#         <OtherIncomeAdjNetIncmAmt>0</OtherIncomeAdjNetIncmAmt>
#         <TotalRevAndExpnssAmt>226155110</TotalRevAndExpnssAmt>
#         <TotalNetInvstIncmAmt>249400334</TotalNetInvstIncmAmt>
#         <TotalAdjNetIncmAmt>0</TotalAdjNetIncmAmt>
#         <CompOfcrDirTrstRevAndExpnssAmt>0</CompOfcrDirTrstRevAndExpnssAmt>
#         <CompOfcrDirTrstNetInvstIncmAmt>0</CompOfcrDirTrstNetInvstIncmAmt>
#         <CompOfcrDirTrstAdjNetIncmAmt>0</CompOfcrDirTrstAdjNetIncmAmt>
#         <CompOfcrDirTrstDsbrsChrtblAmt>0</CompOfcrDirTrstDsbrsChrtblAmt>
#         <LegalFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002100001">226949</LegalFeesRevAndExpnssAmt>
#         <LegalFeesNetInvstIncmAmt>115025</LegalFeesNetInvstIncmAmt>
#         <LegalFeesAdjNetIncmAmt>0</LegalFeesAdjNetIncmAmt>
#         <LegalFeesDsbrsChrtblAmt>280034</LegalFeesDsbrsChrtblAmt>
#         <AccountingFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002200001">434282</AccountingFeesRevAndExpnssAmt>
#         <AccountingFeesNetInvstIncmAmt>176221</AccountingFeesNetInvstIncmAmt>
#         <AccountingFeesAdjNetIncmAmt>0</AccountingFeesAdjNetIncmAmt>
#         <AccountingFeesChrtblPrpsAmt>197727</AccountingFeesChrtblPrpsAmt>
#         <OtherProfFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002300001">1682677</OtherProfFeesRevAndExpnssAmt>
#         <OtherProfFeesNetInvstIncmAmt>750000</OtherProfFeesNetInvstIncmAmt>
#         <OtherProfFeesAdjNetIncmAmt>0</OtherProfFeesAdjNetIncmAmt>
#         <OtherProfFeesDsbrsChrtblAmt>915000</OtherProfFeesDsbrsChrtblAmt>
#         <TaxesRevAndExpnssAmt referenceDocumentId="RetDoc2002500001">15946000</TaxesRevAndExpnssAmt>
#         <TaxesNetInvstIncmAmt>0</TaxesNetInvstIncmAmt>
#         <TaxesAdjNetIncmAmt>0</TaxesAdjNetIncmAmt>
#         <TaxesDsbrsChrtblAmt>0</TaxesDsbrsChrtblAmt>
#         <OtherExpensesRevAndExpnssAmt referenceDocumentId="RetDoc2003200001">310</OtherExpensesRevAndExpnssAmt>
#         <OtherExpensesNetInvstIncmAmt>21736384</OtherExpensesNetInvstIncmAmt>
#         <OtherExpensesAdjNetIncmAmt>0</OtherExpensesAdjNetIncmAmt>
#         <OtherExpensesDsbrsChrtblAmt>310</OtherExpensesDsbrsChrtblAmt>
#         <TotOprExpensesRevAndExpnssAmt>18290218</TotOprExpensesRevAndExpnssAmt>
#         <TotOprExpensesNetInvstIncmAmt>22777630</TotOprExpensesNetInvstIncmAmt>
#         <TotOprExpensesAdjNetIncmAmt>0</TotOprExpensesAdjNetIncmAmt>
#         <TotOprExpensesDsbrsChrtblAmt>1393071</TotOprExpensesDsbrsChrtblAmt>
#         <ContriPaidRevAndExpnssAmt>170025837</ContriPaidRevAndExpnssAmt>
#         <ContriPaidDsbrsChrtblAmt>213346910</ContriPaidDsbrsChrtblAmt>
#         <TotalExpensesRevAndExpnssAmt>188316055</TotalExpensesRevAndExpnssAmt>
#         <TotalExpensesNetInvstIncmAmt>22777630</TotalExpensesNetInvstIncmAmt>
#         <TotalExpensesAdjNetIncmAmt>0</TotalExpensesAdjNetIncmAmt>
#         <TotalExpensesDsbrsChrtblAmt>214739981</TotalExpensesDsbrsChrtblAmt>
#         <ExcessRevenueOverExpensesAmt>37839055</ExcessRevenueOverExpensesAmt>
#         <NetInvestmentIncomeAmt>226622704</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#       </AnalysisOfRevenueAndExpenses>
#       <Form990PFBalanceSheetsGrp>
#         <CashEOYAmt>1300</CashEOYAmt>
#         <CashEOYFMVAmt>1300</CashEOYFMVAmt>
#         <SavAndTempCashInvstBOYAmt>2483435216</SavAndTempCashInvstBOYAmt>
#         <SavAndTempCashInvstEOYAmt>1369143320</SavAndTempCashInvstEOYAmt>
#         <SavAndTempCashInvstEOYFMVAmt>1369143320</SavAndTempCashInvstEOYFMVAmt>
#         <AcctRcvblAmt>255483</AcctRcvblAmt>
#         <AcctRcvblEOYAmt>255483</AcctRcvblEOYAmt>
#         <AcctRcvblEOYFMVAmt>255483</AcctRcvblEOYFMVAmt>
#         <CorporateStockBOYAmt>1207724866</CorporateStockBOYAmt>
#         <CorporateStockEOYAmt referenceDocumentId="RetDoc2018900001">1511095223</CorporateStockEOYAmt>
#         <CorporateStockEOYFMVAmt>1511095223</CorporateStockEOYFMVAmt>
#         <OtherInvestmentsBOYAmt>1806767429</OtherInvestmentsBOYAmt>
#         <OtherInvestmentsEOYAmt referenceDocumentId="RetDoc2018100001">3482344014</OtherInvestmentsEOYAmt>
#         <OtherInvestmentsEOYFMVAmt>3482344014</OtherInvestmentsEOYFMVAmt>
#         <OtherAssetsBOYAmt referenceDocumentId="RetDoc2046600001">15087071</OtherAssetsBOYAmt>
#         <OtherAssetsEOYAmt referenceDocumentId="RetDoc2046600001">41166637</OtherAssetsEOYAmt>
#         <OtherAssetsEOYFMVAmt referenceDocumentId="RetDoc2046600001">41166637</OtherAssetsEOYFMVAmt>
#         <TotalAssetsBOYAmt>5513014582</TotalAssetsBOYAmt>
#         <TotalAssetsEOYAmt>6404005977</TotalAssetsEOYAmt>
#         <TotalAssetsEOYFMVAmt>6404005977</TotalAssetsEOYFMVAmt>
#         <AccountsPayableBOYAmt>308587</AccountsPayableBOYAmt>
#         <AccountsPayableEOYAmt>853533</AccountsPayableEOYAmt>
#         <GrantsPayableBOYAmt>114214284</GrantsPayableBOYAmt>
#         <GrantsPayableEOYAmt>70893210</GrantsPayableEOYAmt>
#         <OtherLiabilitiesBOYAmt referenceDocumentId="RetDoc2065700001">22054000</OtherLiabilitiesBOYAmt>
#         <OtherLiabilitiesEOYAmt referenceDocumentId="RetDoc2065700001">32000000</OtherLiabilitiesEOYAmt>
#         <TotalLiabilitiesBOYAmt>136576871</TotalLiabilitiesBOYAmt>
#         <TotalLiabilitiesEOYAmt>103746743</TotalLiabilitiesEOYAmt>
#         <OrganizationFollowsFASB117Ind>X</OrganizationFollowsFASB117Ind>
#         <NoDonorRstrNetAssestsBOYAmt>5376437711</NoDonorRstrNetAssestsBOYAmt>
#         <NoDonorRstrNetAssestsEOYAmt>6300259234</NoDonorRstrNetAssestsEOYAmt>
#         <TotNetAstOrFundBalancesBOYAmt>5376437711</TotNetAstOrFundBalancesBOYAmt>
#         <TotNetAstOrFundBalancesEOYAmt>6300259234</TotNetAstOrFundBalancesEOYAmt>
#         <TotalLiabilitiesNetAstBOYAmt>5513014582</TotalLiabilitiesNetAstBOYAmt>
#         <TotalLiabilitiesNetAstEOYAmt>6404005977</TotalLiabilitiesNetAstEOYAmt>
#       </Form990PFBalanceSheetsGrp>
#       <ChgInNetAssetsFundBalancesGrp>
#         <TotNetAstOrFundBalancesBOYAmt>5376437711</TotNetAstOrFundBalancesBOYAmt>
#         <ExcessRevenueOverExpensesAmt>37839055</ExcessRevenueOverExpensesAmt>
#         <OtherIncreasesAmt referenceDocumentId="RetDoc2049700001">885982468</OtherIncreasesAmt>
#         <SubtotalAmt>6300259234</SubtotalAmt>
#         <OtherDecreasesAmt>0</OtherDecreasesAmt>
#         <TotNetAstOrFundBalancesEOYAmt>6300259234</TotNetAstOrFundBalancesEOYAmt>
#       </ChgInNetAssetsFundBalancesGrp>
#       <CapGainsLossTxInvstIncmDetail>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>PUBLICLY TRADED SECURITIES</PropertyDesc>
#           <GrossSalesPriceAmt>133993076</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>52</CostOrOtherBasisAmt>
#           <GainOrLossAmt>133993024</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>133993024</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>ALTERNATIVE INVESTMENTS</PropertyDesc>
#           <HowAcquiredCd>P</HowAcquiredCd>
#           <GrossSalesPriceAmt>442513203</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>362689083</CostOrOtherBasisAmt>
#           <GainOrLossAmt>79824120</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>79824120</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapitalGainNetIncomeAmt>213817144</CapitalGainNetIncomeAmt>
#         <NetShortTermCapitalGainLossAmt>0</NetShortTermCapitalGainLossAmt>
#       </CapGainsLossTxInvstIncmDetail>
#       <ExciseTaxBasedOnInvstIncmGrp>
#         <InvestmentIncomeExciseTaxAmt>3150056</InvestmentIncomeExciseTaxAmt>
#         <TaxUnderSection511Amt>0</TaxUnderSection511Amt>
#         <SubtotalAmt>3150056</SubtotalAmt>
#         <SubtitleATaxAmt>0</SubtitleATaxAmt>
#         <TaxBasedOnInvestmentIncomeAmt>3150056</TaxBasedOnInvestmentIncomeAmt>
#         <EstimatedPlusOvpmtIncmTxAmt>1914306</EstimatedPlusOvpmtIncmTxAmt>
#         <ExemptFrgnOrgTaxWthldAtSrceAmt>0</ExemptFrgnOrgTaxWthldAtSrceAmt>
#         <ExtsnRequestIncomeTaxPaidAmt>8000000</ExtsnRequestIncomeTaxPaidAmt>
#         <BackupWithholdingWithheldAmt>0</BackupWithholdingWithheldAmt>
#         <TotalPaymentsAndCreditsAmt>9914306</TotalPaymentsAndCreditsAmt>
#         <Form2220AttachedInd referenceDocumentId="RetDoc1192000001">X</Form2220AttachedInd>
#         <EsPenaltyAmt>0</EsPenaltyAmt>
#         <OverpaymentAmt>6764250</OverpaymentAmt>
#         <AppliedToESTaxAmt>6764250</AppliedToESTaxAmt>
#         <RefundAmt>0</RefundAmt>
#       </ExciseTaxBasedOnInvstIncmGrp>
#       <StatementsRegardingActyGrp>
#         <LegislativePoliticalActyInd>0</LegislativePoliticalActyInd>
#         <MoreThan100SpentInd>0</MoreThan100SpentInd>
#         <Form1120POLFiledInd>0</Form1120POLFiledInd>
#         <Section4955OrganizationTaxAmt>0</Section4955OrganizationTaxAmt>
#         <Section4955ManagersTaxAmt>0</Section4955ManagersTaxAmt>
#         <TaxReimbursedAmt>0</TaxReimbursedAmt>
#         <ActivitiesNotPreviouslyRptInd>0</ActivitiesNotPreviouslyRptInd>
#         <ChangesToArticlesOrBylawsInd>0</ChangesToArticlesOrBylawsInd>
#         <UnrelatedBusIncmOverLimitInd>1</UnrelatedBusIncmOverLimitInd>
#         <Form990TFiledInd>1</Form990TFiledInd>
#         <OrganizationDissolvedEtcInd>0</OrganizationDissolvedEtcInd>
#         <Section508eRqrSatisfiedInd>1</Section508eRqrSatisfiedInd>
#         <AtLeast5000InAssetsInd>1</AtLeast5000InAssetsInd>
#         <OrgReportOrRegisterStateCd>CA</OrgReportOrRegisterStateCd>
#         <Form990PFFiledWithAttyGenInd>1</Form990PFFiledWithAttyGenInd>
#         <PrivateOperatingFoundationInd>0</PrivateOperatingFoundationInd>
#         <NewSubstantialContributorsInd>0</NewSubstantialContributorsInd>
#         <OwnControlledEntityInd referenceDocumentId="RetDoc2205000001">1</OwnControlledEntityInd>
#         <DonorAdvisedFundInd>0</DonorAdvisedFundInd>
#         <ComplyWithPublicInspRqrInd>1</ComplyWithPublicInspRqrInd>
#         <WebsiteAddressTxt>N/A</WebsiteAddressTxt>
#         <IndividualWithBooksNm>APERCEN PARTNERS LLC</IndividualWithBooksNm>
#         <PhoneNum>6508047100</PhoneNum>
#         <LocationOfBooksUSAddress>
#           <AddressLine1Txt>314 LYTTON AVE</AddressLine1Txt>
#           <CityNm>PALO ALTO</CityNm>
#           <StateAbbreviationCd>CA</StateAbbreviationCd>
#           <ZIPCd>94301</ZIPCd>
#         </LocationOfBooksUSAddress>
#         <ForeignAccountsQuestionInd>0</ForeignAccountsQuestionInd>
#       </StatementsRegardingActyGrp>
#       <StatementsRegardingActy4720Grp>
#         <SaleOrExchDisqualifiedPrsnInd>0</SaleOrExchDisqualifiedPrsnInd>
#         <BrrwOrLendDisqualifiedPrsnInd>0</BrrwOrLendDisqualifiedPrsnInd>
#         <FurnGoodsDisqualifiedPrsnInd>1</FurnGoodsDisqualifiedPrsnInd>
#         <PayCompDisqualifiedPrsnInd>1</PayCompDisqualifiedPrsnInd>
#         <TransferAstDisqualifiedPrsnInd>0</TransferAstDisqualifiedPrsnInd>
#         <PaymentToGovernmentOfficialInd>0</PaymentToGovernmentOfficialInd>
#         <ActsFailToQlfyAsExceptionsInd>1</ActsFailToQlfyAsExceptionsInd>
#         <UncorrectedPriorActsInd>0</UncorrectedPriorActsInd>
#         <UndistributedIncomePYInd>0</UndistributedIncomePYInd>
#         <BusinessHoldingsInd>1</BusinessHoldingsInd>
#         <ExcessBusinessHoldingsInd>0</ExcessBusinessHoldingsInd>
#         <JeopardyInvestmentsInd>0</JeopardyInvestmentsInd>
#         <UncorrectedPYJeopardyInvstInd>0</UncorrectedPYJeopardyInvstInd>
#         <InfluenceLegislationInd>0</InfluenceLegislationInd>
#         <InfluenceElectionInd>0</InfluenceElectionInd>
#         <GrantsToIndividualsInd>0</GrantsToIndividualsInd>
#         <GrantsToOrganizationsInd>1</GrantsToOrganizationsInd>
#         <NoncharitablePurposeInd>0</NoncharitablePurposeInd>
#         <TransactionsFailToQlfyAsExcInd>0</TransactionsFailToQlfyAsExcInd>
#         <MaintainedExpenditureRspnsInd referenceDocumentId="RetDoc2118100001">1</MaintainedExpenditureRspnsInd>
#         <RcvFndsToPayPrsnlBnftCntrctInd>0</RcvFndsToPayPrsnlBnftCntrctInd>
#         <PayPremiumsPrsnlBnftCntrctInd>0</PayPremiumsPrsnlBnftCntrctInd>
#         <ProhibitedTaxShelterTransInd>0</ProhibitedTaxShelterTransInd>
#         <SubjToTaxRmnrtnExPrchtPymtInd>0</SubjToTaxRmnrtnExPrchtPymtInd>
#       </StatementsRegardingActy4720Grp>
#       <OfficerDirTrstKeyEmplInfoGrp>
#         <OfficerDirTrstKeyEmplGrp>
#           <PersonNm>MARK ZUCKERBERG</PersonNm>
#           <USAddress>
#             <AddressLine1Txt>314 LYTTON AVE</AddressLine1Txt>
#             <CityNm>PALO ALTO</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94301</ZIPCd>
#           </USAddress>
#           <TitleTxt>TRUSTEE</TitleTxt>
#           <AverageHrsPerWkDevotedToPosRt>1.50</AverageHrsPerWkDevotedToPosRt>
#           <CompensationAmt>0</CompensationAmt>
#           <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#           <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#         </OfficerDirTrstKeyEmplGrp>
#         <CompOfHghstPdEmplOrNONETxt>NONE</CompOfHghstPdEmplOrNONETxt>
#         <OtherEmployeePaidOver50kCnt>0</OtherEmployeePaidOver50kCnt>
#         <CompensationOfHghstPdCntrctGrp>
#           <BusinessName>
#             <BusinessNameLine1Txt>PRICEWATERHOUSECOOPERS ADVISORY SERVICES LLC</BusinessNameLine1Txt>
#           </BusinessName>
#           <USAddress>
#             <AddressLine1Txt>4040 W BOY SCOUT BLVD</AddressLine1Txt>
#             <CityNm>TAMPA</CityNm>
#             <StateAbbreviationCd>FL</StateAbbreviationCd>
#             <ZIPCd>33607</ZIPCd>
#           </USAddress>
#           <ServiceTypeTxt>CONSULTING</ServiceTypeTxt>
#           <CompensationAmt>840000</CompensationAmt>
#         </CompensationOfHghstPdCntrctGrp>
#         <CompensationOfHghstPdCntrctGrp>
#           <BusinessName>
#             <BusinessNameLine1Txt>MUNGER TOLLES &amp; OLSON LLP</BusinessNameLine1Txt>
#           </BusinessName>
#           <USAddress>
#             <AddressLine1Txt>350 SOUTH GRAND AVE 50TH FLOOR</AddressLine1Txt>
#             <CityNm>LOS ANGELES</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>90071</ZIPCd>
#           </USAddress>
#           <ServiceTypeTxt>LEGAL</ServiceTypeTxt>
#           <CompensationAmt>723946</CompensationAmt>
#         </CompensationOfHghstPdCntrctGrp>
#         <CompensationOfHghstPdCntrctGrp>
#           <BusinessName>
#             <BusinessNameLine1Txt>APERCEN PARTNERS LLC</BusinessNameLine1Txt>
#           </BusinessName>
#           <USAddress>
#             <AddressLine1Txt>314 LYTTON AVE</AddressLine1Txt>
#             <CityNm>PALO ALTO</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94301</ZIPCd>
#           </USAddress>
#           <ServiceTypeTxt>ACCOUNTING &amp; CONSULTING</ServiceTypeTxt>
#           <CompensationAmt>327814</CompensationAmt>
#         </CompensationOfHghstPdCntrctGrp>
#         <CompensationOfHghstPdCntrctGrp>
#           <BusinessName>
#             <BusinessNameLine1Txt>SILICON VALLEY COMMUNITY FOUNDATION</BusinessNameLine1Txt>
#           </BusinessName>
#           <USAddress>
#             <AddressLine1Txt>2440 W EL CAMINO REAL 300</AddressLine1Txt>
#             <CityNm>MOUNTAIN VIEW</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94040</ZIPCd>
#           </USAddress>
#           <ServiceTypeTxt>GRANT SERVICING</ServiceTypeTxt>
#           <CompensationAmt>75000</CompensationAmt>
#         </CompensationOfHghstPdCntrctGrp>
#         <CompensationOfHghstPdCntrctGrp>
#           <BusinessName>
#             <BusinessNameLine1Txt>KPMG LLP</BusinessNameLine1Txt>
#           </BusinessName>
#           <USAddress>
#             <AddressLine1Txt>3 CHESTNUT RIDGE RD</AddressLine1Txt>
#             <CityNm>MONTVALE</CityNm>
#             <StateAbbreviationCd>NJ</StateAbbreviationCd>
#             <ZIPCd>07645</ZIPCd>
#           </USAddress>
#           <ServiceTypeTxt>AUDIT &amp; TAX</ServiceTypeTxt>
#           <CompensationAmt>65177</CompensationAmt>
#         </CompensationOfHghstPdCntrctGrp>
#         <ContractorPaidOver50kCnt>0</ContractorPaidOver50kCnt>
#       </OfficerDirTrstKeyEmplInfoGrp>
#       <SumOfProgramRelatedInvstGrp>
#         <Description1Txt>INVESTMENT FOR THE PURPOSE OF MAKING HOME OWNERSHIP MORE AFFORDABLE FOR ESSENTIAL PROFESSIONALS THROUGH DOWN PAYMENT ASSISTANCE.</Description1Txt>
#         <Expenses1Amt>18381908</Expenses1Amt>
#         <Description2Txt>INVESTMENT FOR THE PURPOSE OF CREATING NEW AFFORDABLE HOUSING AND PRESERVING EXISTING AFFORDABLE HOUSING IN THE CALIFORNIA BAY AREA.</Description2Txt>
#         <Expenses2Amt>10000000</Expenses2Amt>
#         <AllOtherProgramRltdInvstTotAmt referenceDocumentId="RetDoc2063500001">0</AllOtherProgramRltdInvstTotAmt>
#         <TotalAmt>28381908</TotalAmt>
#       </SumOfProgramRelatedInvstGrp>
#       <MinimumInvestmentReturnGrp>
#         <AverageMonthlyFMVOfSecAmt>1463108069</AverageMonthlyFMVOfSecAmt>
#         <AverageMonthlyCashBalancesAmt>1664829237</AverageMonthlyCashBalancesAmt>
#         <FMVAllOtherNoncharitableAstAmt>3254830538</FMVAllOtherNoncharitableAstAmt>
#         <TotalFMVOfUnusedAssetsAmt>6382767844</TotalFMVOfUnusedAssetsAmt>
#         <ReductionClaimedAmt>0</ReductionClaimedAmt>
#         <AcquisitionIndebtednessAmt>0</AcquisitionIndebtednessAmt>
#         <AdjustedTotalFMVOfUnusedAstAmt>6382767844</AdjustedTotalFMVOfUnusedAstAmt>
#         <CashDeemedCharitableAmt>95741518</CashDeemedCharitableAmt>
#         <NetVlNoncharitableAssetsAmt>6287026326</NetVlNoncharitableAssetsAmt>
#         <MinimumInvestmentReturnAmt>314351316</MinimumInvestmentReturnAmt>
#       </MinimumInvestmentReturnGrp>
#       <DistributableAmountGrp>
#         <MinimumInvestmentReturnAmt>314351316</MinimumInvestmentReturnAmt>
#         <TaxBasedOnInvestmentIncomeAmt>3150056</TaxBasedOnInvestmentIncomeAmt>
#         <TotalTaxAmt>3150056</TotalTaxAmt>
#         <DistributableBeforeAdjAmt>311201260</DistributableBeforeAdjAmt>
#         <RecoveriesQualfiedDistriAmt>0</RecoveriesQualfiedDistriAmt>
#         <DistributableBeforeDedAmt>311201260</DistributableBeforeDedAmt>
#         <DeductionFromDistributableAmt>0</DeductionFromDistributableAmt>
#         <DistributableAsAdjustedAmt>311201260</DistributableAsAdjustedAmt>
#       </DistributableAmountGrp>
#       <QualifyingDistriPartXIIGrp>
#         <ExpensesAndContributionsAmt>214739981</ExpensesAndContributionsAmt>
#         <ProgramRelatedInvstTotalAmt>28381908</ProgramRelatedInvstTotalAmt>
#         <QualifyingDistributionsAmt>243121889</QualifyingDistributionsAmt>
#         <PctSect4940eOrgNetInvstIncmAmt>0</PctSect4940eOrgNetInvstIncmAmt>
#         <AdjustedQualifyingDistriAmt>243121889</AdjustedQualifyingDistriAmt>
#       </QualifyingDistriPartXIIGrp>
#       <UndistributedIncomeGrp>
#         <DistributableAsAdjustedAmt>311201260</DistributableAsAdjustedAmt>
#         <UndistributedIncomePYAmt>174465398</UndistributedIncomePYAmt>
#         <TotalForPriorYearsAmt>0</TotalForPriorYearsAmt>
#         <TotalExcessDistributionCyovAmt>0</TotalExcessDistributionCyovAmt>
#         <QualifyingDistributionsAmt>243121889</QualifyingDistributionsAmt>
#         <AppliedToYear1Amt>174465398</AppliedToYear1Amt>
#         <AppliedToPriorYearsAmt>0</AppliedToPriorYearsAmt>
#         <TreatedAsDistriFromCorpusAmt>0</TreatedAsDistriFromCorpusAmt>
#         <AppliedToCurrentYearAmt>68656491</AppliedToCurrentYearAmt>
#         <RemainingDistriFromCorpusAmt>0</RemainingDistriFromCorpusAmt>
#         <ExcessDistriCyovAppCYCorpusAmt>0</ExcessDistriCyovAppCYCorpusAmt>
#         <ExcessDistributionCyovAppCYAmt>0</ExcessDistributionCyovAppCYAmt>
#         <TotalCorpusAmt>0</TotalCorpusAmt>
#         <PriorYearUndistributedIncmAmt>0</PriorYearUndistributedIncmAmt>
#         <PriorYearDeficiencyOrTaxAmt>0</PriorYearDeficiencyOrTaxAmt>
#         <Taxable1Amt>0</Taxable1Amt>
#         <Taxable2Amt>0</Taxable2Amt>
#         <UndistributedIncomeCYAmt>242544769</UndistributedIncomeCYAmt>
#         <CorpusDistri170b1EOr4942g3Amt>0</CorpusDistri170b1EOr4942g3Amt>
#         <ExcessDistriCyovFromYr5Amt>0</ExcessDistriCyovFromYr5Amt>
#         <ExcessDistriCyovToNextYrAmt>0</ExcessDistriCyovToNextYrAmt>
#       </UndistributedIncomeGrp>
#       <SupplementaryInformationGrp>
#         <ContributingManagerNm>MARK ZUCKERBERG</ContributingManagerNm>
#         <OnlyContriToPreselectedInd>X</OnlyContriToPreselectedInd>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ADDGENE INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>490 ARSENAL WAY SUITE 100</AddressLine1Txt>
#             <CityNm>WATERTOWN</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02472</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#           <Amt>1050659</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ALAMEDA COUNTY PUBLIC HEALTH DEPARTMENT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1000 BROADWAY SUITE 500</AddressLine1Txt>
#             <CityNm>OAKLAND</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94607</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#           <Amt>500000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BATTELLE FOR KIDS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>4525 TRUEMAN BLVD</AddressLine1Txt>
#             <CityNm>HILLIARD</CityNm>
#             <StateAbbreviationCd>OH</StateAbbreviationCd>
#             <ZIPCd>43026</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>STUDENT ASSESSMENT RESEARCH</GrantOrContributionPurposeTxt>
#           <Amt>80000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BAYLOR COLLEGE OF MEDICINE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>ONE BAYLOR PLAZA</AddressLine1Txt>
#             <CityNm>HOUSTON</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>77030</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>666431</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BELOVED COMMUNITY INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>3157 GENTILLY BLVD 176</AddressLine1Txt>
#             <CityNm>NEW ORLEANS</CityNm>
#             <StateAbbreviationCd>LA</StateAbbreviationCd>
#             <ZIPCd>70122</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#           <Amt>900000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BEN-GURION UNIVERSITY OF THE NEGEV</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientForeignAddress>
#             <AddressLine1Txt>PO BOX 653</AddressLine1Txt>
#             <CityNm>BEERSHEVA</CityNm>
#             <CountryCd>IS</CountryCd>
#             <ForeignPostalCd>8410501</ForeignPostalCd>
#           </RecipientForeignAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>181760</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BLACK TEACHER COLLABORATIVE INCORPORATED</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>2170 BOULEVARD GRANADA SW</AddressLine1Txt>
#             <CityNm>ATLANTA</CityNm>
#             <StateAbbreviationCd>GA</StateAbbreviationCd>
#             <ZIPCd>30311</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#           <Amt>650000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BOSTON DEBATE LEAGUE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1542 TREMONT ST</AddressLine1Txt>
#             <CityNm>BOSTON</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02120</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>DEBATE-INSPIRED CLASSROOMS</GrantOrContributionPurposeTxt>
#           <Amt>65000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BROAD INSTITUTE INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>415 MAIN ST</AddressLine1Txt>
#             <CityNm>CAMBRIDGE</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02142</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>925403</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BROAD INSTITUTE INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>415 MAIN ST</AddressLine1Txt>
#             <CityNm>CAMBRIDGE</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02142</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>972129</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BROAD INSTITUTE INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>415 MAIN ST</AddressLine1Txt>
#             <CityNm>CAMBRIDGE</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02142</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>1072581</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CENTER FOR COLLABORATIVE EDUCATION INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>33 HARRISON AVE 6TH FLOOR</AddressLine1Txt>
#             <CityNm>BOSTON</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02111</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>HOLISTIC SCHOOL QUALITY MEASURES</GrantOrContributionPurposeTxt>
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CHAN ZUCKERBERG BIOHUB INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>499 ILLINOIS ST</AddressLine1Txt>
#             <CityNm>SAN FRANCISCO</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94158</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>MEDICAL RESEARCH</GrantOrContributionPurposeTxt>
#           <Amt>60000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CHANCELLOR MASTERS &amp; SCHOLARS OF THE UNIVERSITY OF OXFORD</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientForeignAddress>
#             <AddressLine1Txt>JOHN RADCLIFFE HOSPITAL LEVEL 3</AddressLine1Txt>
#             <CityNm>OXFORD</CityNm>
#             <CountryCd>UK</CountryCd>
#             <ForeignPostalCd>OX3 9DU</ForeignPostalCd>
#           </RecipientForeignAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>1142713</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CITIZENS OF THE WORLD CHARTER SCHOOLS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientForeignAddress>
#             <AddressLine1Txt>5371 WILSHIRE BLVD SUITE 210</AddressLine1Txt>
#             <CityNm>LOS ANGELES</CityNm>
#             <ProvinceOrStateNm>CALIFORNIA</ProvinceOrStateNm>
#             <CountryCd>UK</CountryCd>
#             <ForeignPostalCd>90036</ForeignPostalCd>
#           </RecipientForeignAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>PEER COACHING AND IDENTITY PROJECTS</GrantOrContributionPurposeTxt>
#           <Amt>475000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>COLD SPRING HARBOR LABORATORY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 100 ONE BUNGTOWN RD</AddressLine1Txt>
#             <CityNm>COLD SPRING HARBOR</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>11724</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>MEDRXIV-BIORXIV PROJECT</GrantOrContributionPurposeTxt>
#           <Amt>946052</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CONTRA COSTA REGIONAL HEALTH FOUNDATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>50 DOUGLAS DR SUITE 310A</AddressLine1Txt>
#             <CityNm>MARTINEZ</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94553</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>RAPID RESPONSE TO COVID-19</GrantOrContributionPurposeTxt>
#           <Amt>500000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CURII CORPORATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>212 ELM ST 3RD FLOOR</AddressLine1Txt>
#             <CityNm>SOMERVILLE</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02144</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>OPEN SCIENCE</GrantOrContributionPurposeTxt>
#           <Amt>180000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>DONORSCHOOSEORG</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>134 WEST 37TH ST 11TH FLOOR</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10018</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>DISTANCE LEARNING PROJECTS IN RESPONSE TO COVID-19</GrantOrContributionPurposeTxt>
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>DUKE UNIVERSITY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>BOX 90581</AddressLine1Txt>
#             <CityNm>DURHAM</CityNm>
#             <StateAbbreviationCd>NC</StateAbbreviationCd>
#             <ZIPCd>27708</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>137170</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ECONOMIC INNOVATION GROUP</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>616 H ST NW SUITE 550</AddressLine1Txt>
#             <CityNm>WASHINGTON</CityNm>
#             <StateAbbreviationCd>DC</StateAbbreviationCd>
#             <ZIPCd>20001</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>IMPROVE STUDENT OUTCOMES</GrantOrContributionPurposeTxt>
#           <Amt>225000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>EDITORIAL PROJECTS IN EDUCATION INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>6935 ARLINGTON RD SUITE 100</AddressLine1Txt>
#             <CityNm>BETHESDA</CityNm>
#             <StateAbbreviationCd>MD</StateAbbreviationCd>
#             <ZIPCd>20814</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>JOURNALISM FOCUSED ON EDUCATION/DIGITAL TRANSFORMATION INITIATIVE</GrantOrContributionPurposeTxt>
#           <Amt>750000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>EDUCATION LEADERS OF COLOR INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>16430 JANINE DR</AddressLine1Txt>
#             <CityNm>WHITTIER</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>90603</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT/INFRASTRUCTURE</GrantOrContributionPurposeTxt>
#           <Amt>1100000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>EDUCATIONAL SERVICE CENTER OF NORTHEAST OHIO</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>6393 OAK TREE BLVD</AddressLine1Txt>
#             <CityNm>INDEPENDENCE</CityNm>
#             <StateAbbreviationCd>OH</StateAbbreviationCd>
#             <ZIPCd>44131</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>WHOLE CHILD PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>1500000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>EQUAL OPPORTUNITY SCHOOLS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>5601 6TH AVE SOUTH SUITE 258</AddressLine1Txt>
#             <CityNm>SEATTLE</CityNm>
#             <StateAbbreviationCd>WA</StateAbbreviationCd>
#             <ZIPCd>98108</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ETHICS AND RELIGIOUS LIBERTY COMMISSION OF THE SOUTHERN BAPTIST CONVENTION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>901 COMMERCE ST SUITE 550</AddressLine1Txt>
#             <CityNm>NASHVILLE</CityNm>
#             <StateAbbreviationCd>TN</StateAbbreviationCd>
#             <ZIPCd>37203</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>CRIMINAL JUSTICE REFORM</GrantOrContributionPurposeTxt>
#           <Amt>90000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FIRST NATIONS DEVELOPMENT INSTITUTE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>2432 MAIN ST 2ND FLOOR</AddressLine1Txt>
#             <CityNm>LONGMONT</CityNm>
#             <StateAbbreviationCd>CO</StateAbbreviationCd>
#             <ZIPCd>80501</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>NATIVE YOUTH DEVELOPMENT IN EDUCATION, MENTAL HEALTH AND IDENTITY</GrantOrContributionPurposeTxt>
#           <Amt>1600000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FRED HUTCHINSON CANCER RESEARCH CENTER</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 19024 J5-200</AddressLine1Txt>
#             <CityNm>SEATTLE</CityNm>
#             <StateAbbreviationCd>WA</StateAbbreviationCd>
#             <ZIPCd>98109</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>333203</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FWDUS EDUCATION FUND INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 34506</AddressLine1Txt>
#             <CityNm>WASHINGTON</CityNm>
#             <StateAbbreviationCd>DC</StateAbbreviationCd>
#             <ZIPCd>20043</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#           <Amt>6521733</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>GATES PHILANTHROPY PARTNERS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 23350</AddressLine1Txt>
#             <CityNm>SEATTLE</CityNm>
#             <StateAbbreviationCd>WA</StateAbbreviationCd>
#             <ZIPCd>98102</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>COVID-19 RESEARCH AND RESPONSE</GrantOrContributionPurposeTxt>
#           <Amt>20000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>GATES PHILANTHROPY PARTNERS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 23350</AddressLine1Txt>
#             <CityNm>SEATTLE</CityNm>
#             <StateAbbreviationCd>WA</StateAbbreviationCd>
#             <ZIPCd>98102</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>CARDIOVASCULAR HEALTH AND INFRASTRUCTURE INITIATIVE</GrantOrContributionPurposeTxt>
#           <Amt>10000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>GENOME INSTITUTE OF SINGAPORE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientForeignAddress>
#             <AddressLine1Txt>60 BIOPOLIS ST GENOME 02-01</AddressLine1Txt>
#             <CityNm>SINGAPORE</CityNm>
#             <CountryCd>SN</CountryCd>
#             <ForeignPostalCd>138672</ForeignPostalCd>
#           </RecipientForeignAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>398731</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>GENOME RESEARCH LIMITED</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientForeignAddress>
#             <AddressLine1Txt>GENOME CAMPUS HINXTON</AddressLine1Txt>
#             <CityNm>CAMBRIDGE</CityNm>
#             <CountryCd>UK</CountryCd>
#             <ForeignPostalCd>CB10 1SA</ForeignPostalCd>
#           </RecipientForeignAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>786291</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>GREATER KANAWHA VALLEY FOUNDATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 3041</AddressLine1Txt>
#             <CityNm>CHARLESTON</CityNm>
#             <StateAbbreviationCd>WV</StateAbbreviationCd>
#             <ZIPCd>25301</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>WEST VIRGINIA JUSTICE REFORM FUND</GrantOrContributionPurposeTxt>
#           <Amt>390000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>INDIANA UNIVERSITY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>400 E 7TH ST ROOM 501</AddressLine1Txt>
#             <CityNm>BLOOMINGTON</CityNm>
#             <StateAbbreviationCd>IN</StateAbbreviationCd>
#             <ZIPCd>47405</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#           <Amt>250233</Amt>
#         </GrantOrContributionPdDurYrGrp>
# ...
#           <AddressLine1Txt>81 PROSPECT ST</AddressLine1Txt>
#           <CityNm>BROOKLYN</CityNm>
#           <StateAbbreviationCd>NY</StateAbbreviationCd>
#           <ZIPCd>11201</ZIPCd>
#         </USAddress>
#         <GrantDt>2020-08-24</GrantDt>
#         <GrantAmt>100000</GrantAmt>
#         <PurposeOfGrantTxt>VIRTUAL AND DISTANCE LEARNING EFFORTS</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>0</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>NONE TO DATE</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#       <ExpenditureResponsibilityGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>NBCUNIVERSAL MEDIA LLC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>30 ROCKEFELLER PLAZA</AddressLine1Txt>
#           <CityNm>NEW YORK</CityNm>
#           <StateAbbreviationCd>NY</StateAbbreviationCd>
#           <ZIPCd>10112</ZIPCd>
#         </USAddress>
#         <GrantDt>2020-09-24</GrantDt>
#         <GrantAmt>925000</GrantAmt>
#         <PurposeOfGrantTxt>DIGITAL EDUCATION CONTENT FOR FAMILIES AND EDUCATORS DURING PANDEMIC</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>925000</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>08/02/21</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#       <ExpenditureResponsibilityGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>OCEAN GENOMICS INC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>3004 QUAIL HOLLOW TERRACE</AddressLine1Txt>
#           <CityNm>BROOKEVILLE</CityNm>
#           <StateAbbreviationCd>MD</StateAbbreviationCd>
#           <ZIPCd>20833</ZIPCd>
#         </USAddress>
#         <GrantDt>2020-12-30</GrantDt>
#         <GrantAmt>235000</GrantAmt>
#         <PurposeOfGrantTxt>OPEN SCIENCE</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>0</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>02/01/21</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#       <ExpenditureResponsibilityGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>PLOTLY TECHNOLOGIES INC</BusinessNameLine1Txt>
#         </BusinessName>
#         <ForeignAddress>
#           <AddressLine1Txt>5555 GASPE AVE</AddressLine1Txt>
#           <CityNm>MONTREAL</CityNm>
#           <ProvinceOrStateNm>QC</ProvinceOrStateNm>
#           <CountryCd>CA</CountryCd>
#           <ForeignPostalCd>H2T 2A3</ForeignPostalCd>
#         </ForeignAddress>
#         <GrantDt>2020-03-23</GrantDt>
#         <GrantAmt>227451</GrantAmt>
#         <PurposeOfGrantTxt>OPEN SCIENCE</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>227451</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>02/01/21</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#       <ExpenditureResponsibilityGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>QUANSIGHT LLC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>PO BOX 91891</AddressLine1Txt>
#           <CityNm>AUSTIN</CityNm>
#           <StateAbbreviationCd>TX</StateAbbreviationCd>
#           <ZIPCd>78709</ZIPCd>
#         </USAddress>
#         <GrantDt>2020-09-17</GrantDt>
#         <GrantAmt>200000</GrantAmt>
#         <PurposeOfGrantTxt>OPEN SCIENCE</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>200000</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>08/04/21</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#       <ExpenditureResponsibilityGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>READ THE DOCS INC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>18120 2ND AVE</AddressLine1Txt>
#           <CityNm>BEND</CityNm>
#           <StateAbbreviationCd>OR</StateAbbreviationCd>
#           <ZIPCd>97703</ZIPCd>
#         </USAddress>
#         <GrantDt>2020-12-23</GrantDt>
#         <GrantAmt>200000</GrantAmt>
#         <PurposeOfGrantTxt>OPEN SCIENCE</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>0</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>NONE TO DATE</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#       <ExpenditureResponsibilityGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>SEAM SOCIAL LABS INC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>420 EAST 62ND ST</AddressLine1Txt>
#           <CityNm>NEW YORK</CityNm>
#           <StateAbbreviationCd>NY</StateAbbreviationCd>
#           <ZIPCd>10065</ZIPCd>
#         </USAddress>
#         <GrantDt>2020-06-25</GrantDt>
#         <GrantAmt>107500</GrantAmt>
#         <PurposeOfGrantTxt>ALAMEDA COUNTY HOUSING AND COMMUNITY DEVELOPMENT INPUT PILOT</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>86292</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>02/15/21</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#       <ExpenditureResponsibilityGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>URSA COMPUTING INC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>1779 KIRBY PKWY NO 16054</AddressLine1Txt>
#           <CityNm>MEMPHIS</CityNm>
#           <StateAbbreviationCd>TN</StateAbbreviationCd>
#           <ZIPCd>38138</ZIPCd>
#         </USAddress>
#         <GrantDt>2020-12-23</GrantDt>
#         <GrantAmt>215000</GrantAmt>
#         <PurposeOfGrantTxt>OPEN SCIENCE</PurposeOfGrantTxt>
#         <ExpendedByGranteeAmt>0</ExpendedByGranteeAmt>
#         <AnyDiversionByGranteeTxt>NO</AnyDiversionByGranteeTxt>
#         <DatesOfReportsByGranteeTxt>02/15/21</DatesOfReportsByGranteeTxt>
#         <ResultsOfVerificationTxt>N/A</ResultsOfVerificationTxt>
#       </ExpenditureResponsibilityGrp>
#     </ExpenditureResponsibilityStmt>
#     <GeneralExplanationAttachment documentId="RetDoc2258700001">
#       <GeneralExplanationGrp>
#         <FormAndLineReferenceDesc>FORM 990-PF, PART XVII, LINE 2A</FormAndLineReferenceDesc>
#         <MediumExplanationTxt>THE TRUSTEE OF THE FILING ENTITY IS ALSO A MANAGER OF CHAN ZUCKERBERG INITIATIVE LLC ("CZI"). ACCORDINGLY, THE FILING ENTITY TECHNICALLY MAY BE CONSIDERED A RELATED ORGANIZATION OF THE ENTITIES LISTED IN RESPONSE TO PART XVII, LINE 2, GIVEN CZI'S RELATIONSHIP WITH THESE ENTITIES. THE FILING ENTITY, AND THESE ENTITIES, DO NOT SHARE OR EXCHANGE ANY INFORMATION. THE FILING ENTITY'S TRUSTEE IS THE CHIEF EXECUTIVE OFFICER OF FACEBOOK. FACEBOOK ADMINISTERS A FEDERALLY-REGISTERED POLITICAL ACTION COMMITTEE. THERE IS NO RELATIONSHIP BETWEEN FACEBOOK'S PAC AND THE FILING ENTITY. FURTHERMORE, NO INFORMATION IS SHARED OR EXCHANGED BETWEEN THE FILING ENTITY AND FACEBOOK, OR FACEBOOK'S PAC.</MediumExplanationTxt>
#       </GeneralExplanationGrp>
#     </GeneralExplanationAttachment>
#     <InvestmentsCorpStockSchedule documentId="RetDoc2018900001">
#       <InvestmentsCorporateStockGrp>
#         <StockNm>FACEBOOK INC CLASS A</StockNm>
#         <EOYBookValueAmt>959739322</EOYBookValueAmt>
#         <EOYFMVAmt>959739322</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>FACEBOOK INC CLASS B</StockNm>
#         <EOYBookValueAmt>521353722</EOYBookValueAmt>
#         <EOYFMVAmt>521353722</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ZILLOW GROUP INC CLASS A</StockNm>
#         <EOYBookValueAmt>750525</EOYBookValueAmt>
#         <EOYFMVAmt>750525</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>ZILLOW GROUP INC CLASS C</StockNm>
#         <EOYBookValueAmt>808654</EOYBookValueAmt>
#         <EOYFMVAmt>808654</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#       <InvestmentsCorporateStockGrp>
#         <StockNm>RIBBIT LEAP LTD</StockNm>
#         <EOYBookValueAmt>28443000</EOYBookValueAmt>
#         <EOYFMVAmt>28443000</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#     </InvestmentsCorpStockSchedule>
#     <InvestmentsOtherSchedule2 documentId="RetDoc2018100001">
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>OTHER INVESTMENTS</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>5604476</BookValueAmt>
#         <EOYFMVAmt>5604476</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>DOMESTIC EQUITY</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>266083111</BookValueAmt>
#         <EOYFMVAmt>266083111</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>INTERNATIONAL DEVELOPED EQUITY</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>645099363</BookValueAmt>
#         <EOYFMVAmt>645099363</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>EMERGING MARKETS</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>673822658</BookValueAmt>
#         <EOYFMVAmt>673822658</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>ABSOLUTE RETURN</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>1532965812</BookValueAmt>
#         <EOYFMVAmt>1532965812</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>PRIVATE EQUITY</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>FMV</ListedAtCostOrFMVCd>
#         <BookValueAmt>358768594</BookValueAmt>
#         <EOYFMVAmt>358768594</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#     </InvestmentsOtherSchedule2>
#     <LegalFeesSchedule documentId="RetDoc2002100001">
#       <LegalFeesGrp>
#         <CategoryTxt>LEGAL FEES</CategoryTxt>
#         <LegalFeesAmt>226949</LegalFeesAmt>
#         <NetInvestmentIncomeAmt>115025</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>280034</DisbursementsCharitablePrpsAmt>
#       </LegalFeesGrp>
#     </LegalFeesSchedule>
#     <OtherAssetsSchedule documentId="RetDoc2046600001">
#       <OtherAssetsScheduleGrp>
#         <Desc>PROGRAM-RELATED INVESTMENTS</Desc>
#         <BOYBookValueAmt>15087071</BOYBookValueAmt>
#         <EOYBookValueAmt>41166637</EOYBookValueAmt>
#         <EOYFMVAmt>41166637</EOYFMVAmt>
#       </OtherAssetsScheduleGrp>
#     </OtherAssetsSchedule>
#     <OtherExpensesSchedule documentId="RetDoc2003200001">
#       <OtherExpensesScheduleGrp>
#         <Desc>LICENSES AND FEES</Desc>
#         <RevenueAndExpensesPerBooksAmt>310</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>310</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#       <OtherExpensesScheduleGrp>
#         <Desc>ALTERNATIVE INVESTMENT DEDUCTIONS</Desc>
#         <RevenueAndExpensesPerBooksAmt>0</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>21736384</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#     </OtherExpensesSchedule>
#     <OtherIncomeSchedule2 documentId="RetDoc2001500001">
#       <OtherIncomeDetail>
#         <Desc>OTHER INVESTMENT INCOME</Desc>
#         <RevenueAndExpensesPerBooksAmt>1000</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>1000</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#       </OtherIncomeDetail>
#       <OtherIncomeDetail>
#         <Desc>ALTERNATIVE INVESTMENT INCOME</Desc>
#         <RevenueAndExpensesPerBooksAmt>6390847</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>3520791</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#       </OtherIncomeDetail>
#     </OtherIncomeSchedule2>
#     <OtherIncreasesSchedule documentId="RetDoc2049700001">
#       <OtherIncreasesDetail>
#         <Desc>UNREALIZED GAIN</Desc>
#         <Amt>885982468</Amt>
#       </OtherIncreasesDetail>
#     </OtherIncreasesSchedule>
#     <OtherLiabilitiesSchedule documentId="RetDoc2065700001">
#       <OtherLiabilitiesDetail>
#         <Desc>EXCISE TAX PAYABLE</Desc>
#         <BOYBookValueAmt>4036000</BOYBookValueAmt>
#         <EOYBookValueAmt>2000000</EOYBookValueAmt>
#       </OtherLiabilitiesDetail>
#       <OtherLiabilitiesDetail>
#         <Desc>DEFERRED EXCISE TAX LIABILITY</Desc>
#         <BOYBookValueAmt>18018000</BOYBookValueAmt>
#         <EOYBookValueAmt>30000000</EOYBookValueAmt>
#       </OtherLiabilitiesDetail>
#     </OtherLiabilitiesSchedule>
#     <OtherProfessionalFeesSchedule documentId="RetDoc2002300001">
#       <OtherProfessionalFeesDetail>
#         <CategoryTxt>OTHER PROFESSIONAL FEES</CategoryTxt>
#         <Amt>932677</Amt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>915000</DisbursementsCharitablePrpsAmt>
#       </OtherProfessionalFeesDetail>
#       <OtherProfessionalFeesDetail>
#         <CategoryTxt>INVESTMENT MANAGEMENT FEES</CategoryTxt>
#         <Amt>750000</Amt>
#         <NetInvestmentIncomeAmt>750000</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </OtherProfessionalFeesDetail>
#     </OtherProfessionalFeesSchedule>
#     <TaxesSchedule documentId="RetDoc2002500001">
#       <TaxesDetail>
#         <CategoryTxt>EXCISE TAX</CategoryTxt>
#         <Amt>15946000</Amt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </TaxesDetail>
#     </TaxesSchedule>
#     <TransfersToControlledEntities documentId="RetDoc2205000001">
#       <TransfersToControlledEntGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>BFF PRESERVATION SIDE CAR LLC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>28 LIBERTY ST 34TH FLOOR</AddressLine1Txt>
#           <CityNm>NEW YORK</CityNm>
#           <StateAbbreviationCd>NY</StateAbbreviationCd>
#           <ZIPCd>10005</ZIPCd>
#         </USAddress>
#         <EIN>842820789</EIN>
#         <Desc>CAPITAL CONTRIBUTION TO PRI THAT IS NOT AN EXCESS BUSINESS HOLDING</Desc>
#         <Amt>10000000</Amt>
#       </TransfersToControlledEntGrp>
#       <TransfersToControlledEntGrp>
#         <BusinessName>
#           <BusinessNameLine1Txt>THE BAY'S FUTURE FUND LLC</BusinessNameLine1Txt>
#         </BusinessName>
#         <USAddress>
#           <AddressLine1Txt>28 LIBERTY ST 34TH FLOOR</AddressLine1Txt>
#           <CityNm>NEW YORK</CityNm>
#           <StateAbbreviationCd>NY</StateAbbreviationCd>
#           <ZIPCd>10005</ZIPCd>
#         </USAddress>
#         <EIN>611926603</EIN>
#         <Desc>CAPITAL CONTRIBUTION TO PRI THAT IS NOT AN EXCESS BUSINESS HOLDING</Desc>
#         <Amt>18381908</Amt>
#       </TransfersToControlledEntGrp>
#       <TotalAmt>28381908</TotalAmt>
#     </TransfersToControlledEntities>
#   </ReturnData>
# </Return>

# %%
from bs4 import BeautifulSoup

# %%
zuck_data = BeautifulSoup(zuck_xml, "xml")
type(zuck_data)
# Out:
# bs4.BeautifulSoup

# %%
zuck_officer_data = zuck_data.select("OfficerDirTrstKeyEmplGrp")
zuck_officer_data
# Out:
# [<OfficerDirTrstKeyEmplGrp>
#  <PersonNm>MARK ZUCKERBERG</PersonNm>
#  <USAddress>
#  <AddressLine1Txt>314 LYTTON AVE</AddressLine1Txt>
#  <CityNm>PALO ALTO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94301</ZIPCd>
#  </USAddress>
#  <TitleTxt>TRUSTEE</TitleTxt>
#  <AverageHrsPerWkDevotedToPosRt>1.50</AverageHrsPerWkDevotedToPosRt>
#  <CompensationAmt>0</CompensationAmt>
#  <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#  <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#  </OfficerDirTrstKeyEmplGrp>]

# %%
import pandas as pd

# %%
officer_data = zuck_data.find_all("OfficerDirTrstKeyEmplGrp")

officer_list = []

for officer in officer_data:
    officer_dict = {}
    name = officer.find("PersonNm")
    officer_dict["name"] = name.text
    
    title = officer.find("TitleTxt")
    officer_dict["title"] = title.text
    
    officer_list.append(officer_dict)

# %%
officer_list
# Out:
# [{'name': 'MARK ZUCKERBERG', 'title': 'TRUSTEE'}]

# %%
zuck_officer_df = pd.DataFrame(officer_list)
zuck_officer_df
# Out:
#               name    title
# 0  MARK ZUCKERBERG  TRUSTEE

# %%
recipient_data = zuck_data.find_all("GrantOrContributionPdDurYrGrp")
recipient_data
# Out:
# [<GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ADDGENE INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>490 ARSENAL WAY SUITE 100</AddressLine1Txt>
#  <CityNm>WATERTOWN</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02472</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>1050659</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ALAMEDA COUNTY PUBLIC HEALTH DEPARTMENT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1000 BROADWAY SUITE 500</AddressLine1Txt>
#  <CityNm>OAKLAND</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94607</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BATTELLE FOR KIDS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>4525 TRUEMAN BLVD</AddressLine1Txt>
#  <CityNm>HILLIARD</CityNm>
#  <StateAbbreviationCd>OH</StateAbbreviationCd>
#  <ZIPCd>43026</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>STUDENT ASSESSMENT RESEARCH</GrantOrContributionPurposeTxt>
#  <Amt>80000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BAYLOR COLLEGE OF MEDICINE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>ONE BAYLOR PLAZA</AddressLine1Txt>
#  <CityNm>HOUSTON</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>77030</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>666431</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BELOVED COMMUNITY INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3157 GENTILLY BLVD 176</AddressLine1Txt>
#  <CityNm>NEW ORLEANS</CityNm>
#  <StateAbbreviationCd>LA</StateAbbreviationCd>
#  <ZIPCd>70122</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>900000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BEN-GURION UNIVERSITY OF THE NEGEV</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>PO BOX 653</AddressLine1Txt>
#  <CityNm>BEERSHEVA</CityNm>
#  <CountryCd>IS</CountryCd>
#  <ForeignPostalCd>8410501</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>181760</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BLACK TEACHER COLLABORATIVE INCORPORATED</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2170 BOULEVARD GRANADA SW</AddressLine1Txt>
#  <CityNm>ATLANTA</CityNm>
#  <StateAbbreviationCd>GA</StateAbbreviationCd>
#  <ZIPCd>30311</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>650000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BOSTON DEBATE LEAGUE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1542 TREMONT ST</AddressLine1Txt>
#  <CityNm>BOSTON</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02120</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>DEBATE-INSPIRED CLASSROOMS</GrantOrContributionPurposeTxt>
#  <Amt>65000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BROAD INSTITUTE INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>415 MAIN ST</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02142</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>925403</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BROAD INSTITUTE INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>415 MAIN ST</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02142</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>972129</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BROAD INSTITUTE INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>415 MAIN ST</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02142</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1072581</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>CENTER FOR COLLABORATIVE EDUCATION INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>33 HARRISON AVE 6TH FLOOR</AddressLine1Txt>
#  <CityNm>BOSTON</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02111</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>HOLISTIC SCHOOL QUALITY MEASURES</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>CHAN ZUCKERBERG BIOHUB INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>499 ILLINOIS ST</AddressLine1Txt>
#  <CityNm>SAN FRANCISCO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94158</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>MEDICAL RESEARCH</GrantOrContributionPurposeTxt>
#  <Amt>60000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>CHANCELLOR MASTERS &amp; SCHOLARS OF THE UNIVERSITY OF OXFORD</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>JOHN RADCLIFFE HOSPITAL LEVEL 3</AddressLine1Txt>
#  <CityNm>OXFORD</CityNm>
#  <CountryCd>UK</CountryCd>
#  <ForeignPostalCd>OX3 9DU</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1142713</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>CITIZENS OF THE WORLD CHARTER SCHOOLS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>5371 WILSHIRE BLVD SUITE 210</AddressLine1Txt>
#  <CityNm>LOS ANGELES</CityNm>
#  <ProvinceOrStateNm>CALIFORNIA</ProvinceOrStateNm>
#  <CountryCd>UK</CountryCd>
#  <ForeignPostalCd>90036</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>PEER COACHING AND IDENTITY PROJECTS</GrantOrContributionPurposeTxt>
#  <Amt>475000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>COLD SPRING HARBOR LABORATORY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 100 ONE BUNGTOWN RD</AddressLine1Txt>
#  <CityNm>COLD SPRING HARBOR</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>11724</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>MEDRXIV-BIORXIV PROJECT</GrantOrContributionPurposeTxt>
#  <Amt>946052</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>CONTRA COSTA REGIONAL HEALTH FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>50 DOUGLAS DR SUITE 310A</AddressLine1Txt>
#  <CityNm>MARTINEZ</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94553</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>RAPID RESPONSE TO COVID-19</GrantOrContributionPurposeTxt>
#  <Amt>500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>CURII CORPORATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>212 ELM ST 3RD FLOOR</AddressLine1Txt>
#  <CityNm>SOMERVILLE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02144</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>OPEN SCIENCE</GrantOrContributionPurposeTxt>
#  <Amt>180000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>DONORSCHOOSEORG</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>134 WEST 37TH ST 11TH FLOOR</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10018</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>DISTANCE LEARNING PROJECTS IN RESPONSE TO COVID-19</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>DUKE UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>BOX 90581</AddressLine1Txt>
#  <CityNm>DURHAM</CityNm>
#  <StateAbbreviationCd>NC</StateAbbreviationCd>
#  <ZIPCd>27708</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>137170</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ECONOMIC INNOVATION GROUP</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>616 H ST NW SUITE 550</AddressLine1Txt>
#  <CityNm>WASHINGTON</CityNm>
#  <StateAbbreviationCd>DC</StateAbbreviationCd>
#  <ZIPCd>20001</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>IMPROVE STUDENT OUTCOMES</GrantOrContributionPurposeTxt>
#  <Amt>225000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>EDITORIAL PROJECTS IN EDUCATION INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>6935 ARLINGTON RD SUITE 100</AddressLine1Txt>
#  <CityNm>BETHESDA</CityNm>
#  <StateAbbreviationCd>MD</StateAbbreviationCd>
#  <ZIPCd>20814</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>JOURNALISM FOCUSED ON EDUCATION/DIGITAL TRANSFORMATION INITIATIVE</GrantOrContributionPurposeTxt>
#  <Amt>750000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>EDUCATION LEADERS OF COLOR INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>16430 JANINE DR</AddressLine1Txt>
#  <CityNm>WHITTIER</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>90603</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT/INFRASTRUCTURE</GrantOrContributionPurposeTxt>
#  <Amt>1100000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>EDUCATIONAL SERVICE CENTER OF NORTHEAST OHIO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>6393 OAK TREE BLVD</AddressLine1Txt>
#  <CityNm>INDEPENDENCE</CityNm>
#  <StateAbbreviationCd>OH</StateAbbreviationCd>
#  <ZIPCd>44131</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>WHOLE CHILD PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>EQUAL OPPORTUNITY SCHOOLS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>5601 6TH AVE SOUTH SUITE 258</AddressLine1Txt>
#  <CityNm>SEATTLE</CityNm>
#  <StateAbbreviationCd>WA</StateAbbreviationCd>
#  <ZIPCd>98108</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ETHICS AND RELIGIOUS LIBERTY COMMISSION OF THE SOUTHERN BAPTIST CONVENTION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>901 COMMERCE ST SUITE 550</AddressLine1Txt>
#  <CityNm>NASHVILLE</CityNm>
#  <StateAbbreviationCd>TN</StateAbbreviationCd>
#  <ZIPCd>37203</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>CRIMINAL JUSTICE REFORM</GrantOrContributionPurposeTxt>
#  <Amt>90000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>FIRST NATIONS DEVELOPMENT INSTITUTE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2432 MAIN ST 2ND FLOOR</AddressLine1Txt>
#  <CityNm>LONGMONT</CityNm>
#  <StateAbbreviationCd>CO</StateAbbreviationCd>
#  <ZIPCd>80501</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>NATIVE YOUTH DEVELOPMENT IN EDUCATION, MENTAL HEALTH AND IDENTITY</GrantOrContributionPurposeTxt>
#  <Amt>1600000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>FRED HUTCHINSON CANCER RESEARCH CENTER</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 19024 J5-200</AddressLine1Txt>
#  <CityNm>SEATTLE</CityNm>
#  <StateAbbreviationCd>WA</StateAbbreviationCd>
#  <ZIPCd>98109</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>333203</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>FWDUS EDUCATION FUND INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 34506</AddressLine1Txt>
#  <CityNm>WASHINGTON</CityNm>
#  <StateAbbreviationCd>DC</StateAbbreviationCd>
#  <ZIPCd>20043</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>6521733</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GATES PHILANTHROPY PARTNERS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 23350</AddressLine1Txt>
#  <CityNm>SEATTLE</CityNm>
#  <StateAbbreviationCd>WA</StateAbbreviationCd>
#  <ZIPCd>98102</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>COVID-19 RESEARCH AND RESPONSE</GrantOrContributionPurposeTxt>
#  <Amt>20000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GATES PHILANTHROPY PARTNERS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 23350</AddressLine1Txt>
#  <CityNm>SEATTLE</CityNm>
#  <StateAbbreviationCd>WA</StateAbbreviationCd>
#  <ZIPCd>98102</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>CARDIOVASCULAR HEALTH AND INFRASTRUCTURE INITIATIVE</GrantOrContributionPurposeTxt>
#  <Amt>10000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GENOME INSTITUTE OF SINGAPORE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>60 BIOPOLIS ST GENOME 02-01</AddressLine1Txt>
#  <CityNm>SINGAPORE</CityNm>
#  <CountryCd>SN</CountryCd>
#  <ForeignPostalCd>138672</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>398731</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GENOME RESEARCH LIMITED</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>GENOME CAMPUS HINXTON</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <CountryCd>UK</CountryCd>
#  <ForeignPostalCd>CB10 1SA</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>786291</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GREATER KANAWHA VALLEY FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 3041</AddressLine1Txt>
#  <CityNm>CHARLESTON</CityNm>
#  <StateAbbreviationCd>WV</StateAbbreviationCd>
#  <ZIPCd>25301</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>WEST VIRGINIA JUSTICE REFORM FUND</GrantOrContributionPurposeTxt>
#  <Amt>390000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>INDIANA UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>400 E 7TH ST ROOM 501</AddressLine1Txt>
#  <CityNm>BLOOMINGTON</CityNm>
#  <StateAbbreviationCd>IN</StateAbbreviationCd>
#  <ZIPCd>47405</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>250233</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>INSIGHTS FOR EDUCATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>TANNENBACHSTRASSE 22</AddressLine1Txt>
#  <CityNm>OBERRIEDEN</CityNm>
#  <CountryCd>SZ</CountryCd>
#  <ForeignPostalCd>8942</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>EDUCATION RESEARCH</GrantOrContributionPurposeTxt>
#  <Amt>195000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>INSIGHTS FOR EDUCATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>TANNENBACHSTRASSE 22</AddressLine1Txt>
#  <CityNm>OBERRIEDEN</CityNm>
#  <CountryCd>SZ</CountryCd>
#  <ForeignPostalCd>8942</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>COVID-19 RESEARCH AND RESPONSE</GrantOrContributionPurposeTxt>
#  <Amt>60000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>INTERNATIONAL SOCIETY FOR TECHNOLOGY IN EDUCATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 45772</AddressLine1Txt>
#  <CityNm>BALTIMORE</CityNm>
#  <StateAbbreviationCd>MD</StateAbbreviationCd>
#  <ZIPCd>21297</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>EDSURGE INITIATIVE</GrantOrContributionPurposeTxt>
#  <Amt>200000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>JOHNS HOPKINS UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1101 E 33RD ST SUITE B001</AddressLine1Txt>
#  <CityNm>BALTIMORE</CityNm>
#  <StateAbbreviationCd>MD</StateAbbreviationCd>
#  <ZIPCd>21218</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>COVID-19 RESEARCH AND RESPONSE</GrantOrContributionPurposeTxt>
#  <Amt>2000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>JOSLIN DIABETES CENTER INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>ONE JOSLIN PLACE</AddressLine1Txt>
#  <CityNm>BOSTON</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02215</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>475464</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>KAROLINSKA INSTITUTET</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>SCHLEES VAG 2</AddressLine1Txt>
#  <CityNm>STOCKHOLM</CityNm>
#  <CountryCd>SW</CountryCd>
#  <ForeignPostalCd>171 77</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>125000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>KNOWLEDGEWORKS FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>312 PLUM ST SUITE 950</AddressLine1Txt>
#  <CityNm>CINCINNATI</CityNm>
#  <StateAbbreviationCd>OH</StateAbbreviationCd>
#  <ZIPCd>45202</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>LIFTED INCORPORATED</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>81 PROSPECT ST</AddressLine1Txt>
#  <CityNm>BROOKLYN</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>11201</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>VIRTUAL AND DISTANCE LEARNING EFFORTS</GrantOrContributionPurposeTxt>
#  <Amt>100000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>LOCUS IMPACT INVESTING</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>7814 CAROUSEL LANE</AddressLine1Txt>
#  <CityNm>RICHMOND</CityNm>
#  <StateAbbreviationCd>VA</StateAbbreviationCd>
#  <ZIPCd>23294</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>COMMUNITY INVESTMENT GUARANTEE POOL</GrantOrContributionPurposeTxt>
#  <Amt>69000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>LOUISIANA PAROLE PROJECT INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 2029</AddressLine1Txt>
#  <CityNm>BATON ROUGE</CityNm>
#  <StateAbbreviationCd>LA</StateAbbreviationCd>
#  <ZIPCd>70821</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED FUNDING TO SECOND LOOK ALLIANCE</GrantOrContributionPurposeTxt>
#  <Amt>75000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NATIONWIDE CHILDREN'S HOSPITAL FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>525 EAST MOUND ST</AddressLine1Txt>
#  <CityNm>COLUMBUS</CityNm>
#  <StateAbbreviationCd>OH</StateAbbreviationCd>
#  <ZIPCd>43215</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>ESTABLISH SCHOOL-BASED CARE SYSTEMS</GrantOrContributionPurposeTxt>
#  <Amt>1950500</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NATIVE AMERICAN COMMUNITY ACADEMY FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1000 INDIAN SCHOOL RD NW</AddressLine1Txt>
#  <CityNm>ALBUQUERQUE</CityNm>
#  <StateAbbreviationCd>NM</StateAbbreviationCd>
#  <ZIPCd>87104</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>LAND-BASED LEARNING</GrantOrContributionPurposeTxt>
#  <Amt>650000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NBCUNIVERSAL MEDIA LLC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>30 ROCKEFELLER PLAZA</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10112</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>DIGITAL EDUCATION CONTENT FOR FAMILIES AND EDUCATORS DURING PANDEMIC</GrantOrContributionPurposeTxt>
#  <Amt>925000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NEW SCHOOLS FUND</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1616 FRANKLIN ST 2ND FLOOR</AddressLine1Txt>
#  <CityNm>OAKLAND</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94612</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>MATH EXECUTIVE FUNCTION PROJECT</GrantOrContributionPurposeTxt>
#  <Amt>7030000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NEW SCHOOLS FUND</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1616 FRANKLIN ST 2ND FLOOR</AddressLine1Txt>
#  <CityNm>OAKLAND</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94612</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>ADVANCED EDUCATION RESEARCH &amp; DEVELOPMENT FUND</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NEW SCHOOLS FUND</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1616 FRANKLIN ST 2ND FLOOR</AddressLine1Txt>
#  <CityNm>OAKLAND</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94612</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>7550000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NEW SCHOOLS FUND</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1616 FRANKLIN ST 2ND FLOOR</AddressLine1Txt>
#  <CityNm>OAKLAND</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94612</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>DIVERSE LEADERS PROGRAM</GrantOrContributionPurposeTxt>
#  <Amt>2450000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NEW VENTURE FUND</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1201 CONNECTICUT AVE NW SUITE 300</AddressLine1Txt>
#  <CityNm>WASHINGTON</CityNm>
#  <StateAbbreviationCd>DC</StateAbbreviationCd>
#  <ZIPCd>20036</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>STUDENT EXPERIENCE RESEARCH NETWORK</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NEW YORK GENOME CENTER INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>101 AVENUE OF THE AMERICAS</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10013</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>506146</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NEZ PERCE TRIBE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>120 BEVER GRADE/PO BOX 365</AddressLine1Txt>
#  <CityNm>LAPWAI</CityNm>
#  <StateAbbreviationCd>ID</StateAbbreviationCd>
#  <ZIPCd>83540</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>CULTURALLY-RESPONSIVE TEACHING</GrantOrContributionPurposeTxt>
#  <Amt>650000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NORTHEASTERN UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>360 HUNTINGTON AVE</AddressLine1Txt>
#  <CityNm>BOSTON</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02115</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>133184</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>NORTHWESTERN UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>633 CLARK ST</AddressLine1Txt>
#  <CityNm>EVANSTON</CityNm>
#  <StateAbbreviationCd>IL</StateAbbreviationCd>
#  <ZIPCd>60208</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1394827</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>OCEAN GENOMICS INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3004 QUAIL HOLLOW TERRACE</AddressLine1Txt>
#  <CityNm>BROOKEVILLE</CityNm>
#  <StateAbbreviationCd>MD</StateAbbreviationCd>
#  <ZIPCd>20833</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>OPEN SCIENCE</GrantOrContributionPurposeTxt>
#  <Amt>235000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PLOTLY TECHNOLOGIES INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>5555 GASPE AVE</AddressLine1Txt>
#  <CityNm>MONTREAL</CityNm>
#  <ProvinceOrStateNm>QC</ProvinceOrStateNm>
#  <CountryCd>CA</CountryCd>
#  <ForeignPostalCd>H2T 2A3</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>OPEN SCIENCE</GrantOrContributionPurposeTxt>
#  <Amt>227451</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PRESIDENT AND FELLOWS OF HARVARD COLLEGE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1033 MASSACHUSETTS AVE SUITE 3</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02138</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>PERSONALIZED LEARNING PROJECT</GrantOrContributionPurposeTxt>
#  <Amt>6000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PRESIDENT AND FELLOWS OF HARVARD COLLEGE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1033 MASSACHUSETTS AVE SUITE 3</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02138</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>CREATION OF OPPORTUNITY INSIGHTS INSTITUTE</GrantOrContributionPurposeTxt>
#  <Amt>2500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PRESIDENT AND FELLOWS OF HARVARD COLLEGE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1033 MASSACHUSETTS AVE SUITE 3</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02138</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1328155</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PRESIDENT AND FELLOWS OF HARVARD COLLEGE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1033 MASSACHUSETTS AVE SUITE 3</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02138</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>669459</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PRESIDENT AND FELLOWS OF HARVARD COLLEGE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>1033 MASSACHUSETTS AVE SUITE 3</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <ProvinceOrStateNm>QC</ProvinceOrStateNm>
#  <CountryCd>CA</CountryCd>
#  <ForeignPostalCd>02138</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>515980</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PRESIDENT AND FELLOWS OF HARVARD COLLEGE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1033 MASSACHUSETTS AVE SUITE 3</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02138</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>666080</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>QUANSIGHT LLC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 91891</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78709</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>OPEN SCIENCE</GrantOrContributionPurposeTxt>
#  <Amt>200000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>READ THE DOCS INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>18120 2ND AVE</AddressLine1Txt>
#  <CityNm>BEND</CityNm>
#  <StateAbbreviationCd>OR</StateAbbreviationCd>
#  <ZIPCd>97703</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>OPEN SCIENCE</GrantOrContributionPurposeTxt>
#  <Amt>200000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REDWOOD EMPIRE FOOD BANK</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3990 BRICKWAY BLVD</AddressLine1Txt>
#  <CityNm>SANTA ROSA</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>95403</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>50000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REGENTS OF THE UNIVERSITY OF CALIFORNIA BERKELEY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2195 HEARST AVE ROOM 120 MC 1104</AddressLine1Txt>
#  <CityNm>BERKELEY</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94704</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1118272</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REGENTS OF THE UNIVERSITY OF CALIFORNIA LOS ANGELES</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1285 FRANZ HALL BOX 951563</AddressLine1Txt>
#  <CityNm>LOS ANGELES</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>90095</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>DEVELOPMENT OF COURSEKATA HIGH SCHOOL COURSE</GrantOrContributionPurposeTxt>
#  <Amt>1300000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REGENTS OF THE UNIVERSITY OF CALIFORNIA SAN DIEGO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>9500 GILMAN DR</AddressLine1Txt>
#  <CityNm>LA JOLLA</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>92093</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>133688</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REGENTS OF THE UNIVERSITY OF CALIFORNIA SAN DIEGO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>9500 GILMAN DR</AddressLine1Txt>
#  <CityNm>LA JOLLA</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>92093</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>667114</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REGENTS OF THE UNIVERSITY OF MICHIGAN</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>500 SOUTH STATE ST</AddressLine1Txt>
#  <CityNm>ANN ARBOR</CityNm>
#  <StateAbbreviationCd>MI</StateAbbreviationCd>
#  <ZIPCd>48109</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>449567</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REGENTS OF THE UNIVERSITY OF MICHIGAN</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>500 SOUTH STATE ST</AddressLine1Txt>
#  <CityNm>ANN ARBOR</CityNm>
#  <ProvinceOrStateNm>MICHIGAN</ProvinceOrStateNm>
#  <CountryCd>SW</CountryCd>
#  <ForeignPostalCd>48109</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>852342</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>REGENTS OF THE UNIVERSITY OF SAN FRANCISCO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3333 CALIFORNIA ST SUITE 315</AddressLine1Txt>
#  <CityNm>SAN FRANCISCO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94143</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>COVID-19 RESEARCH AND RESPONSE</GrantOrContributionPurposeTxt>
#  <Amt>13600000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ROSWELL PARK ALLIANCE FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>ELM CARLTON ST</AddressLine1Txt>
#  <CityNm>BUFFALO</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>14240</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>652525</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ROYAL INSTITUTE OF TECHNOLOGY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>BRINELLVAGEN 8</AddressLine1Txt>
#  <CityNm>STOCKHOLM</CityNm>
#  <CountryCd>SW</CountryCd>
#  <ForeignPostalCd>114 28</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SAN FRANCISCO STATE UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1600 HOLLOWAY AVE</AddressLine1Txt>
#  <CityNm>SAN FRANCISCO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94132</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>COMMUNITY RESPONSIVE EDUCATION</GrantOrContributionPurposeTxt>
#  <Amt>216413</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SEAM SOCIAL LABS INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>420 EAST 62ND ST</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10065</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>ALAMEDA COUNTY HOUSING AND COMMUNITY DEVELOPMENT INPUT PILOT</GrantOrContributionPurposeTxt>
#  <Amt>107500</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SIERRA HEALTH FOUNDATION CENTER FOR HEALTH PROGRAM MANAGEMENT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1321 GARDEN HWY SUITE 210</AddressLine1Txt>
#  <CityNm>SACRAMENTO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>95833</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>CALIFORNIA FOR ALL COVID-19 PUBLIC AWARENESS CAMPAIGN</GrantOrContributionPurposeTxt>
#  <Amt>2000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SIERRA HEALTH FOUNDATION CENTER FOR HEALTH PROGRAM MANAGEMENT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1321 GARDEN HWY SUITE 210</AddressLine1Txt>
#  <CityNm>SACRAMENTO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>95833</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>IMPROVE HEALTH FOR ADOLESCENT BOYS AND YOUNG MEN OF COLOR</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SILICON VALLEY COMMUNITY FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2440 WEST EL CAMINO REAL SUITE 300</AddressLine1Txt>
#  <CityNm>MOUNTAIN VIEW</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94040</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>DIGITAL TRANSFORMATION PROJECT</GrantOrContributionPurposeTxt>
#  <Amt>450000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>TEACH FOR AMERICA</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>606 S OLIVE ST 300</AddressLine1Txt>
#  <CityNm>LOS ANGELES</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>90014</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE BOARD OF TRUSTEES OF STANFORD UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3160 PORTER DR SUITE 100</AddressLine1Txt>
#  <CityNm>PALO ALTO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94304</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>323342</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE FREEDOM BOUND CENTER</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>4101 67TH ST</AddressLine1Txt>
#  <CityNm>SACRAMENTO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>95820</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>YOUTH WELLNESS INDEX</GrantOrContributionPurposeTxt>
#  <Amt>250000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE GENERAL HOSPITAL CORPORATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>55 FRUIT ST</AddressLine1Txt>
#  <CityNm>BOSTON</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02114</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>275000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE GENERAL HOSPITAL CORPORATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>55 FRUIT ST</AddressLine1Txt>
#  <CityNm>BOSTON</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02114</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1342938</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE PENNSYLVANIA STATE UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>110 TECHNOLOGY CENTER BUILDING</AddressLine1Txt>
#  <CityNm>UNIVERSITY PARK</CityNm>
#  <StateAbbreviationCd>PA</StateAbbreviationCd>
#  <ZIPCd>16802</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>ASSET-BASED DIALOGIC TEACHING</GrantOrContributionPurposeTxt>
#  <Amt>590000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE PRIMARY SCHOOL - EAST PALO ALTO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2086 CLARKE ST</AddressLine1Txt>
#  <CityNm>EAST PALO ALTO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94303</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>13466321</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE TRUSTEES OF THE UNIVERSITY OF PENNSYLVANIA</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3451 WALNUT ST</AddressLine1Txt>
#  <CityNm>PHILADELPHIA</CityNm>
#  <StateAbbreviationCd>PA</StateAbbreviationCd>
#  <ZIPCd>19104</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>928960</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE UNIVERSITY OF TEXAS AT AUSTIN</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3925 WEST BRAKER LANE BUILDING 156</AddressLine1Txt>
#  <AddressLine2Txt>SUITE 3340</AddressLine2Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78759</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>HOGG FOUNDATION FOR MENTAL HEALTH</GrantOrContributionPurposeTxt>
#  <Amt>1100000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>TRUSTEES OF COLUMBIA UNIVERSITY IN THE CITY OF NEW YORK</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>622 WEST 113TH ST</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10032</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>TRUSTEES OF COLUMBIA UNIVERSITY IN THE CITY OF NEW YORK</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>622 WEST 113TH ST</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10032</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>COVID RECOVERY CORPS</GrantOrContributionPurposeTxt>
#  <Amt>893495</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>TURNAROUND FOR CHILDREN INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>25 WEST 45TH ST 6TH FLOOR</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10036</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>GENERAL OPERATING SUPPORT</GrantOrContributionPurposeTxt>
#  <Amt>600000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNITED WAY OF SUMMIT COUNTY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>37 NORTH HIGH ST</AddressLine1Txt>
#  <CityNm>AKRON</CityNm>
#  <StateAbbreviationCd>OH</StateAbbreviationCd>
#  <ZIPCd>44308</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>WHOLE CHILD PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNIVERSITY OF ARIZONA FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1111 NORTH CHERRY AVE</AddressLine1Txt>
#  <CityNm>TUCSON</CityNm>
#  <StateAbbreviationCd>AZ</StateAbbreviationCd>
#  <ZIPCd>85721</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>ASSET-BASED DIALOGIC TEACHING</GrantOrContributionPurposeTxt>
#  <Amt>60369</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNIVERSITY OF CALIFORNIA SAN FRANCISCO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>220 MONTGOMERY ST FLOOR 5</AddressLine1Txt>
#  <CityNm>SAN FRANCISCO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94145</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1008094</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNIVERSITY OF CHICAGO</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>5235 SOUTH HARPER CT</AddressLine1Txt>
#  <CityNm>CHICAGO</CityNm>
#  <StateAbbreviationCd>IL</StateAbbreviationCd>
#  <ZIPCd>60615</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>525642</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNIVERSITY OF SOUTHERN CALIFORNIA</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>3720 S FLOWER ST CUB 303-28</AddressLine1Txt>
#  <CityNm>LOS ANGELES</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>90089</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>EDUCATOR SUPPORT TO PROMOTE SELF-DIRECTION AMONG ADOLESCENT GIRLS OF COLOR</GrantOrContributionPurposeTxt>
#  <Amt>650000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNIVERSITY OF TEXAS FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 250</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78767</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>1330515</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNIVERSITY OF WASHINGTON</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>4333 BROOKLYN AVE NE BOX 359505</AddressLine1Txt>
#  <CityNm>SEATTLE</CityNm>
#  <StateAbbreviationCd>WA</StateAbbreviationCd>
#  <ZIPCd>98195</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>833334</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>URSA COMPUTING INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1779 KIRBY PKWY NO 16054</AddressLine1Txt>
#  <CityNm>MEMPHIS</CityNm>
#  <StateAbbreviationCd>TN</StateAbbreviationCd>
#  <ZIPCd>38138</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>NC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>OPEN SCIENCE</GrantOrContributionPurposeTxt>
#  <Amt>215000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>WASHINGTON UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>CAMPUS BOX 1082 ONE BROOKINGS DR</AddressLine1Txt>
#  <CityNm>ST LOUIS</CityNm>
#  <StateAbbreviationCd>MO</StateAbbreviationCd>
#  <ZIPCd>63130</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>566667</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>WEIZMANN INSTITUTE OF SCIENCE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>234 HERZL ST</AddressLine1Txt>
#  <CityNm>REHOVOT</CityNm>
#  <CountryCd>IS</CountryCd>
#  <ForeignPostalCd>76100</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SEED NETWORK GRANT</GrantOrContributionPurposeTxt>
#  <Amt>668477</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>WESTED</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>730 HARRISON ST</AddressLine1Txt>
#  <CityNm>SAN FRANCISCO</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94107</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>STRATEGIC LITERACY INITIATIVE</GrantOrContributionPurposeTxt>
#  <Amt>650000</Amt>
#  </GrantOrContributionPdDurYrGrp>]

# %%
recipient_list = []

for recipient in recipient_data:
    recipient_dict = {}
    recipient_name = recipient.find("BusinessNameLine1Txt")
    recipient_dict["business_name"] = recipient_name.text
    
    recipient_amount = recipient.find("Amt")
    recipient_dict["amount_received"] = recipient_amount.text
    
    recipient_purpose = recipient.find("GrantOrContributionPurposeTxt")
    recipient_dict["purpose"] = recipient_purpose.text

    recipient_city = recipient.find("CityNm")
    recipient_dict["city"] = recipient_city.text
    
    recipient_state = recipient.find("StateAbbreviationCd")
    recipient_dict["state"] = recipient_state.text
    recipient_list.append(recipient_dict)

    print(recipient_list)
    print("******")
# Out:
# [{'business_name': 'ADDGENE INC', 'amount_received': '1050659', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'WATERTOWN', 'state': 'MA'}]
# ******
# [{'business_name': 'ADDGENE INC', 'amount_received': '1050659', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'WATERTOWN', 'state': 'MA'}, {'business_name': 'ALAMEDA COUNTY PUBLIC HEALTH DEPARTMENT', 'amount_received': '500000', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'OAKLAND', 'state': 'CA'}]
# ******
# [{'business_name': 'ADDGENE INC', 'amount_received': '1050659', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'WATERTOWN', 'state': 'MA'}, {'business_name': 'ALAMEDA COUNTY PUBLIC HEALTH DEPARTMENT', 'amount_received': '500000', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'OAKLAND', 'state': 'CA'}, {'business_name': 'BATTELLE FOR KIDS', 'amount_received': '80000', 'purpose': 'STUDENT ASSESSMENT RESEARCH', 'city': 'HILLIARD', 'state': 'OH'}]
# ******
# [{'business_name': 'ADDGENE INC', 'amount_received': '1050659', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'WATERTOWN', 'state': 'MA'}, {'business_name': 'ALAMEDA COUNTY PUBLIC HEALTH DEPARTMENT', 'amount_received': '500000', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'OAKLAND', 'state': 'CA'}, {'business_name': 'BATTELLE FOR KIDS', 'amount_received': '80000', 'purpose': 'STUDENT ASSESSMENT RESEARCH', 'city': 'HILLIARD', 'state': 'OH'}, {'business_name': 'BAYLOR COLLEGE OF MEDICINE', 'amount_received': '666431', 'purpose': 'SEED NETWORK GRANT', 'city': 'HOUSTON', 'state': 'TX'}]
# ******
# [{'business_name': 'ADDGENE INC', 'amount_received': '1050659', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'WATERTOWN', 'state': 'MA'}, {'business_name': 'ALAMEDA COUNTY PUBLIC HEALTH DEPARTMENT', 'amount_received': '500000', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'OAKLAND', 'state': 'CA'}, {'business_name': 'BATTELLE FOR KIDS', 'amount_received': '80000', 'purpose': 'STUDENT ASSESSMENT RESEARCH', 'city': 'HILLIARD', 'state': 'OH'}, {'business_name': 'BAYLOR COLLEGE OF MEDICINE', 'amount_received': '666431', 'purpose': 'SEED NETWORK GRANT', 'city': 'HOUSTON', 'state': 'TX'}, {'business_name': 'BELOVED COMMUNITY INC', 'amount_received': '900000', 'purpose': 'GENERAL OPERATING SUPPORT', 'city': 'NEW ORLEANS', 'state': 'LA'}]
# ******
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# Cell In[12], line 18
#      15 recipient_dict["city"] = recipient_city.text
#      17 recipient_state = recipient.find("StateAbbreviationCd")
# ---> 18 recipient_dict["state"] = recipient_state.text
#      19 recipient_list.append(recipient_dict)
#      21 print(recipient_list)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
zuck_recipient_df = pd.DataFrame(recipient_list)
zuck_recipient_df.head()
# Out:
#                              business_name amount_received  \
# 0                              ADDGENE INC         1050659
# 1  ALAMEDA COUNTY PUBLIC HEALTH DEPARTMENT          500000
# 2                        BATTELLE FOR KIDS           80000
# 3               BAYLOR COLLEGE OF MEDICINE          666431
# 4                    BELOVED COMMUNITY INC          900000
#
#                        purpose         city state
# 0    GENERAL OPERATING SUPPORT    WATERTOWN    MA
# 1    GENERAL OPERATING SUPPORT      OAKLAND    CA
# 2  STUDENT ASSESSMENT RESEARCH     HILLIARD    OH
# 3           SEED NETWORK GRANT      HOUSTON    TX
# 4    GENERAL OPERATING SUPPORT  NEW ORLEANS    LA

# %%
len(zuck_recipient_df)
# Out:
# 5

# %%
zuck_recipient_df["amount_received"].astype(float).sum()
# Out:
# 3197090.0

# %%
contributor_data = zuck_data.find_all("ContributorInformationGrp")

contributor_list = []

for contributor in contributor_data:
    contributor_dict = {}
    name = contributor.find("BusinessNameLine1Txt")
    contributor_dict["contributor_name"] = name.text
    
    amount_contributed = contributor.find("TotalContributionsAmt")
    contributor_dict["contributed_amount"] = amount_contributed.text
    
    contributor_list.append(contributor_dict)
    
    print(contributor_dict)
# Out:
# {'contributor_name': 'CHAN ZUCKERBERG INITIATIVE LLC', 'contributed_amount': '60000000'}

# %%
zuck_contributor_df = pd.DataFrame(contributor_list)
zuck_contributor_df
# Out:
#                  contributor_name contributed_amount
# 0  CHAN ZUCKERBERG INITIATIVE LLC           60000000
