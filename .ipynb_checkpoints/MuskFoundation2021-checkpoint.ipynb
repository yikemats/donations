# %%
# Project 03 - Donation tells you who they really are! (Musk Foundation)

# %%
import requests
musk_foundation = requests.get("https://projects.propublica.org/nonprofits/download-xml?object_id=202233199349106528")
musk_foundation
# Out:
# <Response [200]>

# %%
# The text is the raw xml of Form 990 tax document,obtained from ProRepublica's non-profit explorer.
musk_xml = musk_foundation.text
print(musk_xml)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <Return xmlns="http://www.irs.gov/efile" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.irs.gov/efile" returnVersion="2021v4.2">
#   <ReturnHeader binaryAttachmentCnt="0">
#     <ReturnTs>2022-11-15T14:40:54-06:00</ReturnTs>
#     <TaxPeriodEndDt>2021-12-31</TaxPeriodEndDt>
#     <PreparerFirmGrp>
#       <PreparerFirmEIN>831356013</PreparerFirmEIN>
#       <PreparerFirmName>
#         <BusinessNameLine1Txt>CATALYST FAMILY OFFICE LLC</BusinessNameLine1Txt>
#       </PreparerFirmName>
#       <PreparerUSAddress>
#         <AddressLine1Txt>5113 SOUTHWEST PARKWAY SUITE 275</AddressLine1Txt>
#         <CityNm>AUSTIN</CityNm>
#         <StateAbbreviationCd>TX</StateAbbreviationCd>
#         <ZIPCd>78735</ZIPCd>
#       </PreparerUSAddress>
#     </PreparerFirmGrp>
#     <ReturnTypeCd>990PF</ReturnTypeCd>
#     <TaxPeriodBeginDt>2021-01-01</TaxPeriodBeginDt>
#     <Filer>
#       <EIN>852133087</EIN>
#       <BusinessName>
#         <BusinessNameLine1Txt>MUSK FOUNDATION</BusinessNameLine1Txt>
#       </BusinessName>
#       <BusinessNameControlTxt>MUSK</BusinessNameControlTxt>
#       <PhoneNum>7372356956</PhoneNum>
#       <USAddress>
#         <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#         <CityNm>AUSTIN</CityNm>
#         <StateAbbreviationCd>TX</StateAbbreviationCd>
#         <ZIPCd>78734</ZIPCd>
#       </USAddress>
#     </Filer>
#     <BusinessOfficerGrp>
#       <PersonNm>JARED BIRCHALL</PersonNm>
#       <PersonTitleTxt>SECRETARY</PersonTitleTxt>
#       <PhoneNum>7372356956</PhoneNum>
#       <SignatureDt>2022-11-15</SignatureDt>
#       <DiscussWithPaidPreparerInd>1</DiscussWithPaidPreparerInd>
#     </BusinessOfficerGrp>
#     <SigningOfficerGrp>
#       <PersonFullName>
#         <PersonFirstNm>JARED</PersonFirstNm>
#         <PersonLastNm>BIRCHALL</PersonLastNm>
#       </PersonFullName>
#       <SSN>999009999</SSN>
#     </SigningOfficerGrp>
#     <PreparerPersonGrp>
#       <PreparerPersonNm>RONALD GONG</PreparerPersonNm>
#       <PTIN>P00191544</PTIN>
#       <PhoneNum>3258993151</PhoneNum>
#     </PreparerPersonGrp>
#     <AdditionalFilerInformation>
#       <TrustedCustomerGrp>
#         <TrustedCustomerCd>3</TrustedCustomerCd>
#         <AuthenticationAssuranceLevelCd>AAL1</AuthenticationAssuranceLevelCd>
#         <IdentityAssuranceLevelCd>IAL1</IdentityAssuranceLevelCd>
#       </TrustedCustomerGrp>
#     </AdditionalFilerInformation>
#     <TaxYr>2021</TaxYr>
#     <BuildTS>2022-09-23 18:48:47Z</BuildTS>
#   </ReturnHeader>
#   <ReturnData documentCnt="13">
#     <IRS990PF documentId="RetDoc1235000001">
#       <Organization501c3ExemptPFInd>X</Organization501c3ExemptPFInd>
#       <FMVAssetsEOYAmt>9419036726</FMVAssetsEOYAmt>
#       <MethodOfAccountingCashInd>X</MethodOfAccountingCashInd>
#       <AnalysisOfRevenueAndExpenses>
#         <ContriRcvdRevAndExpnssAmt>5703165040</ContriRcvdRevAndExpnssAmt>
#         <InterestOnSavRevAndExpnssAmt>1912</InterestOnSavRevAndExpnssAmt>
#         <InterestOnSavNetInvstIncmAmt>1912</InterestOnSavNetInvstIncmAmt>
#         <DividendsRevAndExpnssAmt>328543</DividendsRevAndExpnssAmt>
#         <DividendsNetInvstIncmAmt>328543</DividendsNetInvstIncmAmt>
#         <NetGainSaleAstRevAndExpnssAmt>326394116</NetGainSaleAstRevAndExpnssAmt>
#         <GrossSalesPriceAmt>496769914</GrossSalesPriceAmt>
#         <CapGainNetIncmNetInvstIncmAmt>326394116</CapGainNetIncmNetInvstIncmAmt>
#         <OtherIncomeRevAndExpnssAmt referenceDocumentId="RetDoc2001500001">12</OtherIncomeRevAndExpnssAmt>
#         <OtherIncomeNetInvstIncmAmt>12</OtherIncomeNetInvstIncmAmt>
#         <OtherIncomeAdjNetIncmAmt>0</OtherIncomeAdjNetIncmAmt>
#         <TotalRevAndExpnssAmt>6029889623</TotalRevAndExpnssAmt>
#         <TotalNetInvstIncmAmt>326724583</TotalNetInvstIncmAmt>
#         <TotalAdjNetIncmAmt>0</TotalAdjNetIncmAmt>
#         <CompOfcrDirTrstRevAndExpnssAmt>0</CompOfcrDirTrstRevAndExpnssAmt>
#         <CompOfcrDirTrstNetInvstIncmAmt>0</CompOfcrDirTrstNetInvstIncmAmt>
#         <CompOfcrDirTrstAdjNetIncmAmt>0</CompOfcrDirTrstAdjNetIncmAmt>
#         <CompOfcrDirTrstDsbrsChrtblAmt>0</CompOfcrDirTrstDsbrsChrtblAmt>
#         <LegalFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002100001">115253</LegalFeesRevAndExpnssAmt>
#         <LegalFeesNetInvstIncmAmt>0</LegalFeesNetInvstIncmAmt>
#         <LegalFeesAdjNetIncmAmt>0</LegalFeesAdjNetIncmAmt>
#         <LegalFeesDsbrsChrtblAmt>115253</LegalFeesDsbrsChrtblAmt>
#         <AccountingFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002200001">55029</AccountingFeesRevAndExpnssAmt>
#         <AccountingFeesNetInvstIncmAmt>27515</AccountingFeesNetInvstIncmAmt>
#         <AccountingFeesAdjNetIncmAmt>0</AccountingFeesAdjNetIncmAmt>
#         <AccountingFeesChrtblPrpsAmt>27514</AccountingFeesChrtblPrpsAmt>
#         <OtherProfFeesRevAndExpnssAmt referenceDocumentId="RetDoc2002300001">1381</OtherProfFeesRevAndExpnssAmt>
#         <OtherProfFeesNetInvstIncmAmt>0</OtherProfFeesNetInvstIncmAmt>
#         <OtherProfFeesAdjNetIncmAmt>0</OtherProfFeesAdjNetIncmAmt>
#         <OtherProfFeesDsbrsChrtblAmt>1381</OtherProfFeesDsbrsChrtblAmt>
#         <TaxesRevAndExpnssAmt referenceDocumentId="RetDoc2002500001">6500000</TaxesRevAndExpnssAmt>
#         <TaxesNetInvstIncmAmt>0</TaxesNetInvstIncmAmt>
#         <TaxesAdjNetIncmAmt>0</TaxesAdjNetIncmAmt>
#         <TaxesDsbrsChrtblAmt>0</TaxesDsbrsChrtblAmt>
#         <OtherExpensesRevAndExpnssAmt referenceDocumentId="RetDoc2003200001">321390</OtherExpensesRevAndExpnssAmt>
#         <OtherExpensesNetInvstIncmAmt>318890</OtherExpensesNetInvstIncmAmt>
#         <OtherExpensesAdjNetIncmAmt>0</OtherExpensesAdjNetIncmAmt>
#         <OtherExpensesDsbrsChrtblAmt>2500</OtherExpensesDsbrsChrtblAmt>
#         <TotOprExpensesRevAndExpnssAmt>6993053</TotOprExpensesRevAndExpnssAmt>
#         <TotOprExpensesNetInvstIncmAmt>346405</TotOprExpensesNetInvstIncmAmt>
#         <TotOprExpensesAdjNetIncmAmt>0</TotOprExpensesAdjNetIncmAmt>
#         <TotOprExpensesDsbrsChrtblAmt>146648</TotOprExpensesDsbrsChrtblAmt>
#         <ContriPaidRevAndExpnssAmt>159938705</ContriPaidRevAndExpnssAmt>
#         <ContriPaidDsbrsChrtblAmt>159938705</ContriPaidDsbrsChrtblAmt>
#         <TotalExpensesRevAndExpnssAmt>166931758</TotalExpensesRevAndExpnssAmt>
#         <TotalExpensesNetInvstIncmAmt>346405</TotalExpensesNetInvstIncmAmt>
#         <TotalExpensesAdjNetIncmAmt>0</TotalExpensesAdjNetIncmAmt>
#         <TotalExpensesDsbrsChrtblAmt>160085353</TotalExpensesDsbrsChrtblAmt>
#         <ExcessRevenueOverExpensesAmt>5862957865</ExcessRevenueOverExpensesAmt>
#         <NetInvestmentIncomeAmt>326378178</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#       </AnalysisOfRevenueAndExpenses>
#       <Form990PFBalanceSheetsGrp>
#         <SavAndTempCashInvstBOYAmt>164506285</SavAndTempCashInvstBOYAmt>
#         <SavAndTempCashInvstEOYAmt>65355447</SavAndTempCashInvstEOYAmt>
#         <SavAndTempCashInvstEOYFMVAmt>65350042</SavAndTempCashInvstEOYFMVAmt>
#         <USGovernmentObligationsBOYAmt>9559760</USGovernmentObligationsBOYAmt>
#         <USGovernmentObligationsEOYAmt referenceDocumentId="RetDoc2210400001">83432960</USGovernmentObligationsEOYAmt>
#         <USGovtObligationsEOYFMVAmt>83057148</USGovtObligationsEOYFMVAmt>
#         <CorporateStockBOYAmt>2065382</CorporateStockBOYAmt>
#         <CorporateStockEOYAmt referenceDocumentId="RetDoc2018900001">4298355</CorporateStockEOYAmt>
#         <CorporateStockEOYFMVAmt>9007295245</CorporateStockEOYFMVAmt>
#         <CorporateBondsBOYAmt>11858771</CorporateBondsBOYAmt>
#         <CorporateBondsEOYAmt referenceDocumentId="RetDoc2044400001">38443812</CorporateBondsEOYAmt>
#         <CorporateBondsEOYFMVAmt>38455320</CorporateBondsEOYFMVAmt>
#         <OtherInvestmentsBOYAmt>29347892</OtherInvestmentsBOYAmt>
#         <OtherInvestmentsEOYAmt referenceDocumentId="RetDoc2018100001">188048661</OtherInvestmentsEOYAmt>
#         <OtherInvestmentsEOYFMVAmt>224878971</OtherInvestmentsEOYFMVAmt>
#         <TotalAssetsBOYAmt>217338090</TotalAssetsBOYAmt>
#         <TotalAssetsEOYAmt>379579235</TotalAssetsEOYAmt>
#         <TotalAssetsEOYFMVAmt>9419036726</TotalAssetsEOYFMVAmt>
#         <TotalLiabilitiesBOYAmt>0</TotalLiabilitiesBOYAmt>
#         <TotalLiabilitiesEOYAmt>0</TotalLiabilitiesEOYAmt>
#         <OrgDoesNotFollowFASB117Ind>X</OrgDoesNotFollowFASB117Ind>
#         <CapitalStockBOYAmt>0</CapitalStockBOYAmt>
#         <CapitalStockEOYAmt>0</CapitalStockEOYAmt>
#         <AdditionalPaidInCapitalBOYAmt>0</AdditionalPaidInCapitalBOYAmt>
#         <AdditionalPaidInCapitalEOYAmt>0</AdditionalPaidInCapitalEOYAmt>
#         <RetainedEarningBOYAmt>217338090</RetainedEarningBOYAmt>
#         <RetainedEarningEOYAmt>379579235</RetainedEarningEOYAmt>
#         <TotNetAstOrFundBalancesBOYAmt>217338090</TotNetAstOrFundBalancesBOYAmt>
#         <TotNetAstOrFundBalancesEOYAmt>379579235</TotNetAstOrFundBalancesEOYAmt>
#         <TotalLiabilitiesNetAstBOYAmt>217338090</TotalLiabilitiesNetAstBOYAmt>
#         <TotalLiabilitiesNetAstEOYAmt>379579235</TotalLiabilitiesNetAstEOYAmt>
#       </Form990PFBalanceSheetsGrp>
#       <ChgInNetAssetsFundBalancesGrp>
#         <TotNetAstOrFundBalancesBOYAmt>217338090</TotNetAstOrFundBalancesBOYAmt>
#         <ExcessRevenueOverExpensesAmt>5862957865</ExcessRevenueOverExpensesAmt>
#         <OtherIncreasesAmt>0</OtherIncreasesAmt>
#         <SubtotalAmt>6080295955</SubtotalAmt>
#         <OtherDecreasesAmt referenceDocumentId="RetDoc2049800001">5700716720</OtherDecreasesAmt>
#         <TotNetAstOrFundBalancesEOYAmt>379579235</TotNetAstOrFundBalancesEOYAmt>
#       </ChgInNetAssetsFundBalancesGrp>
#       <CapGainsLossTxInvstIncmDetail>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>MORGAN STANLEY #0481 - ST COVERED</PropertyDesc>
#           <GrossSalesPriceAmt>25294804</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>25382377</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-87573</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-87573</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>MORGAN STANLEY #0481 - LT COVERED</PropertyDesc>
#           <GrossSalesPriceAmt>10163704</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>10204334</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-40630</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-40630</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>MORGAN STANLEY #0481 - LT NONCOVERED</PropertyDesc>
#           <GrossSalesPriceAmt>326736406</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>215347</CostOrOtherBasisAmt>
#           <GainOrLossAmt>326521059</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>326521059</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>FEDERATED HRMS INST PRM OBL (PUBLICLY TRADED SEC)</PropertyDesc>
#           <GrossSalesPriceAmt>100000000</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>99993240</CostOrOtherBasisAmt>
#           <GainOrLossAmt>6760</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>6760</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>FEDERATED HRMS INST PRM OBL (PUBLICLY TRADED SEC)</PropertyDesc>
#           <GrossSalesPriceAmt>2000000</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>2000200</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-200</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-200</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>FEDERATED HRMS INST PRM OBL (PUBLICLY TRADED SEC)</PropertyDesc>
#           <GrossSalesPriceAmt>5000000</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>5000500</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-500</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-500</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>FEDERATED HRMS INST PRM OBL (PUBLICLY TRADED SEC)</PropertyDesc>
#           <GrossSalesPriceAmt>10000000</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>10001327</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-1327</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-1327</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>MORGAN STANLEY #0014 - ST COVERED</PropertyDesc>
#           <GrossSalesPriceAmt>16900000</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>16903557</CostOrOtherBasisAmt>
#           <GainOrLossAmt>-3557</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>-3557</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapGainsLossTxInvstIncmGrp>
#           <PropertyDesc>MORGAN STANLEY #0014 - LT COVERED</PropertyDesc>
#           <GrossSalesPriceAmt>675000</GrossSalesPriceAmt>
#           <CostOrOtherBasisAmt>674916</CostOrOtherBasisAmt>
#           <GainOrLossAmt>84</GainOrLossAmt>
#           <GainsMinusExcessOrLossesAmt>84</GainsMinusExcessOrLossesAmt>
#         </CapGainsLossTxInvstIncmGrp>
#         <CapitalGainNetIncomeAmt>326394116</CapitalGainNetIncomeAmt>
#         <NetShortTermCapitalGainLossAmt>-86397</NetShortTermCapitalGainLossAmt>
#       </CapGainsLossTxInvstIncmDetail>
#       <ExciseTaxBasedOnInvstIncmGrp>
#         <InvestmentIncomeExciseTaxAmt>4536657</InvestmentIncomeExciseTaxAmt>
#         <TaxUnderSection511Amt>0</TaxUnderSection511Amt>
#         <SubtotalAmt>4536657</SubtotalAmt>
#         <SubtitleATaxAmt>0</SubtitleATaxAmt>
#         <TaxBasedOnInvestmentIncomeAmt>4536657</TaxBasedOnInvestmentIncomeAmt>
#         <EstimatedPlusOvpmtIncmTxAmt>4333483</EstimatedPlusOvpmtIncmTxAmt>
#         <ExemptFrgnOrgTaxWthldAtSrceAmt>0</ExemptFrgnOrgTaxWthldAtSrceAmt>
#         <ExtsnRequestIncomeTaxPaidAmt>220000</ExtsnRequestIncomeTaxPaidAmt>
#         <BackupWithholdingWithheldAmt>0</BackupWithholdingWithheldAmt>
#         <TotalPaymentsAndCreditsAmt>4553483</TotalPaymentsAndCreditsAmt>
#         <Form2220AttachedInd referenceDocumentId="RetDoc1192000001">X</Form2220AttachedInd>
#         <EsPenaltyAmt>0</EsPenaltyAmt>
#         <OverpaymentAmt>16826</OverpaymentAmt>
#         <AppliedToESTaxAmt>16826</AppliedToESTaxAmt>
#         <RefundAmt>0</RefundAmt>
#       </ExciseTaxBasedOnInvstIncmGrp>
#       <StatementsRegardingActyGrp>
#         <LegislativePoliticalActyInd>0</LegislativePoliticalActyInd>
#         <MoreThan100SpentInd>0</MoreThan100SpentInd>
#         <Form1120POLFiledInd>0</Form1120POLFiledInd>
#         <Section4955OrganizationTaxAmt>0</Section4955OrganizationTaxAmt>
#         <Section4955ManagersTaxAmt>0</Section4955ManagersTaxAmt>
#         <TaxReimbursedAmt>0</TaxReimbursedAmt>
#         <ActivitiesNotPreviouslyRptInd>0</ActivitiesNotPreviouslyRptInd>
#         <ChangesToArticlesOrBylawsInd>0</ChangesToArticlesOrBylawsInd>
#         <UnrelatedBusIncmOverLimitInd>0</UnrelatedBusIncmOverLimitInd>
#         <OrganizationDissolvedEtcInd>0</OrganizationDissolvedEtcInd>
#         <Section508eRqrSatisfiedInd>1</Section508eRqrSatisfiedInd>
#         <AtLeast5000InAssetsInd>1</AtLeast5000InAssetsInd>
#         <OrgReportOrRegisterStateCd>TX</OrgReportOrRegisterStateCd>
#         <Form990PFFiledWithAttyGenInd>1</Form990PFFiledWithAttyGenInd>
#         <PrivateOperatingFoundationInd>0</PrivateOperatingFoundationInd>
#         <NewSubstantialContributorsInd>0</NewSubstantialContributorsInd>
#         <OwnControlledEntityInd>0</OwnControlledEntityInd>
#         <DonorAdvisedFundInd>0</DonorAdvisedFundInd>
#         <ComplyWithPublicInspRqrInd>1</ComplyWithPublicInspRqrInd>
#         <WebsiteAddressTxt>WWW.MUSKFOUNDATION.ORG</WebsiteAddressTxt>
#         <PersonsWithBooksName>
#           <BusinessNameLine1Txt>MUSK FOUNDATION</BusinessNameLine1Txt>
#         </PersonsWithBooksName>
#         <PhoneNum>7372356956</PhoneNum>
#         <LocationOfBooksUSAddress>
#           <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#           <CityNm>AUSTIN</CityNm>
#           <StateAbbreviationCd>TX</StateAbbreviationCd>
#           <ZIPCd>78734</ZIPCd>
#         </LocationOfBooksUSAddress>
#         <ForeignAccountsQuestionInd>0</ForeignAccountsQuestionInd>
#       </StatementsRegardingActyGrp>
#       <StatementsRegardingActy4720Grp>
#         <SaleOrExchDisqualifiedPrsnInd>0</SaleOrExchDisqualifiedPrsnInd>
#         <BrrwOrLendDisqualifiedPrsnInd>0</BrrwOrLendDisqualifiedPrsnInd>
#         <FurnGoodsDisqualifiedPrsnInd>0</FurnGoodsDisqualifiedPrsnInd>
#         <PayCompDisqualifiedPrsnInd>0</PayCompDisqualifiedPrsnInd>
#         <TransferAstDisqualifiedPrsnInd>0</TransferAstDisqualifiedPrsnInd>
#         <PaymentToGovernmentOfficialInd>0</PaymentToGovernmentOfficialInd>
#         <UncorrectedPriorActsInd>0</UncorrectedPriorActsInd>
#         <UndistributedIncomePYInd>0</UndistributedIncomePYInd>
#         <BusinessHoldingsInd>0</BusinessHoldingsInd>
#         <JeopardyInvestmentsInd>0</JeopardyInvestmentsInd>
#         <UncorrectedPYJeopardyInvstInd>0</UncorrectedPYJeopardyInvstInd>
#         <InfluenceLegislationInd>0</InfluenceLegislationInd>
#         <InfluenceElectionInd>0</InfluenceElectionInd>
#         <GrantsToIndividualsInd>0</GrantsToIndividualsInd>
#         <GrantsToOrganizationsInd>0</GrantsToOrganizationsInd>
#         <NoncharitablePurposeInd>0</NoncharitablePurposeInd>
#         <RcvFndsToPayPrsnlBnftCntrctInd>0</RcvFndsToPayPrsnlBnftCntrctInd>
#         <PayPremiumsPrsnlBnftCntrctInd>0</PayPremiumsPrsnlBnftCntrctInd>
#         <ProhibitedTaxShelterTransInd>0</ProhibitedTaxShelterTransInd>
#         <SubjToTaxRmnrtnExPrchtPymtInd>0</SubjToTaxRmnrtnExPrchtPymtInd>
#       </StatementsRegardingActy4720Grp>
#       <OfficerDirTrstKeyEmplInfoGrp>
#         <OfficerDirTrstKeyEmplGrp>
#           <PersonNm>ELON MUSK</PersonNm>
#           <USAddress>
#             <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78734</ZIPCd>
#           </USAddress>
#           <TitleTxt>PRESIDENT &amp; DIRECTOR</TitleTxt>
#           <AverageHrsPerWkDevotedToPosRt>1.00</AverageHrsPerWkDevotedToPosRt>
#           <CompensationAmt>0</CompensationAmt>
#           <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#           <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#         </OfficerDirTrstKeyEmplGrp>
#         <OfficerDirTrstKeyEmplGrp>
#           <PersonNm>JARED BIRCHALL</PersonNm>
#           <USAddress>
#             <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78734</ZIPCd>
#           </USAddress>
#           <TitleTxt>SECRETARY &amp; TREASURER &amp; DIRECTOR</TitleTxt>
#           <AverageHrsPerWkDevotedToPosRt>1.00</AverageHrsPerWkDevotedToPosRt>
#           <CompensationAmt>0</CompensationAmt>
#           <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#           <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#         </OfficerDirTrstKeyEmplGrp>
#         <OfficerDirTrstKeyEmplGrp>
#           <PersonNm>MATILDA SIMON</PersonNm>
#           <USAddress>
#             <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78734</ZIPCd>
#           </USAddress>
#           <TitleTxt>DIRECTOR</TitleTxt>
#           <AverageHrsPerWkDevotedToPosRt>0.10</AverageHrsPerWkDevotedToPosRt>
#           <CompensationAmt>0</CompensationAmt>
#           <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#           <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#         </OfficerDirTrstKeyEmplGrp>
#         <CompOfHghstPdEmplOrNONETxt>NONE</CompOfHghstPdEmplOrNONETxt>
#         <OtherEmployeePaidOver50kCnt>0</OtherEmployeePaidOver50kCnt>
#         <CompensationOfHghstPdCntrctGrp>
#           <BusinessName>
#             <BusinessNameLine1Txt>WITHERS BERGMAN LLP</BusinessNameLine1Txt>
#           </BusinessName>
#           <USAddress>
#             <AddressLine1Txt>157 CHURCH STREET 12TH FLOOR</AddressLine1Txt>
#             <CityNm>NEW HAVEN</CityNm>
#             <StateAbbreviationCd>CT</StateAbbreviationCd>
#             <ZIPCd>06510</ZIPCd>
#           </USAddress>
#           <ServiceTypeTxt>LEGAL</ServiceTypeTxt>
#           <CompensationAmt>113340</CompensationAmt>
#         </CompensationOfHghstPdCntrctGrp>
#         <ContractorPaidOver50kCnt>0</ContractorPaidOver50kCnt>
#       </OfficerDirTrstKeyEmplInfoGrp>
#       <SumOfProgramRelatedInvstGrp>
#         <TotalAmt>0</TotalAmt>
#       </SumOfProgramRelatedInvstGrp>
#       <MinimumInvestmentReturnGrp>
#         <AverageMonthlyFMVOfSecAmt>4094602174</AverageMonthlyFMVOfSecAmt>
#         <AverageMonthlyCashBalancesAmt>118227444</AverageMonthlyCashBalancesAmt>
#         <FMVAllOtherNoncharitableAstAmt>0</FMVAllOtherNoncharitableAstAmt>
#         <TotalFMVOfUnusedAssetsAmt>4212829618</TotalFMVOfUnusedAssetsAmt>
#         <ReductionClaimedAmt>0</ReductionClaimedAmt>
#         <AcquisitionIndebtednessAmt>0</AcquisitionIndebtednessAmt>
#         <AdjustedTotalFMVOfUnusedAstAmt>4212829618</AdjustedTotalFMVOfUnusedAstAmt>
#         <CashDeemedCharitableAmt>63192444</CashDeemedCharitableAmt>
#         <NetVlNoncharitableAssetsAmt>4149637174</NetVlNoncharitableAssetsAmt>
#         <MinimumInvestmentReturnAmt>207481859</MinimumInvestmentReturnAmt>
#       </MinimumInvestmentReturnGrp>
#       <DistributableAmountGrp>
#         <MinimumInvestmentReturnAmt>207481859</MinimumInvestmentReturnAmt>
#         <TaxBasedOnInvestmentIncomeAmt>4536657</TaxBasedOnInvestmentIncomeAmt>
#         <TotalTaxAmt>4536657</TotalTaxAmt>
#         <DistributableBeforeAdjAmt>202945202</DistributableBeforeAdjAmt>
#         <RecoveriesQualfiedDistriAmt>0</RecoveriesQualfiedDistriAmt>
#         <DistributableBeforeDedAmt>202945202</DistributableBeforeDedAmt>
#         <DeductionFromDistributableAmt>0</DeductionFromDistributableAmt>
#         <DistributableAsAdjustedAmt>202945202</DistributableAsAdjustedAmt>
#       </DistributableAmountGrp>
#       <PFQualifyingDistributionsGrp>
#         <ExpensesAndContributionsAmt>160085353</ExpensesAndContributionsAmt>
#         <ProgramRelatedInvstTotalAmt>0</ProgramRelatedInvstTotalAmt>
#         <QualifyingDistributionsAmt>160085353</QualifyingDistributionsAmt>
#       </PFQualifyingDistributionsGrp>
#       <UndistributedIncomeGrp>
#         <DistributableAsAdjustedAmt>202945202</DistributableAsAdjustedAmt>
#         <UndistributedIncomePYAmt>0</UndistributedIncomePYAmt>
#         <TotalForPriorYearsAmt>0</TotalForPriorYearsAmt>
#         <ExcessDistributionCyovYr5Amt>488992</ExcessDistributionCyovYr5Amt>
#         <ExcessDistributionCyovYr2Amt>1182545</ExcessDistributionCyovYr2Amt>
#         <TotalExcessDistributionCyovAmt>1671537</TotalExcessDistributionCyovAmt>
#         <QualifyingDistributionsAmt>160085353</QualifyingDistributionsAmt>
#         <AppliedToYear1Amt>0</AppliedToYear1Amt>
#         <AppliedToPriorYearsAmt>0</AppliedToPriorYearsAmt>
#         <TreatedAsDistriFromCorpusAmt>0</TreatedAsDistriFromCorpusAmt>
#         <AppliedToCurrentYearAmt>160085353</AppliedToCurrentYearAmt>
#         <RemainingDistriFromCorpusAmt>0</RemainingDistriFromCorpusAmt>
#         <ExcessDistriCyovAppCYCorpusAmt>1671537</ExcessDistriCyovAppCYCorpusAmt>
#         <ExcessDistributionCyovAppCYAmt>1671537</ExcessDistributionCyovAppCYAmt>
#         <TotalCorpusAmt>0</TotalCorpusAmt>
#         <PriorYearUndistributedIncmAmt>0</PriorYearUndistributedIncmAmt>
#         <PriorYearDeficiencyOrTaxAmt>0</PriorYearDeficiencyOrTaxAmt>
#         <Taxable1Amt>0</Taxable1Amt>
#         <Taxable2Amt>0</Taxable2Amt>
#         <UndistributedIncomeCYAmt>41188312</UndistributedIncomeCYAmt>
#         <CorpusDistri170b1EOr4942g3Amt>0</CorpusDistri170b1EOr4942g3Amt>
#         <ExcessDistriCyovFromYr5Amt>0</ExcessDistriCyovFromYr5Amt>
#         <ExcessDistriCyovToNextYrAmt>0</ExcessDistriCyovToNextYrAmt>
#       </UndistributedIncomeGrp>
#       <SupplementaryInformationGrp>
#         <ContributingManagerNm>ELON MUSK</ContributingManagerNm>
#         <OnlyContriToPreselectedInd>X</OnlyContriToPreselectedInd>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>SIGNAL TECHNOLOGY FOUNDATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>650 CASTRO STREET SUITE 120-223</AddressLine1Txt>
#             <CityNm>MOUNTAIN VIEW</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>94041</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION</GrantOrContributionPurposeTxt>
#           <Amt>2000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>STEAMSPACE EDUCATION OUTREACH</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>6108 BULLARD DRIVE UNIT A</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78757</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>10000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>VIRGINIA 30 DAY FUND</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1314 RUGBY RD</AddressLine1Txt>
#             <CityNm>CHARLOTTESVILLE</CityNm>
#             <StateAbbreviationCd>VA</StateAbbreviationCd>
#             <ZIPCd>22903</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS</GrantOrContributionPurposeTxt>
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FUTURE OF LIFE INSTITUTE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>70 VASSAR ST RM 37-626B</AddressLine1Txt>
#             <CityNm>CAMBRIDGE</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02139</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE</GrantOrContributionPurposeTxt>
#           <Amt>4000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FOUNDERS PLEDGE INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>228 PARK AVE S PMB 71081</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>100031502</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT CHARITABLE GIVING</GrantOrContributionPurposeTxt>
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>DONORSCHOOSEORG</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>134 WEST 37TH STREET - 11TH FLOOR</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10018</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT EDUCATION OF STUDENTS IN NEED</GrantOrContributionPurposeTxt>
#           <Amt>945000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ST JUDE CHILDREN'S RESEARCH HOSPITAL</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>501 ST JUDE PLACE</AddressLine1Txt>
#             <CityNm>MEMPHIS</CityNm>
#             <StateAbbreviationCd>TN</StateAbbreviationCd>
#             <ZIPCd>38105</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES</GrantOrContributionPurposeTxt>
#           <Amt>55000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>UNICEF USA</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>125 MAIDEN LANE</AddressLine1Txt>
#             <CityNm>NEW YORK</CityNm>
#             <StateAbbreviationCd>NY</StateAbbreviationCd>
#             <ZIPCd>10038</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT EDUCATION OF STUDENTS IN NEED</GrantOrContributionPurposeTxt>
#           <Amt>5000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>FEEDING TEXAS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1524 SOUTH IH-35 SUITE 342</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78704</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT WINTER STORM URI DISASTER RELIEF</GrantOrContributionPurposeTxt>
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>AUSTIN DISASTER RELIEF NETWORK</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 15424</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78761</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT WINTER STORM URI DISASTER RELIEF</GrantOrContributionPurposeTxt>
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>X PRIZE FOUNDATION INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>800 CORPORATE POINTE SUITE 350</AddressLine1Txt>
#             <CityNm>CULVER CITY</CityNm>
#             <StateAbbreviationCd>CA</StateAbbreviationCd>
#             <ZIPCd>90230</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL</GrantOrContributionPurposeTxt>
#           <Amt>54000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BROWNSVILLE INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1900 E PRICE ROAD</AddressLine1Txt>
#             <CityNm>BROWNSVILLE</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78521</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>4946056</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>600 N MESQUITE ST</AddressLine1Txt>
#             <CityNm>LOS FRESNOS</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78566</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>1279503</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>240 N CROCKETT ST</AddressLine1Txt>
#             <CityNm>SAN BENITO</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78586</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>1245513</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>IDEA PUBLIC SCHOOLS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>2115 W PIKE BOULEVARD</AddressLine1Txt>
#             <CityNm>WESLACO</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78596</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES</GrantOrContributionPurposeTxt>
#           <Amt>941519</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>LA FERIA INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>203 E OLEANDER AVE</AddressLine1Txt>
#             <CityNm>LA FERIA</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78559</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>378403</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>POINT ISABEL INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>101 PORT ROAD</AddressLine1Txt>
#             <CityNm>PORT ISABEL</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78578</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>253366</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>JUBILEE ACADEMIES</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>4434 ROLAND ROAD</AddressLine1Txt>
#             <CityNm>SAN ANTONIO</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78222</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>232040</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>RIO HONDO INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>215 WEST COLORADO STREET</AddressLine1Txt>
#             <CityNm>RIO HONDO</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78583</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>213393</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>100 MED HIGH DRIVE</AddressLine1Txt>
#             <CityNm>MERCEDES</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78570</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>179756</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>HARMONY SCIENCE ACADEMY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>9321 W SAM HOUSTON PKWY S</AddressLine1Txt>
#             <CityNm>HOUSTON</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>77099</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>123453</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>SANTA ROSA INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>102 JESUS R CRUZ</AddressLine1Txt>
#             <CityNm>SANTA ROSA</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78593</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>55584</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>SANTA MARIA INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>11119 MILITARY RD</AddressLine1Txt>
#             <CityNm>SANTA MARIA</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78592</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>35669</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>RAUL YZAGUIRRE SCHOOLS FOR SUCCESS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>2950 BROADWAY</AddressLine1Txt>
#             <CityNm>HOUSTON</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>77017</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>46676</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>SOUTH TEXAS EDUCATIONAL TECHNOLOGIES INC</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>2402 E BUS HWY 83 BLDG 100</AddressLine1Txt>
#             <CityNm>WESLACO</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78596</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>40338</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>407 N 77 SUNSHINE STRIP</AddressLine1Txt>
#             <CityNm>HARLINGEN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78550</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>2182553</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>PROMESA PUBLIC SCHOOLS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>5800 E MARTIN LUTHER KING JR BLVD</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78721</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>28030</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>ROMAN CATHOLIC DIOCESE OF BROWNSVILLE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1910 UNIVERSITY BLVD</AddressLine1Txt>
#             <CityNm>BROWNSVILLE</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78520</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT GUADALUPE MIDDLE SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>10250</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>RESPONSIVE EDUCATION SOLUTIONS</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 292730</AddressLine1Txt>
#             <CityNm>LEWISVILLE</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>75029</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>22302</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BROWNSVILLE COMMUNITY IMPROVEMENT CORP</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>500 EAST SAINT CHARLES STREET</AddressLine1Txt>
#             <CityNm>BROWNSVILLE</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78520</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT DOWNTOWN BROWNSVILLE BUSINESS IMPROVEMENT AND GROWTH PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>2355000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>CITY OF BROWNSVILLE</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>1001 E ELIZABETH STREET</AddressLine1Txt>
#             <CityNm>BROWNSVILLE</CityNm>
# ...
#           <Amt>1000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>THE TRAIL FOUNDATION</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>PO BOX 5195</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78763</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT PROTECTION OF THE BUTLER TRAIL</GrantOrContributionPurposeTxt>
#           <Amt>50000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>BROWNSVILLE MUSEUM OF FINE ART</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>660 E RINGGOLD ST</AddressLine1Txt>
#             <CityNm>BROWNSVILLE</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78520</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT ART EDUCATION AND CULTURAL ENRICHMENT</GrantOrContributionPurposeTxt>
#           <Amt>24300</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>THE UNIVERSITY OF TEXAS AT AUSTIN</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>110 INNER CAMPUS DRIVE</AddressLine1Txt>
#             <CityNm>AUSTIN</CityNm>
#             <StateAbbreviationCd>TX</StateAbbreviationCd>
#             <ZIPCd>78705</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>10000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>GEORGETOWN UNIVERSITY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>37TH AND O STREETS NW</AddressLine1Txt>
#             <CityNm>WASHINGTON</CityNm>
#             <StateAbbreviationCd>DC</StateAbbreviationCd>
#             <ZIPCd>20057</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>2000000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>UNIVERSITY OF PENNSYLVANIA</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>249 S 36TH STREET</AddressLine1Txt>
#             <CityNm>PHILADELPHIA</CityNm>
#             <StateAbbreviationCd>PA</StateAbbreviationCd>
#             <ZIPCd>19104</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>1500000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>MASSACHUSETTS INSTITUTE OF TECHNOLOGY</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientUSAddress>
#             <AddressLine1Txt>77 MASSACHUSETTS AVENUE</AddressLine1Txt>
#             <CityNm>CAMBRIDGE</CityNm>
#             <StateAbbreviationCd>MA</StateAbbreviationCd>
#             <ZIPCd>02139</ZIPCd>
#           </RecipientUSAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#           <Amt>1500000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <GrantOrContributionPdDurYrGrp>
#           <RecipientBusinessName>
#             <BusinessNameLine1Txt>GLOBAL CHANGE DATA LAB</BusinessNameLine1Txt>
#           </RecipientBusinessName>
#           <RecipientForeignAddress>
#             <AddressLine1Txt>106-108 COWLEY ROAD</AddressLine1Txt>
#             <CityNm>OXFORD</CityNm>
#             <CountryCd>UK</CountryCd>
#             <ForeignPostalCd>OX4 1JE</ForeignPostalCd>
#           </RecipientForeignAddress>
#           <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#           <RecipientFoundationStatusTxt>PC: EQUIVALENCY DET.</RecipientFoundationStatusTxt>
#           <GrantOrContributionPurposeTxt>SUPPORT PRODUCTION AND MAINTENANCE OF PUBLIC ONLINE RESOURCES ON ENVIRONMENT</GrantOrContributionPurposeTxt>
#           <Amt>1500000</Amt>
#         </GrantOrContributionPdDurYrGrp>
#         <TotalGrantOrContriPdDurYrAmt>159938705</TotalGrantOrContriPdDurYrAmt>
#         <TotalGrantOrContriApprvFutAmt>0</TotalGrantOrContriApprvFutAmt>
#       </SupplementaryInformationGrp>
#       <AnalysisIncomeProducingActyGrp>
#         <IntOnSavAndTempCashInvstGrp>
#           <ExclusionCd>14</ExclusionCd>
#           <ExclusionAmt>1912</ExclusionAmt>
#         </IntOnSavAndTempCashInvstGrp>
#         <DividendsAndInterestFromSecDtl>
#           <ExclusionCd>14</ExclusionCd>
#           <ExclusionAmt>328543</ExclusionAmt>
#         </DividendsAndInterestFromSecDtl>
#         <OtherInvestmentIncomeGrp>
#           <ExclusionCd>14</ExclusionCd>
#           <ExclusionAmt>12</ExclusionAmt>
#         </OtherInvestmentIncomeGrp>
#         <GainSalesAstOthThanInvntryGrp>
#           <ExclusionCd>18</ExclusionCd>
#           <ExclusionAmt>326394116</ExclusionAmt>
#         </GainSalesAstOthThanInvntryGrp>
#         <SubtotalsIncmProducingActyGrp>
#           <UnrelatedBusinessTaxblIncmAmt>0</UnrelatedBusinessTaxblIncmAmt>
#           <ExclusionAmt>326724583</ExclusionAmt>
#           <RelatedOrExemptFunctionIncmAmt>0</RelatedOrExemptFunctionIncmAmt>
#         </SubtotalsIncmProducingActyGrp>
#         <TotalIncomeProducingActyAmt>326724583</TotalIncomeProducingActyAmt>
#       </AnalysisIncomeProducingActyGrp>
#       <TrnsfrTransRlnNonchrtblEOGrp>
#         <TrnsfrOfCashToNonchrtblEOInd>0</TrnsfrOfCashToNonchrtblEOInd>
#         <TrnsfrOtherAssetNonchrtblEOInd>0</TrnsfrOtherAssetNonchrtblEOInd>
#         <SalesOrExchangesOfAssetsInd>0</SalesOrExchangesOfAssetsInd>
#         <PurchaseOfAssetsNonchrtblEOInd>0</PurchaseOfAssetsNonchrtblEOInd>
#         <RentalOfFacilitiesOthAssetsInd>0</RentalOfFacilitiesOthAssetsInd>
#         <ReimbursementArrangementsInd>0</ReimbursementArrangementsInd>
#         <LoansOrLoanGuaranteesInd>0</LoansOrLoanGuaranteesInd>
#         <PerformanceOfServicesEtcInd>0</PerformanceOfServicesEtcInd>
#         <SharingOfFacilitiesEtcInd>0</SharingOfFacilitiesEtcInd>
#         <RelationshipsNonchrtblEOInd>0</RelationshipsNonchrtblEOInd>
#       </TrnsfrTransRlnNonchrtblEOGrp>
#     </IRS990PF>
#     <IRS990ScheduleB documentId="RetDoc1234500001">
#       <Organization501c3ExemptPFInd>X</Organization501c3ExemptPFInd>
#       <GeneralRuleInd>X</GeneralRuleInd>
#       <ContributorInformationGrp>
#         <ContributorNum>1</ContributorNum>
#         <ContributorPersonNm>ELON MUSK</ContributorPersonNm>
#         <ContributorUSAddress>
#           <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#           <CityNm>AUSTIN</CityNm>
#           <StateAbbreviationCd>TX</StateAbbreviationCd>
#           <ZIPCd>78734</ZIPCd>
#         </ContributorUSAddress>
#         <TotalContributionsAmt>5703165040</TotalContributionsAmt>
#         <PersonContributionInd>X</PersonContributionInd>
#         <NoncashContributionInd>X</NoncashContributionInd>
#       </ContributorInformationGrp>
#       <NonCashPropertyContributionGrp>
#         <ContributorNum>1</ContributorNum>
#         <NoncashPropertyDesc>2,234,000 SHARES OF TESLA INC.</NoncashPropertyDesc>
#         <FairMarketValueAmt>2492496140</FairMarketValueAmt>
#         <ReceivedDt>2021-11-19</ReceivedDt>
#       </NonCashPropertyContributionGrp>
#       <NonCashPropertyContributionGrp>
#         <ContributorNum>1</ContributorNum>
#         <NoncashPropertyDesc>1,560,000 SHARES OF TESLA INC.</NoncashPropertyDesc>
#         <FairMarketValueAmt>1820816400</FairMarketValueAmt>
#         <ReceivedDt>2021-11-22</ReceivedDt>
#       </NonCashPropertyContributionGrp>
#       <NonCashPropertyContributionGrp>
#         <ContributorNum>1</ContributorNum>
#         <NoncashPropertyDesc>500,000 SHARES OF TESLA INC.</NoncashPropertyDesc>
#         <FairMarketValueAmt>560800000</FairMarketValueAmt>
#         <ReceivedDt>2021-11-23</ReceivedDt>
#       </NonCashPropertyContributionGrp>
#       <NonCashPropertyContributionGrp>
#         <ContributorNum>1</ContributorNum>
#         <NoncashPropertyDesc>500,000 SHARES OF TESLA INC.</NoncashPropertyDesc>
#         <FairMarketValueAmt>548695000</FairMarketValueAmt>
#         <ReceivedDt>2021-11-24</ReceivedDt>
#       </NonCashPropertyContributionGrp>
#       <NonCashPropertyContributionGrp>
#         <ContributorNum>1</ContributorNum>
#         <NoncashPropertyDesc>250,000 SHARES OF TESLA INC.</NoncashPropertyDesc>
#         <FairMarketValueAmt>280357500</FairMarketValueAmt>
#         <ReceivedDt>2021-11-29</ReceivedDt>
#       </NonCashPropertyContributionGrp>
#     </IRS990ScheduleB>
#     <AccountingFeesSchedule documentId="RetDoc2002200001">
#       <AccountingFeesDetail>
#         <CategoryTxt>ACCOUNTING FEES</CategoryTxt>
#         <Amt>55029</Amt>
#         <NetInvestmentIncomeAmt>27515</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>27514</DisbursementsCharitablePrpsAmt>
#       </AccountingFeesDetail>
#     </AccountingFeesSchedule>
#     <InvestmentsCorpBondsSchedule documentId="RetDoc2044400001">
#       <InvestmentsCorporateBondsGrp>
#         <BondNm>CORPORATE BONDS</BondNm>
#         <EOYBookValueAmt>38443812</EOYBookValueAmt>
#         <EOYFMVAmt>38455320</EOYFMVAmt>
#       </InvestmentsCorporateBondsGrp>
#     </InvestmentsCorpBondsSchedule>
#     <InvestmentsCorpStockSchedule documentId="RetDoc2018900001">
#       <InvestmentsCorporateStockGrp>
#         <StockNm>CORPORATE STOCK</StockNm>
#         <EOYBookValueAmt>4298355</EOYBookValueAmt>
#         <EOYFMVAmt>9007295245</EOYFMVAmt>
#       </InvestmentsCorporateStockGrp>
#     </InvestmentsCorpStockSchedule>
#     <InvestmentsGovtObligationsSch documentId="RetDoc2210400001">
#       <USGovtObligationsBookVlEOYAmt>83432960</USGovtObligationsBookVlEOYAmt>
#       <USGovtObligationsEOYFMVAmt>83057148</USGovtObligationsEOYFMVAmt>
#       <StateLocalSecBookVlEOYAmt>0</StateLocalSecBookVlEOYAmt>
#       <StateLocalSecEOYFMVAmt>0</StateLocalSecEOYFMVAmt>
#     </InvestmentsGovtObligationsSch>
#     <InvestmentsOtherSchedule2 documentId="RetDoc2018100001">
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>OTHER INVESTMENTS</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>AT COST</ListedAtCostOrFMVCd>
#         <BookValueAmt>188028754</BookValueAmt>
#         <EOYFMVAmt>224859064</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#       <InvestmentsOtherGrp>
#         <CategoryOrItemTxt>ACCRUED INTEREST CARRYOVER</CategoryOrItemTxt>
#         <ListedAtCostOrFMVCd>AT COST</ListedAtCostOrFMVCd>
#         <BookValueAmt>19907</BookValueAmt>
#         <EOYFMVAmt>19907</EOYFMVAmt>
#       </InvestmentsOtherGrp>
#     </InvestmentsOtherSchedule2>
#     <LegalFeesSchedule documentId="RetDoc2002100001">
#       <LegalFeesGrp>
#         <CategoryTxt>LEGAL FEES</CategoryTxt>
#         <LegalFeesAmt>115253</LegalFeesAmt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>115253</DisbursementsCharitablePrpsAmt>
#       </LegalFeesGrp>
#     </LegalFeesSchedule>
#     <OtherDecreasesSchedule documentId="RetDoc2049800001">
#       <OtherDecreasesDetail>
#         <Desc>UNREALIZED GAIN/(LOSS)</Desc>
#         <Amt>5700716720</Amt>
#       </OtherDecreasesDetail>
#     </OtherDecreasesSchedule>
#     <OtherExpensesSchedule documentId="RetDoc2003200001">
#       <OtherExpensesScheduleGrp>
#         <Desc>BOND AMORTIZATION</Desc>
#         <RevenueAndExpensesPerBooksAmt>188056</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>188056</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#       <OtherExpensesScheduleGrp>
#         <Desc>INVESTMENT FEES</Desc>
#         <RevenueAndExpensesPerBooksAmt>130834</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>130834</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#       <OtherExpensesScheduleGrp>
#         <Desc>MISCELLANEOUS FEE</Desc>
#         <RevenueAndExpensesPerBooksAmt>2500</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>2500</DisbursementsCharitablePrpsAmt>
#       </OtherExpensesScheduleGrp>
#     </OtherExpensesSchedule>
#     <OtherIncomeSchedule2 documentId="RetDoc2001500001">
#       <OtherIncomeDetail>
#         <Desc>CLASS ACTION SETTLEMENT</Desc>
#         <RevenueAndExpensesPerBooksAmt>1</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>1</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#       </OtherIncomeDetail>
#       <OtherIncomeDetail>
#         <Desc>MISCELLANEOUS INCOME</Desc>
#         <RevenueAndExpensesPerBooksAmt>11</RevenueAndExpensesPerBooksAmt>
#         <NetInvestmentIncomeAmt>11</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#       </OtherIncomeDetail>
#     </OtherIncomeSchedule2>
#     <OtherProfessionalFeesSchedule documentId="RetDoc2002300001">
#       <OtherProfessionalFeesDetail>
#         <CategoryTxt>PROFESSIONAL SERVICES</CategoryTxt>
#         <Amt>1250</Amt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>1250</DisbursementsCharitablePrpsAmt>
#       </OtherProfessionalFeesDetail>
#       <OtherProfessionalFeesDetail>
#         <CategoryTxt>REGISTERED AGENT FEES</CategoryTxt>
#         <Amt>131</Amt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>131</DisbursementsCharitablePrpsAmt>
#       </OtherProfessionalFeesDetail>
#     </OtherProfessionalFeesSchedule>
#     <TaxesSchedule documentId="RetDoc2002500001">
#       <TaxesDetail>
#         <CategoryTxt>FEDERAL EXTENSION PAYMENT</CategoryTxt>
#         <Amt>2200000</Amt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </TaxesDetail>
#       <TaxesDetail>
#         <CategoryTxt>FEDERAL ESTIMATED TAX</CategoryTxt>
#         <Amt>4300000</Amt>
#         <NetInvestmentIncomeAmt>0</NetInvestmentIncomeAmt>
#         <AdjustedNetIncomeAmt>0</AdjustedNetIncomeAmt>
#         <DisbursementsCharitablePrpsAmt>0</DisbursementsCharitablePrpsAmt>
#       </TaxesDetail>
#     </TaxesSchedule>
#   </ReturnData>
# </Return>

# %%
from bs4 import BeautifulSoup

# %%
musk_data = BeautifulSoup(musk_xml, "xml")
type(musk_data)
# Out:
# bs4.BeautifulSoup

# %%
musk_officer_data = musk_data.select("OfficerDirTrstKeyEmplGrp")
musk_officer_data
# Out:
# [<OfficerDirTrstKeyEmplGrp>
#  <PersonNm>ELON MUSK</PersonNm>
#  <USAddress>
#  <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78734</ZIPCd>
#  </USAddress>
#  <TitleTxt>PRESIDENT &amp; DIRECTOR</TitleTxt>
#  <AverageHrsPerWkDevotedToPosRt>1.00</AverageHrsPerWkDevotedToPosRt>
#  <CompensationAmt>0</CompensationAmt>
#  <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#  <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#  </OfficerDirTrstKeyEmplGrp>,
#  <OfficerDirTrstKeyEmplGrp>
#  <PersonNm>JARED BIRCHALL</PersonNm>
#  <USAddress>
#  <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78734</ZIPCd>
#  </USAddress>
#  <TitleTxt>SECRETARY &amp; TREASURER &amp; DIRECTOR</TitleTxt>
#  <AverageHrsPerWkDevotedToPosRt>1.00</AverageHrsPerWkDevotedToPosRt>
#  <CompensationAmt>0</CompensationAmt>
#  <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#  <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#  </OfficerDirTrstKeyEmplGrp>,
#  <OfficerDirTrstKeyEmplGrp>
#  <PersonNm>MATILDA SIMON</PersonNm>
#  <USAddress>
#  <AddressLine1Txt>PO BOX 341886</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78734</ZIPCd>
#  </USAddress>
#  <TitleTxt>DIRECTOR</TitleTxt>
#  <AverageHrsPerWkDevotedToPosRt>0.10</AverageHrsPerWkDevotedToPosRt>
#  <CompensationAmt>0</CompensationAmt>
#  <EmployeeBenefitProgramAmt>0</EmployeeBenefitProgramAmt>
#  <ExpenseAccountOtherAllwncAmt>0</ExpenseAccountOtherAllwncAmt>
#  </OfficerDirTrstKeyEmplGrp>]

# %%
import pandas as pd

# %%
officer_data = musk_data.find_all("OfficerDirTrstKeyEmplGrp")

officer_list = []

for officer in officer_data:
    officer_dict = {}
    name = officer.find("PersonNm")
    officer_dict["name"] = name.text
    
    title = officer.find("TitleTxt")
    officer_dict["title"] = title.text
    
    officer_list.append(officer_dict)
    
    print(officer_dict)
    print("*********")
# Out:
# {'name': 'ELON MUSK', 'title': 'PRESIDENT & DIRECTOR'}
# *********
# {'name': 'JARED BIRCHALL', 'title': 'SECRETARY & TREASURER & DIRECTOR'}
# *********
# {'name': 'MATILDA SIMON', 'title': 'DIRECTOR'}
# *********

# %%
officer_list
# Out:
# [{'name': 'ELON MUSK', 'title': 'PRESIDENT & DIRECTOR'},
#  {'name': 'JARED BIRCHALL', 'title': 'SECRETARY & TREASURER & DIRECTOR'},
#  {'name': 'MATILDA SIMON', 'title': 'DIRECTOR'}]

# %%
musk_officer_df = pd.DataFrame(officer_list)
musk_officer_df
# Out:
#              name                             title
# 0       ELON MUSK              PRESIDENT & DIRECTOR
# 1  JARED BIRCHALL  SECRETARY & TREASURER & DIRECTOR
# 2   MATILDA SIMON                          DIRECTOR

# %%
recipient_data = musk_data.find_all("GrantOrContributionPdDurYrGrp")
recipient_data
# Out:
# [<GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SIGNAL TECHNOLOGY FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>650 CASTRO STREET SUITE 120-223</AddressLine1Txt>
#  <CityNm>MOUNTAIN VIEW</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>94041</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION</GrantOrContributionPurposeTxt>
#  <Amt>2000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>STEAMSPACE EDUCATION OUTREACH</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>6108 BULLARD DRIVE UNIT A</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78757</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>10000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>VIRGINIA 30 DAY FUND</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1314 RUGBY RD</AddressLine1Txt>
#  <CityNm>CHARLOTTESVILLE</CityNm>
#  <StateAbbreviationCd>VA</StateAbbreviationCd>
#  <ZIPCd>22903</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>FUTURE OF LIFE INSTITUTE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>70 VASSAR ST RM 37-626B</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02139</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE</GrantOrContributionPurposeTxt>
#  <Amt>4000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>FOUNDERS PLEDGE INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>228 PARK AVE S PMB 71081</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>100031502</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT CHARITABLE GIVING</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>DONORSCHOOSEORG</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>134 WEST 37TH STREET - 11TH FLOOR</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10018</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT EDUCATION OF STUDENTS IN NEED</GrantOrContributionPurposeTxt>
#  <Amt>945000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ST JUDE CHILDREN'S RESEARCH HOSPITAL</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>501 ST JUDE PLACE</AddressLine1Txt>
#  <CityNm>MEMPHIS</CityNm>
#  <StateAbbreviationCd>TN</StateAbbreviationCd>
#  <ZIPCd>38105</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES</GrantOrContributionPurposeTxt>
#  <Amt>55000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNICEF USA</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>125 MAIDEN LANE</AddressLine1Txt>
#  <CityNm>NEW YORK</CityNm>
#  <StateAbbreviationCd>NY</StateAbbreviationCd>
#  <ZIPCd>10038</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT EDUCATION OF STUDENTS IN NEED</GrantOrContributionPurposeTxt>
#  <Amt>5000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>FEEDING TEXAS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1524 SOUTH IH-35 SUITE 342</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78704</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT WINTER STORM URI DISASTER RELIEF</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>AUSTIN DISASTER RELIEF NETWORK</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 15424</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78761</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT WINTER STORM URI DISASTER RELIEF</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>X PRIZE FOUNDATION INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>800 CORPORATE POINTE SUITE 350</AddressLine1Txt>
#  <CityNm>CULVER CITY</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>90230</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL</GrantOrContributionPurposeTxt>
#  <Amt>54000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BROWNSVILLE INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1900 E PRICE ROAD</AddressLine1Txt>
#  <CityNm>BROWNSVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78521</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>4946056</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>600 N MESQUITE ST</AddressLine1Txt>
#  <CityNm>LOS FRESNOS</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78566</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>1279503</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>240 N CROCKETT ST</AddressLine1Txt>
#  <CityNm>SAN BENITO</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78586</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>1245513</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>IDEA PUBLIC SCHOOLS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2115 W PIKE BOULEVARD</AddressLine1Txt>
#  <CityNm>WESLACO</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78596</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES</GrantOrContributionPurposeTxt>
#  <Amt>941519</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>LA FERIA INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>203 E OLEANDER AVE</AddressLine1Txt>
#  <CityNm>LA FERIA</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78559</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>378403</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>POINT ISABEL INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>101 PORT ROAD</AddressLine1Txt>
#  <CityNm>PORT ISABEL</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78578</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>253366</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>JUBILEE ACADEMIES</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>4434 ROLAND ROAD</AddressLine1Txt>
#  <CityNm>SAN ANTONIO</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78222</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>232040</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>RIO HONDO INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>215 WEST COLORADO STREET</AddressLine1Txt>
#  <CityNm>RIO HONDO</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78583</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>213393</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>100 MED HIGH DRIVE</AddressLine1Txt>
#  <CityNm>MERCEDES</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78570</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>179756</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>HARMONY SCIENCE ACADEMY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>9321 W SAM HOUSTON PKWY S</AddressLine1Txt>
#  <CityNm>HOUSTON</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>77099</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>123453</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SANTA ROSA INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>102 JESUS R CRUZ</AddressLine1Txt>
#  <CityNm>SANTA ROSA</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78593</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>55584</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SANTA MARIA INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>11119 MILITARY RD</AddressLine1Txt>
#  <CityNm>SANTA MARIA</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78592</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>35669</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>RAUL YZAGUIRRE SCHOOLS FOR SUCCESS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2950 BROADWAY</AddressLine1Txt>
#  <CityNm>HOUSTON</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>77017</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>46676</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SOUTH TEXAS EDUCATIONAL TECHNOLOGIES INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2402 E BUS HWY 83 BLDG 100</AddressLine1Txt>
#  <CityNm>WESLACO</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78596</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>40338</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DISTRICT</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>407 N 77 SUNSHINE STRIP</AddressLine1Txt>
#  <CityNm>HARLINGEN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78550</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>2182553</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>PROMESA PUBLIC SCHOOLS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>5800 E MARTIN LUTHER KING JR BLVD</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78721</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>28030</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>ROMAN CATHOLIC DIOCESE OF BROWNSVILLE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1910 UNIVERSITY BLVD</AddressLine1Txt>
#  <CityNm>BROWNSVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78520</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT GUADALUPE MIDDLE SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>10250</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>RESPONSIVE EDUCATION SOLUTIONS</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 292730</AddressLine1Txt>
#  <CityNm>LEWISVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>75029</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SCHOOL OPERATIONS AND PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>22302</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BROWNSVILLE COMMUNITY IMPROVEMENT CORP</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>500 EAST SAINT CHARLES STREET</AddressLine1Txt>
#  <CityNm>BROWNSVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78520</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT DOWNTOWN BROWNSVILLE BUSINESS IMPROVEMENT AND GROWTH PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>2355000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>CITY OF BROWNSVILLE</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1001 E ELIZABETH STREET</AddressLine1Txt>
#  <CityNm>BROWNSVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78520</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>GOV</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT COMMUNITY IMPROVEMENT AND PAYMENT OF CITY EXPENSES</GrantOrContributionPurposeTxt>
#  <Amt>1339325</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GOOD NEIGHBOR SETTLEMENT HOUSE INC</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>1254 E TYLER ST</AddressLine1Txt>
#  <CityNm>BROWNSVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78520</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT SOCIAL SERVICES FOR PEOPLE IN NEED</GrantOrContributionPurposeTxt>
#  <Amt>208676</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>SBP</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>2645 TOULOUSE STREET</AddressLine1Txt>
#  <CityNm>NEW ORLEANS</CityNm>
#  <StateAbbreviationCd>LA</StateAbbreviationCd>
#  <ZIPCd>70119</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT HURRICANE IDA DISASTER RELIEF</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BROWNSVILLE WELLNESS COALITION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>ONE WEST UNIVERSITY DRIVE - UTSPH</AddressLine1Txt>
#  <CityNm>BROWNSVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78520</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT CULTIVATION OF HEALTHY FOOD AND LIFESTYLES</GrantOrContributionPurposeTxt>
#  <Amt>292000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>HACK CLUB</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>8605 SANTA MONICA BLVD 86294</AddressLine1Txt>
#  <CityNm>WEST HOLLYWOOD</CityNm>
#  <StateAbbreviationCd>CA</StateAbbreviationCd>
#  <ZIPCd>90069</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT CODING EDUCATION</GrantOrContributionPurposeTxt>
#  <Amt>1000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE TRAIL FOUNDATION</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>PO BOX 5195</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78763</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT PROTECTION OF THE BUTLER TRAIL</GrantOrContributionPurposeTxt>
#  <Amt>50000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>BROWNSVILLE MUSEUM OF FINE ART</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>660 E RINGGOLD ST</AddressLine1Txt>
#  <CityNm>BROWNSVILLE</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78520</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT ART EDUCATION AND CULTURAL ENRICHMENT</GrantOrContributionPurposeTxt>
#  <Amt>24300</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>THE UNIVERSITY OF TEXAS AT AUSTIN</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>110 INNER CAMPUS DRIVE</AddressLine1Txt>
#  <CityNm>AUSTIN</CityNm>
#  <StateAbbreviationCd>TX</StateAbbreviationCd>
#  <ZIPCd>78705</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>10000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GEORGETOWN UNIVERSITY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>37TH AND O STREETS NW</AddressLine1Txt>
#  <CityNm>WASHINGTON</CityNm>
#  <StateAbbreviationCd>DC</StateAbbreviationCd>
#  <ZIPCd>20057</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>2000000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>UNIVERSITY OF PENNSYLVANIA</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>249 S 36TH STREET</AddressLine1Txt>
#  <CityNm>PHILADELPHIA</CityNm>
#  <StateAbbreviationCd>PA</StateAbbreviationCd>
#  <ZIPCd>19104</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>MASSACHUSETTS INSTITUTE OF TECHNOLOGY</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientUSAddress>
#  <AddressLine1Txt>77 MASSACHUSETTS AVENUE</AddressLine1Txt>
#  <CityNm>CAMBRIDGE</CityNm>
#  <StateAbbreviationCd>MA</StateAbbreviationCd>
#  <ZIPCd>02139</ZIPCd>
#  </RecipientUSAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT RESEARCH PROGRAMS</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>,
#  <GrantOrContributionPdDurYrGrp>
#  <RecipientBusinessName>
#  <BusinessNameLine1Txt>GLOBAL CHANGE DATA LAB</BusinessNameLine1Txt>
#  </RecipientBusinessName>
#  <RecipientForeignAddress>
#  <AddressLine1Txt>106-108 COWLEY ROAD</AddressLine1Txt>
#  <CityNm>OXFORD</CityNm>
#  <CountryCd>UK</CountryCd>
#  <ForeignPostalCd>OX4 1JE</ForeignPostalCd>
#  </RecipientForeignAddress>
#  <RecipientRelationshipTxt>N/A</RecipientRelationshipTxt>
#  <RecipientFoundationStatusTxt>PC: EQUIVALENCY DET.</RecipientFoundationStatusTxt>
#  <GrantOrContributionPurposeTxt>SUPPORT PRODUCTION AND MAINTENANCE OF PUBLIC ONLINE RESOURCES ON ENVIRONMENT</GrantOrContributionPurposeTxt>
#  <Amt>1500000</Amt>
#  </GrantOrContributionPdDurYrGrp>]

# %%
recipient_list = []

for recipient in recipient_data:
    recipient_dict = {}
    recipient_name = recipient.find("BusinessNameLine1Txt")
    recipient_dict["business_name"] = recipient_name.text
    
    recipient_amount = recipient.find("Amt")
    recipient_dict["amount_received"] = recipient_amount.text
    
    recipient_purpose = recipient.find("GrantOrContributionPurposeTxt")
    recipient_dict["purpose"] = recipient_purpose.text

    recipient_city = recipient.find("CityNm")
    recipient_dict["city"] = recipient_city.text
    
    recipient_state = recipient.find("StateAbbreviationCd")
    recipient_dict["state"] = recipient_state.text
    recipient_list.append(recipient_dict)

    print(recipient_list)
    print("******")
# Out:
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}, {'business_name': 'RIO HONDO INDEPENDENT SCHOOL DISTRICT', 'amount_received': '213393', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'RIO HONDO', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}, {'business_name': 'RIO HONDO INDEPENDENT SCHOOL DISTRICT', 'amount_received': '213393', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'RIO HONDO', 'state': 'TX'}, {'business_name': 'SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT', 'amount_received': '179756', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'MERCEDES', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}, {'business_name': 'RIO HONDO INDEPENDENT SCHOOL DISTRICT', 'amount_received': '213393', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'RIO HONDO', 'state': 'TX'}, {'business_name': 'SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT', 'amount_received': '179756', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'MERCEDES', 'state': 'TX'}, {'business_name': 'HARMONY SCIENCE ACADEMY', 'amount_received': '123453', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'HOUSTON', 'state': 'TX'}]
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}, {'business_name': 'RIO HONDO INDEPENDENT SCHOOL DISTRICT', 'amount_received': '213393', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'RIO HONDO', 'state': 'TX'}, {'business_name': 'SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT', 'amount_received': '179756', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'MERCEDES', 'state': 'TX'}, {'business_name': 'HARMONY SCIENCE ACADEMY', 'amount_received': '123453', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'HOUSTON', 'state': 'TX'}, {'business_name': 'SANTA ROSA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '55584', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SANTA ROSA', 'state': 'TX'}]
# ******
# ...
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}, {'business_name': 'RIO HONDO INDEPENDENT SCHOOL DISTRICT', 'amount_received': '213393', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'RIO HONDO', 'state': 'TX'}, {'business_name': 'SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT', 'amount_received': '179756', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'MERCEDES', 'state': 'TX'}, {'business_name': 'HARMONY SCIENCE ACADEMY', 'amount_received': '123453', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'HOUSTON', 'state': 'TX'}, {'business_name': 'SANTA ROSA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '55584', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SANTA ROSA', 'state': 'TX'}, {'business_name': 'SANTA MARIA INDEPENDENT SCHOOL DISTRICT', 'amount_receiv ...
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}, {'business_name': 'RIO HONDO INDEPENDENT SCHOOL DISTRICT', 'amount_received': '213393', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'RIO HONDO', 'state': 'TX'}, {'business_name': 'SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT', 'amount_received': '179756', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'MERCEDES', 'state': 'TX'}, {'business_name': 'HARMONY SCIENCE ACADEMY', 'amount_received': '123453', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'HOUSTON', 'state': 'TX'}, {'business_name': 'SANTA ROSA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '55584', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SANTA ROSA', 'state': 'TX'}, {'business_name': 'SANTA MARIA INDEPENDENT SCHOOL DISTRICT', 'amount_receiv ...
# ******
# [{'business_name': 'SIGNAL TECHNOLOGY FOUNDATION', 'amount_received': '2000000', 'purpose': 'SUPPORT PROTECTION OF FREE EXPRESSION AND SECURITY OF GLOBAL COMMUNICATION', 'city': 'MOUNTAIN VIEW', 'state': 'CA'}, {'business_name': 'STEAMSPACE EDUCATION OUTREACH', 'amount_received': '10000', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'VIRGINIA 30 DAY FUND', 'amount_received': '1000000', 'purpose': 'SUPPORT SMALL BUSINESSES AT RISK DUE TO THE COVID-19 CRISIS', 'city': 'CHARLOTTESVILLE', 'state': 'VA'}, {'business_name': 'FUTURE OF LIFE INSTITUTE', 'amount_received': '4000000', 'purpose': 'SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARDING LIFE AND DEVELOPING OPTIMISTIC VISIONS OF THE FUTURE', 'city': 'CAMBRIDGE', 'state': 'MA'}, {'business_name': 'FOUNDERS PLEDGE INC', 'amount_received': '1000000', 'purpose': 'SUPPORT CHARITABLE GIVING', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'DONORSCHOOSEORG', 'amount_received': '945000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': "ST JUDE CHILDREN'S RESEARCH HOSPITAL", 'amount_received': '55000000', 'purpose': 'SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CATASTROPHIC DISEASES', 'city': 'MEMPHIS', 'state': 'TN'}, {'business_name': 'UNICEF USA', 'amount_received': '5000000', 'purpose': 'SUPPORT EDUCATION OF STUDENTS IN NEED', 'city': 'NEW YORK', 'state': 'NY'}, {'business_name': 'FEEDING TEXAS', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'AUSTIN DISASTER RELIEF NETWORK', 'amount_received': '1000000', 'purpose': 'SUPPORT WINTER STORM URI DISASTER RELIEF', 'city': 'AUSTIN', 'state': 'TX'}, {'business_name': 'X PRIZE FOUNDATION INC', 'amount_received': '54000000', 'purpose': 'SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON REMOVAL', 'city': 'CULVER CITY', 'state': 'CA'}, {'business_name': 'BROWNSVILLE INDEPENDENT SCHOOL DISTRICT', 'amount_received': '4946056', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'BROWNSVILLE', 'state': 'TX'}, {'business_name': 'LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1279503', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LOS FRESNOS', 'state': 'TX'}, {'business_name': 'SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DISTRICT', 'amount_received': '1245513', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN BENITO', 'state': 'TX'}, {'business_name': 'IDEA PUBLIC SCHOOLS', 'amount_received': '941519', 'purpose': 'SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED COMMUNITIES', 'city': 'WESLACO', 'state': 'TX'}, {'business_name': 'LA FERIA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '378403', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'LA FERIA', 'state': 'TX'}, {'business_name': 'POINT ISABEL INDEPENDENT SCHOOL DISTRICT', 'amount_received': '253366', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'PORT ISABEL', 'state': 'TX'}, {'business_name': 'JUBILEE ACADEMIES', 'amount_received': '232040', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SAN ANTONIO', 'state': 'TX'}, {'business_name': 'RIO HONDO INDEPENDENT SCHOOL DISTRICT', 'amount_received': '213393', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'RIO HONDO', 'state': 'TX'}, {'business_name': 'SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT', 'amount_received': '179756', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'MERCEDES', 'state': 'TX'}, {'business_name': 'HARMONY SCIENCE ACADEMY', 'amount_received': '123453', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'HOUSTON', 'state': 'TX'}, {'business_name': 'SANTA ROSA INDEPENDENT SCHOOL DISTRICT', 'amount_received': '55584', 'purpose': 'SUPPORT SCHOOL OPERATIONS AND PROGRAMS', 'city': 'SANTA ROSA', 'state': 'TX'}, {'business_name': 'SANTA MARIA INDEPENDENT SCHOOL DISTRICT', 'amount_receiv ...
# ******
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# Cell In[26], line 18
#      15 recipient_dict["city"] = recipient_city.text
#      17 recipient_state = recipient.find("StateAbbreviationCd")
# ---> 18 recipient_dict["state"] = recipient_state.text
#      19 recipient_list.append(recipient_dict)
#      21 print(recipient_list)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
musk_recipient_df = pd.DataFrame(recipient_list)
musk_recipient_df
# Out:
#                                         business_name amount_received  \
# 0                        SIGNAL TECHNOLOGY FOUNDATION         2000000
# 1                       STEAMSPACE EDUCATION OUTREACH           10000
# 2                                VIRGINIA 30 DAY FUND         1000000
# 3                            FUTURE OF LIFE INSTITUTE         4000000
# 4                                 FOUNDERS PLEDGE INC         1000000
# 5                                     DONORSCHOOSEORG          945000
# 6                ST JUDE CHILDREN'S RESEARCH HOSPITAL        55000000
# 7                                          UNICEF USA         5000000
# 8                                       FEEDING TEXAS         1000000
# 9                      AUSTIN DISASTER RELIEF NETWORK         1000000
# 10                             X PRIZE FOUNDATION INC        54000000
# 11            BROWNSVILLE INDEPENDENT SCHOOL DISTRICT         4946056
# 12  LOS FRESNOS CONSOLIDATED INDEPENDENT SCHOOL DI...         1279503
# 13  SAN BENITO CONSOLIDATED INDEPENDENT SCHOOL DIS...         1245513
# 14                                IDEA PUBLIC SCHOOLS          941519
# 15               LA FERIA INDEPENDENT SCHOOL DISTRICT          378403
# 16           POINT ISABEL INDEPENDENT SCHOOL DISTRICT          253366
# 17                                  JUBILEE ACADEMIES          232040
# 18              RIO HONDO INDEPENDENT SCHOOL DISTRICT          213393
# 19            SOUTH TEXAS INDEPENDENT SCHOOL DISTRICT          179756
# 20                            HARMONY SCIENCE ACADEMY          123453
# 21             SANTA ROSA INDEPENDENT SCHOOL DISTRICT           55584
# 22            SANTA MARIA INDEPENDENT SCHOOL DISTRICT           35669
# 23                 RAUL YZAGUIRRE SCHOOLS FOR SUCCESS           46676
# 24           SOUTH TEXAS EDUCATIONAL TECHNOLOGIES INC           40338
# 25  HARLINGEN CONSOLIDATED INDEPENDENT SCHOOL DIST...         2182553
# 26                             PROMESA PUBLIC SCHOOLS           28030
# 27              ROMAN CATHOLIC DIOCESE OF BROWNSVILLE           10250
# 28                     RESPONSIVE EDUCATION SOLUTIONS           22302
# 29             BROWNSVILLE COMMUNITY IMPROVEMENT CORP         2355000
# 30                                CITY OF BROWNSVILLE         1339325
# 31                 GOOD NEIGHBOR SETTLEMENT HOUSE INC          208676
# 32                                                SBP         1000000
# 33                     BROWNSVILLE WELLNESS COALITION          292000
# 34                                          HACK CLUB         1000000
# 35                               THE TRAIL FOUNDATION           50000
# 36                     BROWNSVILLE MUSEUM OF FINE ART           24300
# 37                  THE UNIVERSITY OF TEXAS AT AUSTIN        10000000
# 38                              GEORGETOWN UNIVERSITY         2000000
# 39                         UNIVERSITY OF PENNSYLVANIA         1500000
# 40              MASSACHUSETTS INSTITUTE OF TECHNOLOGY         1500000
#
#                                               purpose             city state
# 0   SUPPORT PROTECTION OF FREE EXPRESSION AND SECU...    MOUNTAIN VIEW    CA
# 1              SUPPORT SCHOOL OPERATIONS AND PROGRAMS           AUSTIN    TX
# 2   SUPPORT SMALL BUSINESSES AT RISK DUE TO THE CO...  CHARLOTTESVILLE    VA
# 3   SUPPORT RESEARCH AND INITIATIVES FOR SAFEGUARD...        CAMBRIDGE    MA
# 4                           SUPPORT CHARITABLE GIVING         NEW YORK    NY
# 5               SUPPORT EDUCATION OF STUDENTS IN NEED         NEW YORK    NY
# 6   SUPPORT RESEARCH AND TREATMENT OF PEDIATRIC CA...          MEMPHIS    TN
# 7               SUPPORT EDUCATION OF STUDENTS IN NEED         NEW YORK    NY
# 8            SUPPORT WINTER STORM URI DISASTER RELIEF           AUSTIN    TX
# 9            SUPPORT WINTER STORM URI DISASTER RELIEF           AUSTIN    TX
# 10  SUPPORT TECHNOLOGICAL DEVELOPMENT FOR CARBON R...      CULVER CITY    CA
# 11             SUPPORT SCHOOL OPERATIONS AND PROGRAMS      BROWNSVILLE    TX
# 12             SUPPORT SCHOOL OPERATIONS AND PROGRAMS      LOS FRESNOS    TX
# 13             SUPPORT SCHOOL OPERATIONS AND PROGRAMS       SAN BENITO    TX
# 14  SUPPORT EDUCATION OF STUDENTS FROM UNDERSERVED...          WESLACO    TX
# 15             SUPPORT SCHOOL OPERATIONS AND PROGRAMS         LA FERIA    TX
# 16             SUPPORT SCHOOL OPERATIONS AND PROGRAMS      PORT ISABEL    TX
# 17             SUPPORT SCHOOL OPERATIONS AND PROGRAMS      SAN ANTONIO    TX
# 18             SUPPORT SCHOOL OPERATIONS AND PROGRAMS        RIO HONDO    TX
# 19             SUPPORT SCHOOL OPERATIONS AND PROGRAMS         MERCEDES    TX
# 20             SUPPORT SCHOOL OPERATIONS AND PROGRAMS          HOUSTON    TX
# 21             SUPPORT SCHOOL OPERATIONS AND PROGRAMS       SANTA ROSA    TX
# 22             SUPPORT SCHOOL OPERATIONS AND PROGRAMS      SANTA MARIA    TX
# 23             SUPPORT SCHOOL OPERATIONS AND PROGRAMS          HOUSTON    TX
# 24             SUPPORT SCHOOL OPERATIONS AND PROGRAMS          WESLACO    TX
# 25             SUPPORT SCHOOL OPERATIONS AND PROGRAMS        HARLINGEN    TX
# 26             SUPPORT SCHOOL OPERATIONS AND PROGRAMS           AUSTIN    TX
# 27  SUPPORT GUADALUPE MIDDLE SCHOOL OPERATIONS AND...      BROWNSVILLE    TX
# 28             SUPPORT SCHOOL OPERATIONS AND PROGRAMS       LEWISVILLE    TX
# 29  SUPPORT DOWNTOWN BROWNSVILLE BUSINESS IMPROVEM...      BROWNSVILLE    TX
# 30  SUPPORT COMMUNITY IMPROVEMENT AND PAYMENT OF C...      BROWNSVILLE    TX
# 31         SUPPORT SOCIAL SERVICES FOR PEOPLE IN NEED      BROWNSVILLE    TX
# 32              SUPPORT HURRICANE IDA DISASTER RELIEF      NEW ORLEANS    LA
# 33  SUPPORT CULTIVATION OF HEALTHY FOOD AND LIFEST...      BROWNSVILLE    TX
# 34                           SUPPORT CODING EDUCATION   WEST HOLLYWOOD    CA
# 35             SUPPORT PROTECTION OF THE BUTLER TRAIL           AUSTIN    TX
# 36      SUPPORT ART EDUCATION AND CULTURAL ENRICHMENT      BROWNSVILLE    TX
# 37                          SUPPORT RESEARCH PROGRAMS           AUSTIN    TX
# 38                          SUPPORT RESEARCH PROGRAMS       WASHINGTON    DC
# 39                          SUPPORT RESEARCH PROGRAMS     PHILADELPHIA    PA
# 40                          SUPPORT RESEARCH PROGRAMS        CAMBRIDGE    MA

# %%
contributor_data = musk_data.find_all("ContributorInformationGrp")

officer_list = []

for officer in officer_data:
    officer_dict = {}
    name = officer.find("PersonNm")
    officer_dict["name"] = name.text
    
    title = officer.find("TitleTxt")
    officer_dict["title"] = title.text
    
    officer_list.append(officer_dict)
    
    print(officer_dict)
    print("*********")
